# %% [markdown]
# # Simon's algorithm

# %% [markdown]
# Simon's algorithm is closely related in principle to the Bernstein-Vazirani algorithm and the Deutsch-Josza algorithm, (which are also explained in other notebooks in this repository).
#
# We are given an "oracle" and promised that its outputs are either **one-to-one** or **two-to-one**, i.e., it either has **exactly** as many possible outputs as possible inputs or **exactly half** as many possible outputs as possible inputs. In effect, all two-to-one functions can be thought of as being based on a "**hidden string**" encoded into the oracle, whereas one-to-one functions are the only case where the hidden string is "**0**." Our problem is therefore to determine the "hidden string" encoded into the oracle.
#
# A classical computer, on average, needs to check about half the possible inputs to answer the question of what the hidden string is; a quantum computer needs **exponentially fewer** queries of the oracle to determine the same answer.

# %%
from collections import Counter
from pyqrack import QrackSimulator

hidden_bits = 37
input_size = 30
num_qubits = input_size * 2
oracle_qubits = [*range(input_size)]

# %% [markdown]
# You may change the `hidden_bits` above to be any value that can fit within the oracle register width. Your `hidden_bits` corresponds to the oracle below:

# %%
def oracle(sim):
    # The first portion of this oracle is effectively a one-to-one oracle,
    # in itself, (though not the only possible one-to-one oracle).
    for i in oracle_qubits:
        sim.mcx([i], i + input_size)

    # The second portion of this oracle makes it two-to-one,
    # (unless "hidden_bits" is 0):
    for i in oracle_qubits:
        if (hidden_bits >> i) & 1:
            for j in oracle_qubits:
                if (hidden_bits >> j) & 1:
                    sim.mcx([i], j + input_size)
            break;

# %% [markdown]
# All of the following statements of equality are true:

# %%
# Prepare the initial register state:
sim = QrackSimulator(num_qubits)
for i in oracle_qubits:
    sim.h(i)

# Make exactly one query to the oracle:
oracle(sim)

# Finish the unitary portion of the algorithm, with the result from the oracle...
# (It is often presented that measurement of the second register needs to occur before this step;
# this is actually wholly theoretically unnecessary in the ideal, due to locality of quantum information.)
for i in oracle_qubits:
    sim.h(i)

# The cost in "shot" count is linear, at this point.
results = Counter(sim.measure_shots(oracle_qubits, 10000))

for key in results.keys():
    print("hidden_bits .", key, "= 0 (mod 2)")
# Out:
# Device #0, Loaded binary from: /home/iamu/.qrack/qrack_ocl_dev_Intel(R)_UHD_Graphics_[0x9bc4].ir
# Device #1, Loaded binary from: /home/iamu/.qrack/qrack_ocl_dev_NVIDIA_GeForce_RTX_3080_Laptop_GPU.ir
# hidden_bits . 2529 = 0 (mod 2)
# hidden_bits . 134246 = 0 (mod 2)
# hidden_bits . 241771 = 0 (mod 2)
# hidden_bits . 246910 = 0 (mod 2)
# hidden_bits . 305671 = 0 (mod 2)
# hidden_bits . 336116 = 0 (mod 2)
# hidden_bits . 431181 = 0 (mod 2)
# hidden_bits . 618560 = 0 (mod 2)
# hidden_bits . 693939 = 0 (mod 2)
# hidden_bits . 703075 = 0 (mod 2)
# hidden_bits . 713751 = 0 (mod 2)
# hidden_bits . 906915 = 0 (mod 2)
# hidden_bits . 1086423 = 0 (mod 2)
# hidden_bits . 1135954 = 0 (mod 2)
# hidden_bits . 1338831 = 0 (mod 2)
# hidden_bits . 1583348 = 0 (mod 2)
# hidden_bits . 1708383 = 0 (mod 2)
# hidden_bits . 1719678 = 0 (mod 2)
# hidden_bits . 1799752 = 0 (mod 2)
# hidden_bits . 1832763 = 0 (mod 2)
# hidden_bits . 1865836 = 0 (mod 2)
# hidden_bits . 1882256 = 0 (mod 2)
# hidden_bits . 1968842 = 0 (mod 2)
# hidden_bits . 1969004 = 0 (mod 2)
# hidden_bits . 2169532 = 0 (mod 2)
# hidden_bits . 2205225 = 0 (mod 2)
# hidden_bits . 2274504 = 0 (mod 2)
# hidden_bits . 2433221 = 0 (mod 2)
# hidden_bits . 2461912 = 0 (mod 2)
# hidden_bits . 2522637 = 0 (mod 2)
# hidden_bits . 2607047 = 0 (mod 2)
# hidden_bits . 2677246 = 0 (mod 2)
# hidden_bits . 2700393 = 0 (mod 2)
# hidden_bits . 2955416 = 0 (mod 2)
# hidden_bits . 2990075 = 0 (mod 2)
# hidden_bits . 3034757 = 0 (mod 2)
# hidden_bits . 3165061 = 0 (mod 2)
# hidden_bits . 3222134 = 0 (mod 2)
# hidden_bits . 3522606 = 0 (mod 2)
# hidden_bits . 3540350 = 0 (mod 2)
# hidden_bits . 3756910 = 0 (mod 2)
# hidden_bits . 3899307 = 0 (mod 2)
# hidden_bits . 4127729 = 0 (mod 2)
# hidden_bits . 4150198 = 0 (mod 2)
# hidden_bits . 4514890 = 0 (mod 2)
# hidden_bits . 4560647 = 0 (mod 2)
# hidden_bits . 4651964 = 0 (mod 2)
# hidden_bits . 4781319 = 0 (mod 2)
# hidden_bits . 4808953 = 0 (mod 2)
# hidden_bits . 5118400 = 0 (mod 2)
# hidden_bits . 5185565 = 0 (mod 2)
# hidden_bits . 5195105 = 0 (mod 2)
# hidden_bits . 5332183 = 0 (mod 2)
# hidden_bits . 5339571 = 0 (mod 2)
# hidden_bits . 5404918 = 0 (mod 2)
# hidden_bits . 5716055 = 0 (mod 2)
# hidden_bits . 5718557 = 0 (mod 2)
# hidden_bits . 6019719 = 0 (mod 2)
# hidden_bits . 6264825 = 0 (mod 2)
# hidden_bits . 6436772 = 0 (mod 2)
# hidden_bits . 6471495 = 0 (mod 2)
# hidden_bits . 6490238 = 0 (mod 2)
# hidden_bits . 6682973 = 0 (mod 2)
# hidden_bits . 6703768 = 0 (mod 2)
# hidden_bits . 6802959 = 0 (mod 2)
# hidden_bits . 6924780 = 0 (mod 2)
# hidden_bits . 6936325 = 0 (mod 2)
# hidden_bits . 6971110 = 0 (mod 2)
# hidden_bits . 7214098 = 0 (mod 2)
# hidden_bits . 7241418 = 0 (mod 2)
# hidden_bits . 7285105 = 0 (mod 2)
# hidden_bits . 7380298 = 0 (mod 2)
# hidden_bits . 7467679 = 0 (mod 2)
# hidden_bits . 7525133 = 0 (mod 2)
# hidden_bits . 7648179 = 0 (mod 2)
# hidden_bits . 7719309 = 0 (mod 2)
# hidden_bits . 7826688 = 0 (mod 2)
# hidden_bits . 7864355 = 0 (mod 2)
# hidden_bits . 8066806 = 0 (mod 2)
# hidden_bits . 8310249 = 0 (mod 2)
# hidden_bits . 8411602 = 0 (mod 2)
# hidden_bits . 8470232 = 0 (mod 2)
# hidden_bits . 8563556 = 0 (mod 2)
# hidden_bits . 8571405 = 0 (mod 2)
# hidden_bits . 8643994 = 0 (mod 2)
# hidden_bits . 8658420 = 0 (mod 2)
# hidden_bits . 8699179 = 0 (mod 2)
# hidden_bits . 8876511 = 0 (mod 2)
# hidden_bits . 8970811 = 0 (mod 2)
# hidden_bits . 8982502 = 0 (mod 2)
# hidden_bits . 9031069 = 0 (mod 2)
# hidden_bits . 9146804 = 0 (mod 2)
# hidden_bits . 9181502 = 0 (mod 2)
# hidden_bits . 9256789 = 0 (mod 2)
# hidden_bits . 9261876 = 0 (mod 2)
# hidden_bits . 9273997 = 0 (mod 2)
# hidden_bits . 9301561 = 0 (mod 2)
# hidden_bits . 9339853 = 0 (mod 2)
# hidden_bits . 9395377 = 0 (mod 2)
# hidden_bits . 9559804 = 0 (mod 2)
# hidden_bits . 9685035 = 0 (mod 2)
# hidden_bits . 9696057 = 0 (mod 2)
# hidden_bits . 9735092 = 0 (mod 2)
# hidden_bits . 9738675 = 0 (mod 2)
# hidden_bits . 9764432 = 0 (mod 2)
# hidden_bits . 10084944 = 0 (mod 2)
# hidden_bits . 10132651 = 0 (mod 2)
# hidden_bits . 10144188 = 0 (mod 2)
# hidden_bits . 10262435 = 0 (mod 2)
# hidden_bits . 10319872 = 0 (mod 2)
# hidden_bits . 10585688 = 0 (mod 2)
# hidden_bits . 10600970 = 0 (mod 2)
# hidden_bits . 10727729 = 0 (mod 2)
# hidden_bits . 10888919 = 0 (mod 2)
# hidden_bits . 11003032 = 0 (mod 2)
# hidden_bits . 11111932 = 0 (mod 2)
# hidden_bits . 11375462 = 0 (mod 2)
# hidden_bits . 11423111 = 0 (mod 2)
# hidden_bits . 11649496 = 0 (mod 2)
# hidden_bits . 11815547 = 0 (mod 2)
# hidden_bits . 11857418 = 0 (mod 2)
# hidden_bits . 11893998 = 0 (mod 2)
# hidden_bits . 11917860 = 0 (mod 2)
# hidden_bits . 12092869 = 0 (mod 2)
# hidden_bits . 12156860 = 0 (mod 2)
# hidden_bits . 12322870 = 0 (mod 2)
# hidden_bits . 12323018 = 0 (mod 2)
# hidden_bits . 12422307 = 0 (mod 2)
# hidden_bits . 12495931 = 0 (mod 2)
# hidden_bits . 12503916 = 0 (mod 2)
# hidden_bits . 12609823 = 0 (mod 2)
# hidden_bits . 12710390 = 0 (mod 2)
# hidden_bits . 12904282 = 0 (mod 2)
# hidden_bits . 12980063 = 0 (mod 2)
# hidden_bits . 13045748 = 0 (mod 2)
# hidden_bits . 13162389 = 0 (mod 2)
# hidden_bits . 13192892 = 0 (mod 2)
# hidden_bits . 13304737 = 0 (mod 2)
# hidden_bits . 13381983 = 0 (mod 2)
# hidden_bits . 13495214 = 0 (mod 2)
# hidden_bits . 13721342 = 0 (mod 2)
# hidden_bits . 13811443 = 0 (mod 2)
# hidden_bits . 13924623 = 0 (mod 2)
# hidden_bits . 14515586 = 0 (mod 2)
# hidden_bits . 14554534 = 0 (mod 2)
# hidden_bits . 14673577 = 0 (mod 2)
# hidden_bits . 14930606 = 0 (mod 2)
# hidden_bits . 14930859 = 0 (mod 2)
# hidden_bits . 14955800 = 0 (mod 2)
# hidden_bits . 14980900 = 0 (mod 2)
# hidden_bits . 15086736 = 0 (mod 2)
# hidden_bits . 15540515 = 0 (mod 2)
# hidden_bits . 15703253 = 0 (mod 2)
# hidden_bits . 15751803 = 0 (mod 2)
# hidden_bits . 15861325 = 0 (mod 2)
# hidden_bits . 15864188 = 0 (mod 2)
# hidden_bits . 15894908 = 0 (mod 2)
# hidden_bits . 15924862 = 0 (mod 2)
# hidden_bits . 15987408 = 0 (mod 2)
# hidden_bits . 16109041 = 0 (mod 2)
# hidden_bits . 16165256 = 0 (mod 2)
# hidden_bits . 16191685 = 0 (mod 2)
# hidden_bits . 16378200 = 0 (mod 2)
# hidden_bits . 16502989 = 0 (mod 2)
# hidden_bits . 16599460 = 0 (mod 2)
# hidden_bits . 16658450 = 0 (mod 2)
# hidden_bits . 16667663 = 0 (mod 2)
# hidden_bits . 16723282 = 0 (mod 2)
# hidden_bits . 16820006 = 0 (mod 2)
# hidden_bits . 17074207 = 0 (mod 2)
# hidden_bits . 17153961 = 0 (mod 2)
# hidden_bits . 17197896 = 0 (mod 2)
# hidden_bits . 17303996 = 0 (mod 2)
# hidden_bits . 17421164 = 0 (mod 2)
# hidden_bits . 17732160 = 0 (mod 2)
# hidden_bits . 17757729 = 0 (mod 2)
# hidden_bits . 17788871 = 0 (mod 2)
# hidden_bits . 17792016 = 0 (mod 2)
# hidden_bits . 18129608 = 0 (mod 2)
# hidden_bits . 18157911 = 0 (mod 2)
# hidden_bits . 18193178 = 0 (mod 2)
# hidden_bits . 18348923 = 0 (mod 2)
# hidden_bits . 18490726 = 0 (mod 2)
# hidden_bits . 18769927 = 0 (mod 2)
# hidden_bits . 18777593 = 0 (mod 2)
# hidden_bits . 18894680 = 0 (mod 2)
# hidden_bits . 19155994 = 0 (mod 2)
# hidden_bits . 19215901 = 0 (mod 2)
# hidden_bits . 19273761 = 0 (mod 2)
# hidden_bits . 19535844 = 0 (mod 2)
# hidden_bits . 19638257 = 0 (mod 2)
# hidden_bits . 19828790 = 0 (mod 2)
# hidden_bits . 19945910 = 0 (mod 2)
# hidden_bits . 20065577 = 0 (mod 2)
# hidden_bits . 20067446 = 0 (mod 2)
# hidden_bits . 20217730 = 0 (mod 2)
# hidden_bits . 20269591 = 0 (mod 2)
# hidden_bits . 20411226 = 0 (mod 2)
# hidden_bits . 20574663 = 0 (mod 2)
# hidden_bits . 20857593 = 0 (mod 2)
# hidden_bits . 20857610 = 0 (mod 2)
# hidden_bits . 20967596 = 0 (mod 2)
# hidden_bits . 20996465 = 0 (mod 2)
# hidden_bits . 21043065 = 0 (mod 2)
# hidden_bits . 21245164 = 0 (mod 2)
# hidden_bits . 21302628 = 0 (mod 2)
# hidden_bits . 21500621 = 0 (mod 2)
# hidden_bits . 21539973 = 0 (mod 2)
# hidden_bits . 21625567 = 0 (mod 2)
# hidden_bits . 21645717 = 0 (mod 2)
# hidden_bits . 21669333 = 0 (mod 2)
# hidden_bits . 21746447 = 0 (mod 2)
# hidden_bits . 21981356 = 0 (mod 2)
# hidden_bits . 21989386 = 0 (mod 2)
# hidden_bits . 22020685 = 0 (mod 2)
# hidden_bits . 22022121 = 0 (mod 2)
# hidden_bits . 22087938 = 0 (mod 2)
# hidden_bits . 22132326 = 0 (mod 2)
# hidden_bits . 22170909 = 0 (mod 2)
# hidden_bits . 22615242 = 0 (mod 2)
# hidden_bits . 22721403 = 0 (mod 2)
# hidden_bits . 22762909 = 0 (mod 2)
# hidden_bits . 22984190 = 0 (mod 2)
# hidden_bits . 23013274 = 0 (mod 2)
# hidden_bits . 23034266 = 0 (mod 2)
# hidden_bits . 23095230 = 0 (mod 2)
# hidden_bits . 23133138 = 0 (mod 2)
# hidden_bits . 23237511 = 0 (mod 2)
# hidden_bits . 23315627 = 0 (mod 2)
# hidden_bits . 23347694 = 0 (mod 2)
# hidden_bits . 23465232 = 0 (mod 2)
# hidden_bits . 23540565 = 0 (mod 2)
# hidden_bits . 23582487 = 0 (mod 2)
# hidden_bits . 23828091 = 0 (mod 2)
# hidden_bits . 23882141 = 0 (mod 2)
# hidden_bits . 23956301 = 0 (mod 2)
# hidden_bits . 24017989 = 0 (mod 2)
# hidden_bits . 24106655 = 0 (mod 2)
# hidden_bits . 24177088 = 0 (mod 2)
# hidden_bits . 24228542 = 0 (mod 2)
# hidden_bits . 24285837 = 0 (mod 2)
# hidden_bits . 24316140 = 0 (mod 2)
# hidden_bits . 24354015 = 0 (mod 2)
# hidden_bits . 24426397 = 0 (mod 2)
# hidden_bits . 24433843 = 0 (mod 2)
# hidden_bits . 24484403 = 0 (mod 2)
# hidden_bits . 24538980 = 0 (mod 2)
# hidden_bits . 24558034 = 0 (mod 2)
# hidden_bits . 24608291 = 0 (mod 2)
# hidden_bits . 24805064 = 0 (mod 2)
# hidden_bits . 25028039 = 0 (mod 2)
# hidden_bits . 25154406 = 0 (mod 2)
# hidden_bits . 25235018 = 0 (mod 2)
# hidden_bits . 25514653 = 0 (mod 2)
# hidden_bits . 25593487 = 0 (mod 2)
# hidden_bits . 25644988 = 0 (mod 2)
# hidden_bits . 25721918 = 0 (mod 2)
# hidden_bits . 25770044 = 0 (mod 2)
# hidden_bits . 25861530 = 0 (mod 2)
# hidden_bits . 26020129 = 0 (mod 2)
# hidden_bits . 26126326 = 0 (mod 2)
# hidden_bits . 26203471 = 0 (mod 2)
# hidden_bits . 26239327 = 0 (mod 2)
# hidden_bits . 26352642 = 0 (mod 2)
# hidden_bits . 26748011 = 0 (mod 2)
# hidden_bits . 26751731 = 0 (mod 2)
# hidden_bits . 26751843 = 0 (mod 2)
# hidden_bits . 26846572 = 0 (mod 2)
# hidden_bits . 26875198 = 0 (mod 2)
# hidden_bits . 26877698 = 0 (mod 2)
# hidden_bits . 26915964 = 0 (mod 2)
# hidden_bits . 26925281 = 0 (mod 2)
# hidden_bits . 27075006 = 0 (mod 2)
# hidden_bits . 27418456 = 0 (mod 2)
# hidden_bits . 27467371 = 0 (mod 2)
# hidden_bits . 27558493 = 0 (mod 2)
# hidden_bits . 27600664 = 0 (mod 2)
# hidden_bits . 27736455 = 0 (mod 2)
# hidden_bits . 27742874 = 0 (mod 2)
# hidden_bits . 27788618 = 0 (mod 2)
# hidden_bits . 27813547 = 0 (mod 2)
# hidden_bits . 27817406 = 0 (mod 2)
# hidden_bits . 27821701 = 0 (mod 2)
# hidden_bits . 27922783 = 0 (mod 2)
# hidden_bits . 27993415 = 0 (mod 2)
# hidden_bits . 28001229 = 0 (mod 2)
# hidden_bits . 28081816 = 0 (mod 2)
# hidden_bits . 28101904 = 0 (mod 2)
# hidden_bits . 28404626 = 0 (mod 2)
# hidden_bits . 28423345 = 0 (mod 2)
# hidden_bits . 28429091 = 0 (mod 2)
# hidden_bits . 28607926 = 0 (mod 2)
# hidden_bits . 28842019 = 0 (mod 2)
# hidden_bits . 28875098 = 0 (mod 2)
# hidden_bits . 28987827 = 0 (mod 2)
# hidden_bits . 29079459 = 0 (mod 2)
# hidden_bits . 29218046 = 0 (mod 2)
# hidden_bits . 29517274 = 0 (mod 2)
# hidden_bits . 29568620 = 0 (mod 2)
# hidden_bits . 29599595 = 0 (mod 2)
# hidden_bits . 29874276 = 0 (mod 2)
# hidden_bits . 30323243 = 0 (mod 2)
# hidden_bits . 30567629 = 0 (mod 2)
# hidden_bits . 30649396 = 0 (mod 2)
# hidden_bits . 30675963 = 0 (mod 2)
# hidden_bits . 30694179 = 0 (mod 2)
# hidden_bits . 30734914 = 0 (mod 2)
# hidden_bits . 30786150 = 0 (mod 2)
# hidden_bits . 30795917 = 0 (mod 2)
# hidden_bits . 31298484 = 0 (mod 2)
# hidden_bits . 31362063 = 0 (mod 2)
# hidden_bits . 31427243 = 0 (mod 2)
# hidden_bits . 31438536 = 0 (mod 2)
# hidden_bits . 31743439 = 0 (mod 2)
# hidden_bits . 31870251 = 0 (mod 2)
# hidden_bits . 32024684 = 0 (mod 2)
# hidden_bits . 32044744 = 0 (mod 2)
# hidden_bits . 32074312 = 0 (mod 2)
# hidden_bits . 32182408 = 0 (mod 2)
# hidden_bits . 32828752 = 0 (mod 2)
# hidden_bits . 33102844 = 0 (mod 2)
# hidden_bits . 33119373 = 0 (mod 2)
# hidden_bits . 33160313 = 0 (mod 2)
# hidden_bits . 33304410 = 0 (mod 2)
# hidden_bits . 33368372 = 0 (mod 2)
# hidden_bits . 33507527 = 0 (mod 2)
# hidden_bits . 33606782 = 0 (mod 2)
# hidden_bits . 33716836 = 0 (mod 2)
# hidden_bits . 33871442 = 0 (mod 2)
# hidden_bits . 34115039 = 0 (mod 2)
# hidden_bits . 34292034 = 0 (mod 2)
# hidden_bits . 34342848 = 0 (mod 2)
# hidden_bits . 34372537 = 0 (mod 2)
# hidden_bits . 34381113 = 0 (mod 2)
# hidden_bits . 34397447 = 0 (mod 2)
# hidden_bits . 34450775 = 0 (mod 2)
# hidden_bits . 34473892 = 0 (mod 2)
# hidden_bits . 34540475 = 0 (mod 2)
# hidden_bits . 34559837 = 0 (mod 2)
# hidden_bits . 34972749 = 0 (mod 2)
# hidden_bits . 35046400 = 0 (mod 2)
# hidden_bits . 35105373 = 0 (mod 2)
# hidden_bits . 35152177 = 0 (mod 2)
# hidden_bits . 35182807 = 0 (mod 2)
# hidden_bits . 35216110 = 0 (mod 2)
# hidden_bits . 35544748 = 0 (mod 2)
# hidden_bits . 35738745 = 0 (mod 2)
# hidden_bits . 36231923 = 0 (mod 2)
# hidden_bits . 36457129 = 0 (mod 2)
# hidden_bits . 36499351 = 0 (mod 2)
# hidden_bits . 36857020 = 0 (mod 2)
# hidden_bits . 37026959 = 0 (mod 2)
# hidden_bits . 37102623 = 0 (mod 2)
# hidden_bits . 37158431 = 0 (mod 2)
# hidden_bits . 37206579 = 0 (mod 2)
# hidden_bits . 37217193 = 0 (mod 2)
# hidden_bits . 37359540 = 0 (mod 2)
# hidden_bits . 37360190 = 0 (mod 2)
# hidden_bits . 37405027 = 0 (mod 2)
# hidden_bits . 37459561 = 0 (mod 2)
# hidden_bits . 37603200 = 0 (mod 2)
# hidden_bits . 37635310 = 0 (mod 2)
# hidden_bits . 37708309 = 0 (mod 2)
# hidden_bits . 37864940 = 0 (mod 2)
# hidden_bits . 37972175 = 0 (mod 2)
# hidden_bits . 38005556 = 0 (mod 2)
# hidden_bits . 38139894 = 0 (mod 2)
# hidden_bits . 38193415 = 0 (mod 2)
# hidden_bits . 38286338 = 0 (mod 2)
# hidden_bits . 38345117 = 0 (mod 2)
# hidden_bits . 38585426 = 0 (mod 2)
# hidden_bits . 38614031 = 0 (mod 2)
# hidden_bits . 38783923 = 0 (mod 2)
# hidden_bits . 38796651 = 0 (mod 2)
# hidden_bits . 38800722 = 0 (mod 2)
# hidden_bits . 38827138 = 0 (mod 2)
# hidden_bits . 38906153 = 0 (mod 2)
# hidden_bits . 38954642 = 0 (mod 2)
# hidden_bits . 39148368 = 0 (mod 2)
# hidden_bits . 39213564 = 0 (mod 2)
# hidden_bits . 39292075 = 0 (mod 2)
# hidden_bits . 39646388 = 0 (mod 2)
# hidden_bits . 39773371 = 0 (mod 2)
# hidden_bits . 39812537 = 0 (mod 2)
# hidden_bits . 39960675 = 0 (mod 2)
# hidden_bits . 40202155 = 0 (mod 2)
# hidden_bits . 40281332 = 0 (mod 2)
# hidden_bits . 40375495 = 0 (mod 2)
# hidden_bits . 40554158 = 0 (mod 2)
# hidden_bits . 40714022 = 0 (mod 2)
# hidden_bits . 40767960 = 0 (mod 2)
# hidden_bits . 40918830 = 0 (mod 2)
# hidden_bits . 40920525 = 0 (mod 2)
# hidden_bits . 41011152 = 0 (mod 2)
# hidden_bits . 41016981 = 0 (mod 2)
# hidden_bits . 41158493 = 0 (mod 2)
# hidden_bits . 41199751 = 0 (mod 2)
# hidden_bits . 41241385 = 0 (mod 2)
# hidden_bits . 41357371 = 0 (mod 2)
# hidden_bits . 41666620 = 0 (mod 2)
# hidden_bits . 41703411 = 0 (mod 2)
# hidden_bits . 41707648 = 0 (mod 2)
# hidden_bits . 42011152 = 0 (mod 2)
# hidden_bits . 42040500 = 0 (mod 2)
# hidden_bits . 42092176 = 0 (mod 2)
# hidden_bits . 42128088 = 0 (mod 2)
# hidden_bits . 42237043 = 0 (mod 2)
# hidden_bits . 42281674 = 0 (mod 2)
# hidden_bits . 42594867 = 0 (mod 2)
# hidden_bits . 42869023 = 0 (mod 2)
# hidden_bits . 42929843 = 0 (mod 2)
# hidden_bits . 42945451 = 0 (mod 2)
# hidden_bits . 43180352 = 0 (mod 2)
# hidden_bits . 43303496 = 0 (mod 2)
# hidden_bits . 43305626 = 0 (mod 2)
# hidden_bits . 43349458 = 0 (mod 2)
# hidden_bits . 43350557 = 0 (mod 2)
# hidden_bits . 43461128 = 0 (mod 2)
# hidden_bits . 43490335 = 0 (mod 2)
# hidden_bits . 43495247 = 0 (mod 2)
# hidden_bits . 43548579 = 0 (mod 2)
# hidden_bits . 43561351 = 0 (mod 2)
# hidden_bits . 43771869 = 0 (mod 2)
# hidden_bits . 44140006 = 0 (mod 2)
# hidden_bits . 44195516 = 0 (mod 2)
# hidden_bits . 44208600 = 0 (mod 2)
# hidden_bits . 44303782 = 0 (mod 2)
# hidden_bits . 44444359 = 0 (mod 2)
# hidden_bits . 44512389 = 0 (mod 2)
# hidden_bits . 44653576 = 0 (mod 2)
# hidden_bits . 44815668 = 0 (mod 2)
# hidden_bits . 44884749 = 0 (mod 2)
# hidden_bits . 45014326 = 0 (mod 2)
# hidden_bits . 45025721 = 0 (mod 2)
# hidden_bits . 45154092 = 0 (mod 2)
# hidden_bits . 45216719 = 0 (mod 2)
# hidden_bits . 45261919 = 0 (mod 2)
# hidden_bits . 45417560 = 0 (mod 2)
# hidden_bits . 45596943 = 0 (mod 2)
# hidden_bits . 45692723 = 0 (mod 2)
# hidden_bits . 45721986 = 0 (mod 2)
# hidden_bits . 45744814 = 0 (mod 2)
# hidden_bits . 45787502 = 0 (mod 2)
# hidden_bits . 45848264 = 0 (mod 2)
# hidden_bits . 45916063 = 0 (mod 2)
# hidden_bits . 45995299 = 0 (mod 2)
# hidden_bits . 45995326 = 0 (mod 2)
# hidden_bits . 46226921 = 0 (mod 2)
# hidden_bits . 46373845 = 0 (mod 2)
# hidden_bits . 46456024 = 0 (mod 2)
# hidden_bits . 46957711 = 0 (mod 2)
# hidden_bits . 46968246 = 0 (mod 2)
# hidden_bits . 47028329 = 0 (mod 2)
# hidden_bits . 47286884 = 0 (mod 2)
# hidden_bits . 47338915 = 0 (mod 2)
# hidden_bits . 47367019 = 0 (mod 2)
# hidden_bits . 47516142 = 0 (mod 2)
# hidden_bits . 47692160 = 0 (mod 2)
# hidden_bits . 47706033 = 0 (mod 2)
# hidden_bits . 47793093 = 0 (mod 2)
# hidden_bits . 47811669 = 0 (mod 2)
# hidden_bits . 47845698 = 0 (mod 2)
# hidden_bits . 47862700 = 0 (mod 2)
# hidden_bits . 47874212 = 0 (mod 2)
# hidden_bits . 47905741 = 0 (mod 2)
# hidden_bits . 47909756 = 0 (mod 2)
# hidden_bits . 47930816 = 0 (mod 2)
# hidden_bits . 48150095 = 0 (mod 2)
# hidden_bits . 48204482 = 0 (mod 2)
# hidden_bits . 48302295 = 0 (mod 2)
# hidden_bits . 48312773 = 0 (mod 2)
# hidden_bits . 48417493 = 0 (mod 2)
# hidden_bits . 48630218 = 0 (mod 2)
# hidden_bits . 48663038 = 0 (mod 2)
# hidden_bits . 49016415 = 0 (mod 2)
# hidden_bits . 49257800 = 0 (mod 2)
# hidden_bits . 49294374 = 0 (mod 2)
# hidden_bits . 49392305 = 0 (mod 2)
# hidden_bits . 49447796 = 0 (mod 2)
# hidden_bits . 49452524 = 0 (mod 2)
# hidden_bits . 49568919 = 0 (mod 2)
# hidden_bits . 49606332 = 0 (mod 2)
# hidden_bits . 49669082 = 0 (mod 2)
# hidden_bits . 49687301 = 0 (mod 2)
# hidden_bits . 49774535 = 0 (mod 2)
# hidden_bits . 49789504 = 0 (mod 2)
# hidden_bits . 49828058 = 0 (mod 2)
# hidden_bits . 49863931 = 0 (mod 2)
# hidden_bits . 49956306 = 0 (mod 2)
# hidden_bits . 50136456 = 0 (mod 2)
# hidden_bits . 50271189 = 0 (mod 2)
# hidden_bits . 50373494 = 0 (mod 2)
# hidden_bits . 50550774 = 0 (mod 2)
# hidden_bits . 50601864 = 0 (mod 2)
# hidden_bits . 50640847 = 0 (mod 2)
# hidden_bits . 50643750 = 0 (mod 2)
# hidden_bits . 50805589 = 0 (mod 2)
# hidden_bits . 50883797 = 0 (mod 2)
# hidden_bits . 50952517 = 0 (mod 2)
# hidden_bits . 50970982 = 0 (mod 2)
# hidden_bits . 51179313 = 0 (mod 2)
# hidden_bits . 51197343 = 0 (mod 2)
# hidden_bits . 51257432 = 0 (mod 2)
# hidden_bits . 51280274 = 0 (mod 2)
# hidden_bits . 51344620 = 0 (mod 2)
# hidden_bits . 51367907 = 0 (mod 2)
# hidden_bits . 51394609 = 0 (mod 2)
# hidden_bits . 51480188 = 0 (mod 2)
# hidden_bits . 51491699 = 0 (mod 2)
# hidden_bits . 51524096 = 0 (mod 2)
# hidden_bits . 51973878 = 0 (mod 2)
# hidden_bits . 52078140 = 0 (mod 2)
# hidden_bits . 52107717 = 0 (mod 2)
# hidden_bits . 52137268 = 0 (mod 2)
# hidden_bits . 52168548 = 0 (mod 2)
# hidden_bits . 52204229 = 0 (mod 2)
# hidden_bits . 52268554 = 0 (mod 2)
# hidden_bits . 52335851 = 0 (mod 2)
# hidden_bits . 52485737 = 0 (mod 2)
# hidden_bits . 52563973 = 0 (mod 2)
# hidden_bits . 52767682 = 0 (mod 2)
# hidden_bits . 52876312 = 0 (mod 2)
# hidden_bits . 52929928 = 0 (mod 2)
# hidden_bits . 53020201 = 0 (mod 2)
# hidden_bits . 53155814 = 0 (mod 2)
# hidden_bits . 53224727 = 0 (mod 2)
# hidden_bits . 53262103 = 0 (mod 2)
# hidden_bits . 53365694 = 0 (mod 2)
# hidden_bits . 53405061 = 0 (mod 2)
# hidden_bits . 53412707 = 0 (mod 2)
# hidden_bits . 53421696 = 0 (mod 2)
# hidden_bits . 53435617 = 0 (mod 2)
# hidden_bits . 53472725 = 0 (mod 2)
# hidden_bits . 53491328 = 0 (mod 2)
# hidden_bits . 53924232 = 0 (mod 2)
# hidden_bits . 54037125 = 0 (mod 2)
# hidden_bits . 54219310 = 0 (mod 2)
# hidden_bits . 54219330 = 0 (mod 2)
# hidden_bits . 54529946 = 0 (mod 2)
# hidden_bits . 54536205 = 0 (mod 2)
# hidden_bits . 54602560 = 0 (mod 2)
# hidden_bits . 54656758 = 0 (mod 2)
# hidden_bits . 54793554 = 0 (mod 2)
# hidden_bits . 54969290 = 0 (mod 2)
# hidden_bits . 54997447 = 0 (mod 2)
# hidden_bits . 55020078 = 0 (mod 2)
# hidden_bits . 55089800 = 0 (mod 2)
# hidden_bits . 55154525 = 0 (mod 2)
# hidden_bits . 55164652 = 0 (mod 2)
# hidden_bits . 55217031 = 0 (mod 2)
# hidden_bits . 55333878 = 0 (mod 2)
# hidden_bits . 55493153 = 0 (mod 2)
# hidden_bits . 55549645 = 0 (mod 2)
# hidden_bits . 55629952 = 0 (mod 2)
# hidden_bits . 55984605 = 0 (mod 2)
# hidden_bits . 56023908 = 0 (mod 2)
# hidden_bits . 56124771 = 0 (mod 2)
# hidden_bits . 56278040 = 0 (mod 2)
# hidden_bits . 56335168 = 0 (mod 2)
# hidden_bits . 56459149 = 0 (mod 2)
# hidden_bits . 56498005 = 0 (mod 2)
# hidden_bits . 56526193 = 0 (mod 2)
# hidden_bits . 56707556 = 0 (mod 2)
# hidden_bits . 56745298 = 0 (mod 2)
# hidden_bits . 56774630 = 0 (mod 2)
# hidden_bits . 56872187 = 0 (mod 2)
# hidden_bits . 57157456 = 0 (mod 2)
# hidden_bits . 57292267 = 0 (mod 2)
# hidden_bits . 57302305 = 0 (mod 2)
# hidden_bits . 57525663 = 0 (mod 2)
# hidden_bits . 57636306 = 0 (mod 2)
# hidden_bits . 57829135 = 0 (mod 2)
# hidden_bits . 57854249 = 0 (mod 2)
# hidden_bits . 57883474 = 0 (mod 2)
# hidden_bits . 57970217 = 0 (mod 2)
# hidden_bits . 58043933 = 0 (mod 2)
# hidden_bits . 58081311 = 0 (mod 2)
# hidden_bits . 58377370 = 0 (mod 2)
# hidden_bits . 58471675 = 0 (mod 2)
# hidden_bits . 58489577 = 0 (mod 2)
# hidden_bits . 58697797 = 0 (mod 2)
# hidden_bits . 58814674 = 0 (mod 2)
# hidden_bits . 59008064 = 0 (mod 2)
# hidden_bits . 59097746 = 0 (mod 2)
# hidden_bits . 59143888 = 0 (mod 2)
# hidden_bits . 59290383 = 0 (mod 2)
# hidden_bits . 59342641 = 0 (mod 2)
# hidden_bits . 59393132 = 0 (mod 2)
# hidden_bits . 59424064 = 0 (mod 2)
# hidden_bits . 59449175 = 0 (mod 2)
# hidden_bits . 59450399 = 0 (mod 2)
# hidden_bits . 59707451 = 0 (mod 2)
# hidden_bits . 59772137 = 0 (mod 2)
# hidden_bits . 59805347 = 0 (mod 2)
# hidden_bits . 59896044 = 0 (mod 2)
# hidden_bits . 59924493 = 0 (mod 2)
# hidden_bits . 59932634 = 0 (mod 2)
# hidden_bits . 59997926 = 0 (mod 2)
# hidden_bits . 60000441 = 0 (mod 2)
# hidden_bits . 60168458 = 0 (mod 2)
# hidden_bits . 60356529 = 0 (mod 2)
# hidden_bits . 60358149 = 0 (mod 2)
# hidden_bits . 60364716 = 0 (mod 2)
# hidden_bits . 60421822 = 0 (mod 2)
# hidden_bits . 60563124 = 0 (mod 2)
# hidden_bits . 60669656 = 0 (mod 2)
# hidden_bits . 60758324 = 0 (mod 2)
# hidden_bits . 60950538 = 0 (mod 2)
# hidden_bits . 60966116 = 0 (mod 2)
# hidden_bits . 61035136 = 0 (mod 2)
# hidden_bits . 61057615 = 0 (mod 2)
# hidden_bits . 61283085 = 0 (mod 2)
# hidden_bits . 61380168 = 0 (mod 2)
# hidden_bits . 61512397 = 0 (mod 2)
# hidden_bits . 61517243 = 0 (mod 2)
# hidden_bits . 61661727 = 0 (mod 2)
# hidden_bits . 61699472 = 0 (mod 2)
# hidden_bits . 61891973 = 0 (mod 2)
# hidden_bits . 62068643 = 0 (mod 2)
# hidden_bits . 62076693 = 0 (mod 2)
# hidden_bits . 62209772 = 0 (mod 2)
# hidden_bits . 62554309 = 0 (mod 2)
# hidden_bits . 62732780 = 0 (mod 2)
# hidden_bits . 62756871 = 0 (mod 2)
# hidden_bits . 63022123 = 0 (mod 2)
# hidden_bits . 63157668 = 0 (mod 2)
# hidden_bits . 63205438 = 0 (mod 2)
# hidden_bits . 63206610 = 0 (mod 2)
# hidden_bits . 63531466 = 0 (mod 2)
# hidden_bits . 63597791 = 0 (mod 2)
# hidden_bits . 63732120 = 0 (mod 2)
# hidden_bits . 63795899 = 0 (mod 2)
# hidden_bits . 63973436 = 0 (mod 2)
# hidden_bits . 64016115 = 0 (mod 2)
# hidden_bits . 64320904 = 0 (mod 2)
# hidden_bits . 64549755 = 0 (mod 2)
# hidden_bits . 64605358 = 0 (mod 2)
# hidden_bits . 64690880 = 0 (mod 2)
# hidden_bits . 64720711 = 0 (mod 2)
# hidden_bits . 64847265 = 0 (mod 2)
# hidden_bits . 64896205 = 0 (mod 2)
# hidden_bits . 64915558 = 0 (mod 2)
# hidden_bits . 64922166 = 0 (mod 2)
# hidden_bits . 64951524 = 0 (mod 2)
# hidden_bits . 64954498 = 0 (mod 2)
# hidden_bits . 64971269 = 0 (mod 2)
# hidden_bits . 65035750 = 0 (mod 2)
# hidden_bits . 65070588 = 0 (mod 2)
# hidden_bits . 65173066 = 0 (mod 2)
# hidden_bits . 65284286 = 0 (mod 2)
# hidden_bits . 65543818 = 0 (mod 2)
# hidden_bits . 65586556 = 0 (mod 2)
# hidden_bits . 65605725 = 0 (mod 2)
# hidden_bits . 65607063 = 0 (mod 2)
# hidden_bits . 65692217 = 0 (mod 2)
# hidden_bits . 65713073 = 0 (mod 2)
# hidden_bits . 65903212 = 0 (mod 2)
# hidden_bits . 66007821 = 0 (mod 2)
# hidden_bits . 66049818 = 0 (mod 2)
# hidden_bits . 66106723 = 0 (mod 2)
# hidden_bits . 66173834 = 0 (mod 2)
# hidden_bits . 66314041 = 0 (mod 2)
# hidden_bits . 66476813 = 0 (mod 2)
# hidden_bits . 66595305 = 0 (mod 2)
# hidden_bits . 66638421 = 0 (mod 2)
# hidden_bits . 66919457 = 0 (mod 2)
# hidden_bits . 66968318 = 0 (mod 2)
# hidden_bits . 67250081 = 0 (mod 2)
# hidden_bits . 67443594 = 0 (mod 2)
# hidden_bits . 67510343 = 0 (mod 2)
# hidden_bits . 67744007 = 0 (mod 2)
# hidden_bits . 67838999 = 0 (mod 2)
# hidden_bits . 67859853 = 0 (mod 2)
# hidden_bits . 67877727 = 0 (mod 2)
# hidden_bits . 67906603 = 0 (mod 2)
# hidden_bits . 67947357 = 0 (mod 2)
# hidden_bits . 68156357 = 0 (mod 2)
# hidden_bits . 68201237 = 0 (mod 2)
# hidden_bits . 68252298 = 0 (mod 2)
# hidden_bits . 68427681 = 0 (mod 2)
# hidden_bits . 68464238 = 0 (mod 2)
# hidden_bits . 68584492 = 0 (mod 2)
# hidden_bits . 68685968 = 0 (mod 2)
# hidden_bits . 68831239 = 0 (mod 2)
# hidden_bits . 69132877 = 0 (mod 2)
# hidden_bits . 69258333 = 0 (mod 2)
# hidden_bits . 69298161 = 0 (mod 2)
# hidden_bits . 69406142 = 0 (mod 2)
# hidden_bits . 69574866 = 0 (mod 2)
# hidden_bits . 69721823 = 0 (mod 2)
# hidden_bits . 69741471 = 0 (mod 2)
# hidden_bits . 69800806 = 0 (mod 2)
# hidden_bits . 69898665 = 0 (mod 2)
# hidden_bits . 69914440 = 0 (mod 2)
# hidden_bits . 70014021 = 0 (mod 2)
# hidden_bits . 70352228 = 0 (mod 2)
# hidden_bits . 70472512 = 0 (mod 2)
# hidden_bits . 70801482 = 0 (mod 2)
# hidden_bits . 70887690 = 0 (mod 2)
# hidden_bits . 71099287 = 0 (mod 2)
# hidden_bits . 71141734 = 0 (mod 2)
# hidden_bits . 71176875 = 0 (mod 2)
# hidden_bits . 71190331 = 0 (mod 2)
# hidden_bits . 71210077 = 0 (mod 2)
# hidden_bits . 71394875 = 0 (mod 2)
# hidden_bits . 71428707 = 0 (mod 2)
# hidden_bits . 71538818 = 0 (mod 2)
# hidden_bits . 71623676 = 0 (mod 2)
# hidden_bits . 72222664 = 0 (mod 2)
# hidden_bits . 72224676 = 0 (mod 2)
# hidden_bits . 72417982 = 0 (mod 2)
# hidden_bits . 72519678 = 0 (mod 2)
# hidden_bits . 72605919 = 0 (mod 2)
# hidden_bits . 72733208 = 0 (mod 2)
# hidden_bits . 72744611 = 0 (mod 2)
# hidden_bits . 72793039 = 0 (mod 2)
# hidden_bits . 72806190 = 0 (mod 2)
# hidden_bits . 72876615 = 0 (mod 2)
# hidden_bits . 72888663 = 0 (mod 2)
# hidden_bits . 72892485 = 0 (mod 2)
# hidden_bits . 72940331 = 0 (mod 2)
# hidden_bits . 73063972 = 0 (mod 2)
# hidden_bits . 73427223 = 0 (mod 2)
# hidden_bits . 73429389 = 0 (mod 2)
# hidden_bits . 73446621 = 0 (mod 2)
# hidden_bits . 73792556 = 0 (mod 2)
# hidden_bits . 73902098 = 0 (mod 2)
# hidden_bits . 74106509 = 0 (mod 2)
# hidden_bits . 74193047 = 0 (mod 2)
# hidden_bits . 74253361 = 0 (mod 2)
# hidden_bits . 74275024 = 0 (mod 2)
# hidden_bits . 74462104 = 0 (mod 2)
# hidden_bits . 74599092 = 0 (mod 2)
# hidden_bits . 74666181 = 0 (mod 2)
# hidden_bits . 74734651 = 0 (mod 2)
# hidden_bits . 74887637 = 0 (mod 2)
# hidden_bits . 74946542 = 0 (mod 2)
# hidden_bits . 75004329 = 0 (mod 2)
# hidden_bits . 75409057 = 0 (mod 2)
# hidden_bits . 75434509 = 0 (mod 2)
# hidden_bits . 75673595 = 0 (mod 2)
# hidden_bits . 75693762 = 0 (mod 2)
# hidden_bits . 75764504 = 0 (mod 2)
# hidden_bits . 75784663 = 0 (mod 2)
# hidden_bits . 75790024 = 0 (mod 2)
# hidden_bits . 75935239 = 0 (mod 2)
# hidden_bits . 75959895 = 0 (mod 2)
# hidden_bits . 75996201 = 0 (mod 2)
# hidden_bits . 76149052 = 0 (mod 2)
# hidden_bits . 76378304 = 0 (mod 2)
# hidden_bits . 76476065 = 0 (mod 2)
# hidden_bits . 76600839 = 0 (mod 2)
# hidden_bits . 76743523 = 0 (mod 2)
# hidden_bits . 76762342 = 0 (mod 2)
# hidden_bits . 76766546 = 0 (mod 2)
# hidden_bits . 76823384 = 0 (mod 2)
# hidden_bits . 76929916 = 0 (mod 2)
# hidden_bits . 76941701 = 0 (mod 2)
# hidden_bits . 76961735 = 0 (mod 2)
# hidden_bits . 77096407 = 0 (mod 2)
# hidden_bits . 77137538 = 0 (mod 2)
# hidden_bits . 77253803 = 0 (mod 2)
# hidden_bits . 77360858 = 0 (mod 2)
# hidden_bits . 77600883 = 0 (mod 2)
# hidden_bits . 77713048 = 0 (mod 2)
# hidden_bits . 77775245 = 0 (mod 2)
# hidden_bits . 77827464 = 0 (mod 2)
# hidden_bits . 77976472 = 0 (mod 2)
# hidden_bits . 77995372 = 0 (mod 2)
# hidden_bits . 78003605 = 0 (mod 2)
# hidden_bits . 78006666 = 0 (mod 2)
# hidden_bits . 78144942 = 0 (mod 2)
# hidden_bits . 78150185 = 0 (mod 2)
# hidden_bits . 78232328 = 0 (mod 2)
# hidden_bits . 78336661 = 0 (mod 2)
# hidden_bits . 78370247 = 0 (mod 2)
# hidden_bits . 78573840 = 0 (mod 2)
# hidden_bits . 78580440 = 0 (mod 2)
# hidden_bits . 78673032 = 0 (mod 2)
# hidden_bits . 78737764 = 0 (mod 2)
# hidden_bits . 78982223 = 0 (mod 2)
# hidden_bits . 79109628 = 0 (mod 2)
# hidden_bits . 79161326 = 0 (mod 2)
# hidden_bits . 79441825 = 0 (mod 2)
# hidden_bits . 79639117 = 0 (mod 2)
# hidden_bits . 79718039 = 0 (mod 2)
# hidden_bits . 79738596 = 0 (mod 2)
# hidden_bits . 79741747 = 0 (mod 2)
# hidden_bits . 79878897 = 0 (mod 2)
# hidden_bits . 80199603 = 0 (mod 2)
# hidden_bits . 80230485 = 0 (mod 2)
# hidden_bits . 80306300 = 0 (mod 2)
# hidden_bits . 80391676 = 0 (mod 2)
# hidden_bits . 80430577 = 0 (mod 2)
# hidden_bits . 80430590 = 0 (mod 2)
# hidden_bits . 80568049 = 0 (mod 2)
# hidden_bits . 80653458 = 0 (mod 2)
# hidden_bits . 80858893 = 0 (mod 2)
# hidden_bits . 80951590 = 0 (mod 2)
# hidden_bits . 81243997 = 0 (mod 2)
# hidden_bits . 81261876 = 0 (mod 2)
# hidden_bits . 81414618 = 0 (mod 2)
# hidden_bits . 81513090 = 0 (mod 2)
# hidden_bits . 81609543 = 0 (mod 2)
# hidden_bits . 81667691 = 0 (mod 2)
# hidden_bits . 81697260 = 0 (mod 2)
# hidden_bits . 81892521 = 0 (mod 2)
# hidden_bits . 81923243 = 0 (mod 2)
# hidden_bits . 81969275 = 0 (mod 2)
# hidden_bits . 82219357 = 0 (mod 2)
# hidden_bits . 82281240 = 0 (mod 2)
# hidden_bits . 82381978 = 0 (mod 2)
# hidden_bits . 82385635 = 0 (mod 2)
# hidden_bits . 82407222 = 0 (mod 2)
# hidden_bits . 82493427 = 0 (mod 2)
# hidden_bits . 82614883 = 0 (mod 2)
# hidden_bits . 82646244 = 0 (mod 2)
# hidden_bits . 82719880 = 0 (mod 2)
# hidden_bits . 82746122 = 0 (mod 2)
# hidden_bits . 82768636 = 0 (mod 2)
# hidden_bits . 82799962 = 0 (mod 2)
# hidden_bits . 82873403 = 0 (mod 2)
# hidden_bits . 82985290 = 0 (mod 2)
# hidden_bits . 83016517 = 0 (mod 2)
# hidden_bits . 83039368 = 0 (mod 2)
# hidden_bits . 83184571 = 0 (mod 2)
# hidden_bits . 83251324 = 0 (mod 2)
# hidden_bits . 83256343 = 0 (mod 2)
# hidden_bits . 83903275 = 0 (mod 2)
# hidden_bits . 83925236 = 0 (mod 2)
# hidden_bits . 84051873 = 0 (mod 2)
# hidden_bits . 84233874 = 0 (mod 2)
# hidden_bits . 84334607 = 0 (mod 2)
# hidden_bits . 84571807 = 0 (mod 2)
# hidden_bits . 84593150 = 0 (mod 2)
# hidden_bits . 84648177 = 0 (mod 2)
# hidden_bits . 84687523 = 0 (mod 2)
# hidden_bits . 84761708 = 0 (mod 2)
# hidden_bits . 85017123 = 0 (mod 2)
# hidden_bits . 85467794 = 0 (mod 2)
# hidden_bits . 85561593 = 0 (mod 2)
# hidden_bits . 85592044 = 0 (mod 2)
# hidden_bits . 85805414 = 0 (mod 2)
# hidden_bits . 85931728 = 0 (mod 2)
# hidden_bits . 86016747 = 0 (mod 2)
# hidden_bits . 86028816 = 0 (mod 2)
# hidden_bits . 86292759 = 0 (mod 2)
# hidden_bits . 86313259 = 0 (mod 2)
# hidden_bits . 86315840 = 0 (mod 2)
# hidden_bits . 86469246 = 0 (mod 2)
# hidden_bits . 86620987 = 0 (mod 2)
# hidden_bits . 87452890 = 0 (mod 2)
# hidden_bits . 87616157 = 0 (mod 2)
# hidden_bits . 87641700 = 0 (mod 2)
# hidden_bits . 87740101 = 0 (mod 2)
# hidden_bits . 87812690 = 0 (mod 2)
# hidden_bits . 87895009 = 0 (mod 2)
# hidden_bits . 87997049 = 0 (mod 2)
# hidden_bits . 87998643 = 0 (mod 2)
# hidden_bits . 88054808 = 0 (mod 2)
# hidden_bits . 88123515 = 0 (mod 2)
# hidden_bits . 88458403 = 0 (mod 2)
# hidden_bits . 88492631 = 0 (mod 2)
# hidden_bits . 88668053 = 0 (mod 2)
# hidden_bits . 88804846 = 0 (mod 2)
# hidden_bits . 88899886 = 0 (mod 2)
# hidden_bits . 88909998 = 0 (mod 2)
# hidden_bits . 88928510 = 0 (mod 2)
# hidden_bits . 88976855 = 0 (mod 2)
# hidden_bits . 88990830 = 0 (mod 2)
# hidden_bits . 89194959 = 0 (mod 2)
# hidden_bits . 89282548 = 0 (mod 2)
# hidden_bits . 89296180 = 0 (mod 2)
# hidden_bits . 89423431 = 0 (mod 2)
# hidden_bits . 89464706 = 0 (mod 2)
# hidden_bits . 89497313 = 0 (mod 2)
# hidden_bits . 89511137 = 0 (mod 2)
# hidden_bits . 89560683 = 0 (mod 2)
# hidden_bits . 89797540 = 0 (mod 2)
# hidden_bits . 89867110 = 0 (mod 2)
# hidden_bits . 89889365 = 0 (mod 2)
# hidden_bits . 89913415 = 0 (mod 2)
# hidden_bits . 89917236 = 0 (mod 2)
# hidden_bits . 89927002 = 0 (mod 2)
# hidden_bits . 90044122 = 0 (mod 2)
# hidden_bits . 90285948 = 0 (mod 2)
# hidden_bits . 90320719 = 0 (mod 2)
# hidden_bits . 90419182 = 0 (mod 2)
# hidden_bits . 90786066 = 0 (mod 2)
# hidden_bits . 91012411 = 0 (mod 2)
# hidden_bits . 91263484 = 0 (mod 2)
# hidden_bits . 91434242 = 0 (mod 2)
# hidden_bits . 91612915 = 0 (mod 2)
# hidden_bits . 91644946 = 0 (mod 2)
# hidden_bits . 92015091 = 0 (mod 2)
# hidden_bits . 92140022 = 0 (mod 2)
# hidden_bits . 92216023 = 0 (mod 2)
# hidden_bits . 92228127 = 0 (mod 2)
# hidden_bits . 92242333 = 0 (mod 2)
# hidden_bits . 92249193 = 0 (mod 2)
# hidden_bits . 92255147 = 0 (mod 2)
# hidden_bits . 92274240 = 0 (mod 2)
# hidden_bits . 92333732 = 0 (mod 2)
# hidden_bits . 92356565 = 0 (mod 2)
# hidden_bits . 92451602 = 0 (mod 2)
# hidden_bits . 92460598 = 0 (mod 2)
# hidden_bits . 92645356 = 0 (mod 2)
# hidden_bits . 92728328 = 0 (mod 2)
# hidden_bits . 92894121 = 0 (mod 2)
# hidden_bits . 92941208 = 0 (mod 2)
# hidden_bits . 93134769 = 0 (mod 2)
# hidden_bits . 93173433 = 0 (mod 2)
# hidden_bits . 93190213 = 0 (mod 2)
# hidden_bits . 93353496 = 0 (mod 2)
# hidden_bits . 93543173 = 0 (mod 2)
# hidden_bits . 93679662 = 0 (mod 2)
# hidden_bits . 93698916 = 0 (mod 2)
# hidden_bits . 93784144 = 0 (mod 2)
# hidden_bits . 93807562 = 0 (mod 2)
# hidden_bits . 94255765 = 0 (mod 2)
# hidden_bits . 94277553 = 0 (mod 2)
# hidden_bits . 94692265 = 0 (mod 2)
# hidden_bits . 94713907 = 0 (mod 2)
# hidden_bits . 94756257 = 0 (mod 2)
# hidden_bits . 95190418 = 0 (mod 2)
# hidden_bits . 95238999 = 0 (mod 2)
# hidden_bits . 95411635 = 0 (mod 2)
# hidden_bits . 95575985 = 0 (mod 2)
# hidden_bits . 95733820 = 0 (mod 2)
# hidden_bits . 95903170 = 0 (mod 2)
# hidden_bits . 95908476 = 0 (mod 2)
# hidden_bits . 96026915 = 0 (mod 2)
# hidden_bits . 96039969 = 0 (mod 2)
# hidden_bits . 96163855 = 0 (mod 2)
# hidden_bits . 96187981 = 0 (mod 2)
# hidden_bits . 96609966 = 0 (mod 2)
# hidden_bits . 96803574 = 0 (mod 2)
# hidden_bits . 96848210 = 0 (mod 2)
# hidden_bits . 97129669 = 0 (mod 2)
# hidden_bits . 97232382 = 0 (mod 2)
# hidden_bits . 97350001 = 0 (mod 2)
# hidden_bits . 97377309 = 0 (mod 2)
# hidden_bits . 97466411 = 0 (mod 2)
# hidden_bits . 97548677 = 0 (mod 2)
# hidden_bits . 97631014 = 0 (mod 2)
# hidden_bits . 97645753 = 0 (mod 2)
# hidden_bits . 97785972 = 0 (mod 2)
# hidden_bits . 97817431 = 0 (mod 2)
# hidden_bits . 97874586 = 0 (mod 2)
# hidden_bits . 97938985 = 0 (mod 2)
# hidden_bits . 97974725 = 0 (mod 2)
# hidden_bits . 97996373 = 0 (mod 2)
# hidden_bits . 98233387 = 0 (mod 2)
# hidden_bits . 98259906 = 0 (mod 2)
# hidden_bits . 98307886 = 0 (mod 2)
# hidden_bits . 98348573 = 0 (mod 2)
# hidden_bits . 98433743 = 0 (mod 2)
# hidden_bits . 98474172 = 0 (mod 2)
# hidden_bits . 98529311 = 0 (mod 2)
# hidden_bits . 99226276 = 0 (mod 2)
# hidden_bits . 99358349 = 0 (mod 2)
# hidden_bits . 99382431 = 0 (mod 2)
# hidden_bits . 99422218 = 0 (mod 2)
# hidden_bits . 99544208 = 0 (mod 2)
# hidden_bits . 99565670 = 0 (mod 2)
# hidden_bits . 99650386 = 0 (mod 2)
# hidden_bits . 99699574 = 0 (mod 2)
# hidden_bits . 99722350 = 0 (mod 2)
# hidden_bits . 99731948 = 0 (mod 2)
# hidden_bits . 99738768 = 0 (mod 2)
# hidden_bits . 99846499 = 0 (mod 2)
# hidden_bits . 99962442 = 0 (mod 2)
# hidden_bits . 100031923 = 0 (mod 2)
# hidden_bits . 100174651 = 0 (mod 2)
# hidden_bits . 100238087 = 0 (mod 2)
# hidden_bits . 100601974 = 0 (mod 2)
# hidden_bits . 100820485 = 0 (mod 2)
# hidden_bits . 100949876 = 0 (mod 2)
# hidden_bits . 101062715 = 0 (mod 2)
# hidden_bits . 101100854 = 0 (mod 2)
# hidden_bits . 101118407 = 0 (mod 2)
# hidden_bits . 101184415 = 0 (mod 2)
# hidden_bits . 101377613 = 0 (mod 2)
# hidden_bits . 101444888 = 0 (mod 2)
# hidden_bits . 101543125 = 0 (mod 2)
# hidden_bits . 101658005 = 0 (mod 2)
# hidden_bits . 101734513 = 0 (mod 2)
# hidden_bits . 101750702 = 0 (mod 2)
# hidden_bits . 101864811 = 0 (mod 2)
# hidden_bits . 102007370 = 0 (mod 2)
# hidden_bits . 102068959 = 0 (mod 2)
# hidden_bits . 102074752 = 0 (mod 2)
# hidden_bits . 102109803 = 0 (mod 2)
# hidden_bits . 102138589 = 0 (mod 2)
# hidden_bits . 102169198 = 0 (mod 2)
# hidden_bits . 102333831 = 0 (mod 2)
# hidden_bits . 102344538 = 0 (mod 2)
# hidden_bits . 102426091 = 0 (mod 2)
# hidden_bits . 102521214 = 0 (mod 2)
# hidden_bits . 102522527 = 0 (mod 2)
# hidden_bits . 102523937 = 0 (mod 2)
# hidden_bits . 103029655 = 0 (mod 2)
# hidden_bits . 103109394 = 0 (mod 2)
# hidden_bits . 103136474 = 0 (mod 2)
# hidden_bits . 103452040 = 0 (mod 2)
# hidden_bits . 103502249 = 0 (mod 2)
# hidden_bits . 103556907 = 0 (mod 2)
# hidden_bits . 103566204 = 0 (mod 2)
# hidden_bits . 103673560 = 0 (mod 2)
# hidden_bits . 103688756 = 0 (mod 2)
# hidden_bits . 103874286 = 0 (mod 2)
# hidden_bits . 103897119 = 0 (mod 2)
# hidden_bits . 103929022 = 0 (mod 2)
# hidden_bits . 103997959 = 0 (mod 2)
# hidden_bits . 103999109 = 0 (mod 2)
# hidden_bits . 104060020 = 0 (mod 2)
# hidden_bits . 104137498 = 0 (mod 2)
# hidden_bits . 104426795 = 0 (mod 2)
# hidden_bits . 104465851 = 0 (mod 2)
# hidden_bits . 104683783 = 0 (mod 2)
# hidden_bits . 104704998 = 0 (mod 2)
# hidden_bits . 104738581 = 0 (mod 2)
# hidden_bits . 104741548 = 0 (mod 2)
# hidden_bits . 104859510 = 0 (mod 2)
# hidden_bits . 105260687 = 0 (mod 2)
# hidden_bits . 105266548 = 0 (mod 2)
# hidden_bits . 105501255 = 0 (mod 2)
# hidden_bits . 105538923 = 0 (mod 2)
# hidden_bits . 105618397 = 0 (mod 2)
# hidden_bits . 105650609 = 0 (mod 2)
# hidden_bits . 105756003 = 0 (mod 2)
# hidden_bits . 105797049 = 0 (mod 2)
# hidden_bits . 105851138 = 0 (mod 2)
# hidden_bits . 105917094 = 0 (mod 2)
# hidden_bits . 105924220 = 0 (mod 2)
# hidden_bits . 105954973 = 0 (mod 2)
# hidden_bits . 106148373 = 0 (mod 2)
# hidden_bits . 106472681 = 0 (mod 2)
# hidden_bits . 106530238 = 0 (mod 2)
# hidden_bits . 106689693 = 0 (mod 2)
# hidden_bits . 106698412 = 0 (mod 2)
# hidden_bits . 106832456 = 0 (mod 2)
# hidden_bits . 106847918 = 0 (mod 2)
# hidden_bits . 107220393 = 0 (mod 2)
# hidden_bits . 107319943 = 0 (mod 2)
# hidden_bits . 107632124 = 0 (mod 2)
# hidden_bits . 107638718 = 0 (mod 2)
# hidden_bits . 108118866 = 0 (mod 2)
# hidden_bits . 108140810 = 0 (mod 2)
# hidden_bits . 108181742 = 0 (mod 2)
# hidden_bits . 108241045 = 0 (mod 2)
# hidden_bits . 108243302 = 0 (mod 2)
# hidden_bits . 108259141 = 0 (mod 2)
# hidden_bits . 108261473 = 0 (mod 2)
# hidden_bits . 108624856 = 0 (mod 2)
# hidden_bits . 108649989 = 0 (mod 2)
# hidden_bits . 108802002 = 0 (mod 2)
# hidden_bits . 108947904 = 0 (mod 2)
# hidden_bits . 109098378 = 0 (mod 2)
# hidden_bits . 109134687 = 0 (mod 2)
# hidden_bits . 109218558 = 0 (mod 2)
# hidden_bits . 109243272 = 0 (mod 2)
# hidden_bits . 109323635 = 0 (mod 2)
# hidden_bits . 109454497 = 0 (mod 2)
# hidden_bits . 109495409 = 0 (mod 2)
# hidden_bits . 109526001 = 0 (mod 2)
# hidden_bits . 109659392 = 0 (mod 2)
# hidden_bits . 109737780 = 0 (mod 2)
# hidden_bits . 109823325 = 0 (mod 2)
# hidden_bits . 109964831 = 0 (mod 2)
# hidden_bits . 110015675 = 0 (mod 2)
# hidden_bits . 110031075 = 0 (mod 2)
# hidden_bits . 110084859 = 0 (mod 2)
# hidden_bits . 110452352 = 0 (mod 2)
# hidden_bits . 110466634 = 0 (mod 2)
# hidden_bits . 110482527 = 0 (mod 2)
# hidden_bits . 110630677 = 0 (mod 2)
# hidden_bits . 110794337 = 0 (mod 2)
# hidden_bits . 110864254 = 0 (mod 2)
# hidden_bits . 110895156 = 0 (mod 2)
# hidden_bits . 110954731 = 0 (mod 2)
# hidden_bits . 111168182 = 0 (mod 2)
# hidden_bits . 111194676 = 0 (mod 2)
# hidden_bits . 111229420 = 0 (mod 2)
# hidden_bits . 111364874 = 0 (mod 2)
# hidden_bits . 111493597 = 0 (mod 2)
# hidden_bits . 111657858 = 0 (mod 2)
# hidden_bits . 111673991 = 0 (mod 2)
# hidden_bits . 111904016 = 0 (mod 2)
# hidden_bits . 111945393 = 0 (mod 2)
# hidden_bits . 112205942 = 0 (mod 2)
# hidden_bits . 112208527 = 0 (mod 2)
# hidden_bits . 112222905 = 0 (mod 2)
# hidden_bits . 112322333 = 0 (mod 2)
# hidden_bits . 112357399 = 0 (mod 2)
# hidden_bits . 112559711 = 0 (mod 2)
# hidden_bits . 112672594 = 0 (mod 2)
# hidden_bits . 112837099 = 0 (mod 2)
# hidden_bits . 113039163 = 0 (mod 2)
# hidden_bits . 113581341 = 0 (mod 2)
# hidden_bits . 113581381 = 0 (mod 2)
# hidden_bits . 113638338 = 0 (mod 2)
# hidden_bits . 113655432 = 0 (mod 2)
# hidden_bits . 113727232 = 0 (mod 2)
# hidden_bits . 113751422 = 0 (mod 2)
# hidden_bits . 113762235 = 0 (mod 2)
# hidden_bits . 113765054 = 0 (mod 2)
# hidden_bits . 114042227 = 0 (mod 2)
# hidden_bits . 114072300 = 0 (mod 2)
# hidden_bits . 114104007 = 0 (mod 2)
# hidden_bits . 114135211 = 0 (mod 2)
# hidden_bits . 114388872 = 0 (mod 2)
# hidden_bits . 114461197 = 0 (mod 2)
# hidden_bits . 114477044 = 0 (mod 2)
# hidden_bits . 114541868 = 0 (mod 2)
# hidden_bits . 114662272 = 0 (mod 2)
# hidden_bits . 114803328 = 0 (mod 2)
# hidden_bits . 114926023 = 0 (mod 2)
# hidden_bits . 114932055 = 0 (mod 2)
# hidden_bits . 114939845 = 0 (mod 2)
# hidden_bits . 114985324 = 0 (mod 2)
# hidden_bits . 115004112 = 0 (mod 2)
# hidden_bits . 115115430 = 0 (mod 2)
# hidden_bits . 115216210 = 0 (mod 2)
# hidden_bits . 115245655 = 0 (mod 2)
# hidden_bits . 115364674 = 0 (mod 2)
# hidden_bits . 115413182 = 0 (mod 2)
# hidden_bits . 115488664 = 0 (mod 2)
# hidden_bits . 115699254 = 0 (mod 2)
# hidden_bits . 115750323 = 0 (mod 2)
# hidden_bits . 115834601 = 0 (mod 2)
# hidden_bits . 116160474 = 0 (mod 2)
# hidden_bits . 116270457 = 0 (mod 2)
# hidden_bits . 116343788 = 0 (mod 2)
# hidden_bits . 116375767 = 0 (mod 2)
# hidden_bits . 116385357 = 0 (mod 2)
# hidden_bits . 116519268 = 0 (mod 2)
# hidden_bits . 116532375 = 0 (mod 2)
# hidden_bits . 116569045 = 0 (mod 2)
# hidden_bits . 116589988 = 0 (mod 2)
# hidden_bits . 116729915 = 0 (mod 2)
# hidden_bits . 116825687 = 0 (mod 2)
# hidden_bits . 116871099 = 0 (mod 2)
# hidden_bits . 117134471 = 0 (mod 2)
# hidden_bits . 117237025 = 0 (mod 2)
# hidden_bits . 117333205 = 0 (mod 2)
# hidden_bits . 117586481 = 0 (mod 2)
# hidden_bits . 117730754 = 0 (mod 2)
# hidden_bits . 117751916 = 0 (mod 2)
# hidden_bits . 117795492 = 0 (mod 2)
# hidden_bits . 117889315 = 0 (mod 2)
# hidden_bits . 117905902 = 0 (mod 2)
# hidden_bits . 118106573 = 0 (mod 2)
# hidden_bits . 118335184 = 0 (mod 2)
# hidden_bits . 118452319 = 0 (mod 2)
# hidden_bits . 118467413 = 0 (mod 2)
# hidden_bits . 118563252 = 0 (mod 2)
# hidden_bits . 118579287 = 0 (mod 2)
# hidden_bits . 118605277 = 0 (mod 2)
# hidden_bits . 118670223 = 0 (mod 2)
# hidden_bits . 118688530 = 0 (mod 2)
# hidden_bits . 118800197 = 0 (mod 2)
# hidden_bits . 118830820 = 0 (mod 2)
# hidden_bits . 118830983 = 0 (mod 2)
# hidden_bits . 118891172 = 0 (mod 2)
# hidden_bits . 119105390 = 0 (mod 2)
# hidden_bits . 119164334 = 0 (mod 2)
# hidden_bits . 119185073 = 0 (mod 2)
# hidden_bits . 119230630 = 0 (mod 2)
# hidden_bits . 119300104 = 0 (mod 2)
# hidden_bits . 119358563 = 0 (mod 2)
# hidden_bits . 119441444 = 0 (mod 2)
# hidden_bits . 119625955 = 0 (mod 2)
# hidden_bits . 120012987 = 0 (mod 2)
# hidden_bits . 120039311 = 0 (mod 2)
# hidden_bits . 120058893 = 0 (mod 2)
# hidden_bits . 120153078 = 0 (mod 2)
# hidden_bits . 120223867 = 0 (mod 2)
# hidden_bits . 120493742 = 0 (mod 2)
# hidden_bits . 120573348 = 0 (mod 2)
# hidden_bits . 120688100 = 0 (mod 2)
# hidden_bits . 120885409 = 0 (mod 2)
# hidden_bits . 120888128 = 0 (mod 2)
# hidden_bits . 121176876 = 0 (mod 2)
# hidden_bits . 121467262 = 0 (mod 2)
# hidden_bits . 121487391 = 0 (mod 2)
# hidden_bits . 121572997 = 0 (mod 2)
# hidden_bits . 121606810 = 0 (mod 2)
# hidden_bits . 121625544 = 0 (mod 2)
# hidden_bits . 121766039 = 0 (mod 2)
# hidden_bits . 121793368 = 0 (mod 2)
# hidden_bits . 122033231 = 0 (mod 2)
# hidden_bits . 122097677 = 0 (mod 2)
# hidden_bits . 122111718 = 0 (mod 2)
# hidden_bits . 122124039 = 0 (mod 2)
# hidden_bits . 122244649 = 0 (mod 2)
# hidden_bits . 122337918 = 0 (mod 2)
# hidden_bits . 122469931 = 0 (mod 2)
# hidden_bits . 122526741 = 0 (mod 2)
# hidden_bits . 122647793 = 0 (mod 2)
# hidden_bits . 122856261 = 0 (mod 2)
# hidden_bits . 122879166 = 0 (mod 2)
# hidden_bits . 123040891 = 0 (mod 2)
# hidden_bits . 123088384 = 0 (mod 2)
# hidden_bits . 123147774 = 0 (mod 2)
# hidden_bits . 123165556 = 0 (mod 2)
# hidden_bits . 123169398 = 0 (mod 2)
# hidden_bits . 123188073 = 0 (mod 2)
# hidden_bits . 123225682 = 0 (mod 2)
# hidden_bits . 123294889 = 0 (mod 2)
# hidden_bits . 123352753 = 0 (mod 2)
# hidden_bits . 123353040 = 0 (mod 2)
# hidden_bits . 123484214 = 0 (mod 2)
# hidden_bits . 123787845 = 0 (mod 2)
# hidden_bits . 123853824 = 0 (mod 2)
# hidden_bits . 123879012 = 0 (mod 2)
# hidden_bits . 124136230 = 0 (mod 2)
# hidden_bits . 124183526 = 0 (mod 2)
# hidden_bits . 124321958 = 0 (mod 2)
# hidden_bits . 124323497 = 0 (mod 2)
# hidden_bits . 124356255 = 0 (mod 2)
# hidden_bits . 124420065 = 0 (mod 2)
# hidden_bits . 124746199 = 0 (mod 2)
# hidden_bits . 124814564 = 0 (mod 2)
# hidden_bits . 124982728 = 0 (mod 2)
# hidden_bits . 125055567 = 0 (mod 2)
# hidden_bits . 125079823 = 0 (mod 2)
# hidden_bits . 125122511 = 0 (mod 2)
# hidden_bits . 125215320 = 0 (mod 2)
# hidden_bits . 125267699 = 0 (mod 2)
# hidden_bits . 125320775 = 0 (mod 2)
# hidden_bits . 125539124 = 0 (mod 2)
# hidden_bits . 125593805 = 0 (mod 2)
# hidden_bits . 125807181 = 0 (mod 2)
# hidden_bits . 126074138 = 0 (mod 2)
# hidden_bits . 126141033 = 0 (mod 2)
# hidden_bits . 126213194 = 0 (mod 2)
# hidden_bits . 126399201 = 0 (mod 2)
# hidden_bits . 126881607 = 0 (mod 2)
# hidden_bits . 127067819 = 0 (mod 2)
# hidden_bits . 127071325 = 0 (mod 2)
# hidden_bits . 127100173 = 0 (mod 2)
# hidden_bits . 127178027 = 0 (mod 2)
# hidden_bits . 127180631 = 0 (mod 2)
# hidden_bits . 127307444 = 0 (mod 2)
# hidden_bits . 127660039 = 0 (mod 2)
# hidden_bits . 127758928 = 0 (mod 2)
# hidden_bits . 127884877 = 0 (mod 2)
# hidden_bits . 127912855 = 0 (mod 2)
# hidden_bits . 127930903 = 0 (mod 2)
# hidden_bits . 128007583 = 0 (mod 2)
# hidden_bits . 128367197 = 0 (mod 2)
# hidden_bits . 128473126 = 0 (mod 2)
# hidden_bits . 128474911 = 0 (mod 2)
# hidden_bits . 128557400 = 0 (mod 2)
# hidden_bits . 128612122 = 0 (mod 2)
# hidden_bits . 128723382 = 0 (mod 2)
# hidden_bits . 128754391 = 0 (mod 2)
# hidden_bits . 128870400 = 0 (mod 2)
# hidden_bits . 128922982 = 0 (mod 2)
# hidden_bits . 129129059 = 0 (mod 2)
# hidden_bits . 129159148 = 0 (mod 2)
# hidden_bits . 129407158 = 0 (mod 2)
# hidden_bits . 129685694 = 0 (mod 2)
# hidden_bits . 129700549 = 0 (mod 2)
# hidden_bits . 129755221 = 0 (mod 2)
# hidden_bits . 129791386 = 0 (mod 2)
# hidden_bits . 129912820 = 0 (mod 2)
# hidden_bits . 129920983 = 0 (mod 2)
# hidden_bits . 130042703 = 0 (mod 2)
# hidden_bits . 130117097 = 0 (mod 2)
# hidden_bits . 130183437 = 0 (mod 2)
# hidden_bits . 130365180 = 0 (mod 2)
# hidden_bits . 130378586 = 0 (mod 2)
# hidden_bits . 130685820 = 0 (mod 2)
# hidden_bits . 130718479 = 0 (mod 2)
# hidden_bits . 130723198 = 0 (mod 2)
# hidden_bits . 130734285 = 0 (mod 2)
# hidden_bits . 130797990 = 0 (mod 2)
# hidden_bits . 130829151 = 0 (mod 2)
# hidden_bits . 131286552 = 0 (mod 2)
# hidden_bits . 131503150 = 0 (mod 2)
# hidden_bits . 131532276 = 0 (mod 2)
# hidden_bits . 131643371 = 0 (mod 2)
# hidden_bits . 131688419 = 0 (mod 2)
# hidden_bits . 131713549 = 0 (mod 2)
# hidden_bits . 131753608 = 0 (mod 2)
# hidden_bits . 131781115 = 0 (mod 2)
# hidden_bits . 131796736 = 0 (mod 2)
# hidden_bits . 131888953 = 0 (mod 2)
# hidden_bits . 131934930 = 0 (mod 2)
# hidden_bits . 132000522 = 0 (mod 2)
# hidden_bits . 132059900 = 0 (mod 2)
# hidden_bits . 132150613 = 0 (mod 2)
# hidden_bits . 132168446 = 0 (mod 2)
# hidden_bits . 132223265 = 0 (mod 2)
# hidden_bits . 132451215 = 0 (mod 2)
# hidden_bits . 132756293 = 0 (mod 2)
# hidden_bits . 132966374 = 0 (mod 2)
# hidden_bits . 133064320 = 0 (mod 2)
# hidden_bits . 133127651 = 0 (mod 2)
# hidden_bits . 133148882 = 0 (mod 2)
# hidden_bits . 133171986 = 0 (mod 2)
# hidden_bits . 133181803 = 0 (mod 2)
# hidden_bits . 133242010 = 0 (mod 2)
# hidden_bits . 133490762 = 0 (mod 2)
# hidden_bits . 133688789 = 0 (mod 2)
# hidden_bits . 133748339 = 0 (mod 2)
# hidden_bits . 133855623 = 0 (mod 2)
# hidden_bits . 133910103 = 0 (mod 2)
# hidden_bits . 133922721 = 0 (mod 2)
# hidden_bits . 134032541 = 0 (mod 2)
# hidden_bits . 134199298 = 0 (mod 2)
# hidden_bits . 134264901 = 0 (mod 2)
# hidden_bits . 134316131 = 0 (mod 2)
# hidden_bits . 134538481 = 0 (mod 2)
# hidden_bits . 134600993 = 0 (mod 2)
# hidden_bits . 134657157 = 0 (mod 2)
# hidden_bits . 134660913 = 0 (mod 2)
# hidden_bits . 134718244 = 0 (mod 2)
# hidden_bits . 134723958 = 0 (mod 2)
# hidden_bits . 134863932 = 0 (mod 2)
# hidden_bits . 134940506 = 0 (mod 2)
# hidden_bits . 134989494 = 0 (mod 2)
# hidden_bits . 134991345 = 0 (mod 2)
# hidden_bits . 135123372 = 0 (mod 2)
# hidden_bits . 135226094 = 0 (mod 2)
# hidden_bits . 135299625 = 0 (mod 2)
# hidden_bits . 135355966 = 0 (mod 2)
# hidden_bits . 135412381 = 0 (mod 2)
# hidden_bits . 135480638 = 0 (mod 2)
# hidden_bits . 135498823 = 0 (mod 2)
# hidden_bits . 135610419 = 0 (mod 2)
# hidden_bits . 136265318 = 0 (mod 2)
# hidden_bits . 136310014 = 0 (mod 2)
# hidden_bits . 136363735 = 0 (mod 2)
# hidden_bits . 136497434 = 0 (mod 2)
# hidden_bits . 136540979 = 0 (mod 2)
# hidden_bits . 136554703 = 0 (mod 2)
# hidden_bits . 136625045 = 0 (mod 2)
# hidden_bits . 136638694 = 0 (mod 2)
# hidden_bits . 136638994 = 0 (mod 2)
# hidden_bits . 136749990 = 0 (mod 2)
# hidden_bits . 136760919 = 0 (mod 2)
# hidden_bits . 136886410 = 0 (mod 2)
# hidden_bits . 136949753 = 0 (mod 2)
# hidden_bits . 136967639 = 0 (mod 2)
# hidden_bits . 136974308 = 0 (mod 2)
# hidden_bits . 137145595 = 0 (mod 2)
# hidden_bits . 137288238 = 0 (mod 2)
# hidden_bits . 137381146 = 0 (mod 2)
# hidden_bits . 137484938 = 0 (mod 2)
# hidden_bits . 137502774 = 0 (mod 2)
# hidden_bits . 137725030 = 0 (mod 2)
# hidden_bits . 138043285 = 0 (mod 2)
# hidden_bits . 138152650 = 0 (mod 2)
# hidden_bits . 138213881 = 0 (mod 2)
# hidden_bits . 138314217 = 0 (mod 2)
# ...
# hidden_bits . 1029743851 = 0 (mod 2)
# hidden_bits . 1029943539 = 0 (mod 2)
# hidden_bits . 1029995454 = 0 (mod 2)
# hidden_bits . 1030018706 = 0 (mod 2)
# hidden_bits . 1030088369 = 0 (mod 2)
# hidden_bits . 1030184152 = 0 (mod 2)
# hidden_bits . 1030245873 = 0 (mod 2)
# hidden_bits . 1030361902 = 0 (mod 2)
# hidden_bits . 1030369340 = 0 (mod 2)
# hidden_bits . 1030515085 = 0 (mod 2)
# hidden_bits . 1030688371 = 0 (mod 2)
# hidden_bits . 1030779065 = 0 (mod 2)
# hidden_bits . 1030836393 = 0 (mod 2)
# hidden_bits . 1030863055 = 0 (mod 2)
# hidden_bits . 1030896661 = 0 (mod 2)
# hidden_bits . 1030928548 = 0 (mod 2)
# hidden_bits . 1031096581 = 0 (mod 2)
# hidden_bits . 1031274632 = 0 (mod 2)
# hidden_bits . 1031326218 = 0 (mod 2)
# hidden_bits . 1031392182 = 0 (mod 2)
# hidden_bits . 1031458934 = 0 (mod 2)
# hidden_bits . 1031573353 = 0 (mod 2)
# hidden_bits . 1031595454 = 0 (mod 2)
# hidden_bits . 1031652693 = 0 (mod 2)
# hidden_bits . 1031685021 = 0 (mod 2)
# hidden_bits . 1031736382 = 0 (mod 2)
# hidden_bits . 1031823501 = 0 (mod 2)
# hidden_bits . 1031847453 = 0 (mod 2)
# hidden_bits . 1031995622 = 0 (mod 2)
# hidden_bits . 1032019970 = 0 (mod 2)
# hidden_bits . 1032047731 = 0 (mod 2)
# hidden_bits . 1032418767 = 0 (mod 2)
# hidden_bits . 1032520463 = 0 (mod 2)
# hidden_bits . 1032525704 = 0 (mod 2)
# hidden_bits . 1032559304 = 0 (mod 2)
# hidden_bits . 1032733016 = 0 (mod 2)
# hidden_bits . 1032849751 = 0 (mod 2)
# hidden_bits . 1032864151 = 0 (mod 2)
# hidden_bits . 1032964030 = 0 (mod 2)
# hidden_bits . 1033516637 = 0 (mod 2)
# hidden_bits . 1033533640 = 0 (mod 2)
# hidden_bits . 1033605064 = 0 (mod 2)
# hidden_bits . 1033700644 = 0 (mod 2)
# hidden_bits . 1033753713 = 0 (mod 2)
# hidden_bits . 1033832080 = 0 (mod 2)
# hidden_bits . 1033868334 = 0 (mod 2)
# hidden_bits . 1033991319 = 0 (mod 2)
# hidden_bits . 1034051471 = 0 (mod 2)
# hidden_bits . 1034135381 = 0 (mod 2)
# hidden_bits . 1034139221 = 0 (mod 2)
# hidden_bits . 1034413698 = 0 (mod 2)
# hidden_bits . 1034509402 = 0 (mod 2)
# hidden_bits . 1034509509 = 0 (mod 2)
# hidden_bits . 1034577752 = 0 (mod 2)
# hidden_bits . 1034651485 = 0 (mod 2)
# hidden_bits . 1034888804 = 0 (mod 2)
# hidden_bits . 1034962768 = 0 (mod 2)
# hidden_bits . 1035024783 = 0 (mod 2)
# hidden_bits . 1035158641 = 0 (mod 2)
# hidden_bits . 1035163527 = 0 (mod 2)
# hidden_bits . 1035298169 = 0 (mod 2)
# hidden_bits . 1035454986 = 0 (mod 2)
# hidden_bits . 1035527047 = 0 (mod 2)
# hidden_bits . 1035541000 = 0 (mod 2)
# hidden_bits . 1035931402 = 0 (mod 2)
# hidden_bits . 1036292409 = 0 (mod 2)
# hidden_bits . 1036500760 = 0 (mod 2)
# hidden_bits . 1036558139 = 0 (mod 2)
# hidden_bits . 1036704781 = 0 (mod 2)
# hidden_bits . 1036784005 = 0 (mod 2)
# hidden_bits . 1036972907 = 0 (mod 2)
# hidden_bits . 1037076375 = 0 (mod 2)
# hidden_bits . 1037108406 = 0 (mod 2)
# hidden_bits . 1037142741 = 0 (mod 2)
# hidden_bits . 1037222561 = 0 (mod 2)
# hidden_bits . 1037416912 = 0 (mod 2)
# hidden_bits . 1037493386 = 0 (mod 2)
# hidden_bits . 1037594470 = 0 (mod 2)
# hidden_bits . 1037615291 = 0 (mod 2)
# hidden_bits . 1037699861 = 0 (mod 2)
# hidden_bits . 1037891897 = 0 (mod 2)
# hidden_bits . 1037980073 = 0 (mod 2)
# hidden_bits . 1037987842 = 0 (mod 2)
# hidden_bits . 1037993567 = 0 (mod 2)
# hidden_bits . 1038024346 = 0 (mod 2)
# hidden_bits . 1038042007 = 0 (mod 2)
# hidden_bits . 1038096898 = 0 (mod 2)
# hidden_bits . 1038165305 = 0 (mod 2)
# hidden_bits . 1038232538 = 0 (mod 2)
# hidden_bits . 1038256408 = 0 (mod 2)
# hidden_bits . 1038460897 = 0 (mod 2)
# hidden_bits . 1038468498 = 0 (mod 2)
# hidden_bits . 1038626376 = 0 (mod 2)
# hidden_bits . 1038636019 = 0 (mod 2)
# hidden_bits . 1038658320 = 0 (mod 2)
# hidden_bits . 1038892273 = 0 (mod 2)
# hidden_bits . 1038916531 = 0 (mod 2)
# hidden_bits . 1038963900 = 0 (mod 2)
# hidden_bits . 1039228734 = 0 (mod 2)
# hidden_bits . 1039263011 = 0 (mod 2)
# hidden_bits . 1039502193 = 0 (mod 2)
# hidden_bits . 1039570312 = 0 (mod 2)
# hidden_bits . 1039578428 = 0 (mod 2)
# hidden_bits . 1039629637 = 0 (mod 2)
# hidden_bits . 1039708687 = 0 (mod 2)
# hidden_bits . 1039823821 = 0 (mod 2)
# hidden_bits . 1039902323 = 0 (mod 2)
# hidden_bits . 1040041588 = 0 (mod 2)
# hidden_bits . 1040042186 = 0 (mod 2)
# hidden_bits . 1040149692 = 0 (mod 2)
# hidden_bits . 1040190482 = 0 (mod 2)
# hidden_bits . 1040236521 = 0 (mod 2)
# hidden_bits . 1040506361 = 0 (mod 2)
# hidden_bits . 1040575890 = 0 (mod 2)
# hidden_bits . 1040598661 = 0 (mod 2)
# hidden_bits . 1040712942 = 0 (mod 2)
# hidden_bits . 1040969076 = 0 (mod 2)
# hidden_bits . 1041296955 = 0 (mod 2)
# hidden_bits . 1041327253 = 0 (mod 2)
# hidden_bits . 1041348732 = 0 (mod 2)
# hidden_bits . 1041455751 = 0 (mod 2)
# hidden_bits . 1041683947 = 0 (mod 2)
# hidden_bits . 1041694336 = 0 (mod 2)
# hidden_bits . 1042018186 = 0 (mod 2)
# hidden_bits . 1042089943 = 0 (mod 2)
# hidden_bits . 1042158282 = 0 (mod 2)
# hidden_bits . 1042229130 = 0 (mod 2)
# hidden_bits . 1042242662 = 0 (mod 2)
# hidden_bits . 1042288318 = 0 (mod 2)
# hidden_bits . 1042310635 = 0 (mod 2)
# hidden_bits . 1042457042 = 0 (mod 2)
# hidden_bits . 1042524504 = 0 (mod 2)
# hidden_bits . 1042526599 = 0 (mod 2)
# hidden_bits . 1042546081 = 0 (mod 2)
# hidden_bits . 1042628439 = 0 (mod 2)
# hidden_bits . 1042647000 = 0 (mod 2)
# hidden_bits . 1042843638 = 0 (mod 2)
# hidden_bits . 1042931015 = 0 (mod 2)
# hidden_bits . 1042932350 = 0 (mod 2)
# hidden_bits . 1042956286 = 0 (mod 2)
# hidden_bits . 1043154403 = 0 (mod 2)
# hidden_bits . 1043180224 = 0 (mod 2)
# hidden_bits . 1043207539 = 0 (mod 2)
# hidden_bits . 1043211692 = 0 (mod 2)
# hidden_bits . 1043238495 = 0 (mod 2)
# hidden_bits . 1043329846 = 0 (mod 2)
# hidden_bits . 1043448564 = 0 (mod 2)
# hidden_bits . 1043476808 = 0 (mod 2)
# hidden_bits . 1043535932 = 0 (mod 2)
# hidden_bits . 1043640292 = 0 (mod 2)
# hidden_bits . 1043667271 = 0 (mod 2)
# hidden_bits . 1043874163 = 0 (mod 2)
# hidden_bits . 1044068104 = 0 (mod 2)
# hidden_bits . 1044124943 = 0 (mod 2)
# hidden_bits . 1044305969 = 0 (mod 2)
# hidden_bits . 1044453824 = 0 (mod 2)
# hidden_bits . 1044457252 = 0 (mod 2)
# hidden_bits . 1044487189 = 0 (mod 2)
# hidden_bits . 1044563208 = 0 (mod 2)
# hidden_bits . 1044721754 = 0 (mod 2)
# hidden_bits . 1044929126 = 0 (mod 2)
# hidden_bits . 1045125228 = 0 (mod 2)
# hidden_bits . 1045132716 = 0 (mod 2)
# hidden_bits . 1045273963 = 0 (mod 2)
# hidden_bits . 1045401907 = 0 (mod 2)
# hidden_bits . 1045570609 = 0 (mod 2)
# hidden_bits . 1045674150 = 0 (mod 2)
# hidden_bits . 1045732103 = 0 (mod 2)
# hidden_bits . 1046264079 = 0 (mod 2)
# hidden_bits . 1046435899 = 0 (mod 2)
# hidden_bits . 1046676754 = 0 (mod 2)
# hidden_bits . 1046759268 = 0 (mod 2)
# hidden_bits . 1046804025 = 0 (mod 2)
# hidden_bits . 1046881309 = 0 (mod 2)
# hidden_bits . 1047151061 = 0 (mod 2)
# hidden_bits . 1047200315 = 0 (mod 2)
# hidden_bits . 1047435579 = 0 (mod 2)
# hidden_bits . 1047543467 = 0 (mod 2)
# hidden_bits . 1047810909 = 0 (mod 2)
# hidden_bits . 1047819154 = 0 (mod 2)
# hidden_bits . 1047843933 = 0 (mod 2)
# hidden_bits . 1047888702 = 0 (mod 2)
# hidden_bits . 1048051625 = 0 (mod 2)
# hidden_bits . 1048099686 = 0 (mod 2)
# hidden_bits . 1048146468 = 0 (mod 2)
# hidden_bits . 1048407960 = 0 (mod 2)
# hidden_bits . 1048407967 = 0 (mod 2)
# hidden_bits . 1048455166 = 0 (mod 2)
# hidden_bits . 1048549881 = 0 (mod 2)
# hidden_bits . 1048559573 = 0 (mod 2)
# hidden_bits . 1048665060 = 0 (mod 2)
# hidden_bits . 1048732129 = 0 (mod 2)
# hidden_bits . 1048841843 = 0 (mod 2)
# hidden_bits . 1048914640 = 0 (mod 2)
# hidden_bits . 1048993287 = 0 (mod 2)
# hidden_bits . 1049017239 = 0 (mod 2)
# hidden_bits . 1049347299 = 0 (mod 2)
# hidden_bits . 1049486538 = 0 (mod 2)
# hidden_bits . 1049647696 = 0 (mod 2)
# hidden_bits . 1049718830 = 0 (mod 2)
# hidden_bits . 1049749896 = 0 (mod 2)
# hidden_bits . 1049804805 = 0 (mod 2)
# hidden_bits . 1049919476 = 0 (mod 2)
# hidden_bits . 1050012195 = 0 (mod 2)
# hidden_bits . 1050030658 = 0 (mod 2)
# hidden_bits . 1050054085 = 0 (mod 2)
# hidden_bits . 1050111426 = 0 (mod 2)
# hidden_bits . 1050314242 = 0 (mod 2)
# hidden_bits . 1050319767 = 0 (mod 2)
# hidden_bits . 1050483712 = 0 (mod 2)
# hidden_bits . 1050527511 = 0 (mod 2)
# hidden_bits . 1050915458 = 0 (mod 2)
# hidden_bits . 1051046131 = 0 (mod 2)
# hidden_bits . 1051193375 = 0 (mod 2)
# hidden_bits . 1051219702 = 0 (mod 2)
# hidden_bits . 1051261151 = 0 (mod 2)
# hidden_bits . 1051420734 = 0 (mod 2)
# hidden_bits . 1051479721 = 0 (mod 2)
# hidden_bits . 1051552555 = 0 (mod 2)
# hidden_bits . 1051621684 = 0 (mod 2)
# hidden_bits . 1051759420 = 0 (mod 2)
# hidden_bits . 1051820075 = 0 (mod 2)
# hidden_bits . 1051884708 = 0 (mod 2)
# hidden_bits . 1051894134 = 0 (mod 2)
# hidden_bits . 1052050219 = 0 (mod 2)
# hidden_bits . 1052175197 = 0 (mod 2)
# hidden_bits . 1052209579 = 0 (mod 2)
# hidden_bits . 1052232223 = 0 (mod 2)
# hidden_bits . 1052389950 = 0 (mod 2)
# hidden_bits . 1052407874 = 0 (mod 2)
# hidden_bits . 1052418885 = 0 (mod 2)
# hidden_bits . 1052559181 = 0 (mod 2)
# hidden_bits . 1052768645 = 0 (mod 2)
# hidden_bits . 1053083124 = 0 (mod 2)
# hidden_bits . 1053178322 = 0 (mod 2)
# hidden_bits . 1053194887 = 0 (mod 2)
# hidden_bits . 1053198413 = 0 (mod 2)
# hidden_bits . 1053233237 = 0 (mod 2)
# hidden_bits . 1053697003 = 0 (mod 2)
# hidden_bits . 1053796475 = 0 (mod 2)
# hidden_bits . 1053820573 = 0 (mod 2)
# hidden_bits . 1053895795 = 0 (mod 2)
# hidden_bits . 1053920227 = 0 (mod 2)
# hidden_bits . 1053920737 = 0 (mod 2)
# hidden_bits . 1053986074 = 0 (mod 2)
# hidden_bits . 1054131341 = 0 (mod 2)
# hidden_bits . 1054132707 = 0 (mod 2)
# hidden_bits . 1054153827 = 0 (mod 2)
# hidden_bits . 1054161813 = 0 (mod 2)
# hidden_bits . 1054177190 = 0 (mod 2)
# hidden_bits . 1054329170 = 0 (mod 2)
# hidden_bits . 1054333575 = 0 (mod 2)
# hidden_bits . 1054356997 = 0 (mod 2)
# hidden_bits . 1054372334 = 0 (mod 2)
# hidden_bits . 1054579735 = 0 (mod 2)
# hidden_bits . 1054640384 = 0 (mod 2)
# hidden_bits . 1054696543 = 0 (mod 2)
# hidden_bits . 1054791281 = 0 (mod 2)
# hidden_bits . 1054815317 = 0 (mod 2)
# hidden_bits . 1054989325 = 0 (mod 2)
# hidden_bits . 1055012245 = 0 (mod 2)
# hidden_bits . 1055136036 = 0 (mod 2)
# hidden_bits . 1055157734 = 0 (mod 2)
# hidden_bits . 1055162110 = 0 (mod 2)
# hidden_bits . 1055301942 = 0 (mod 2)
# hidden_bits . 1055508260 = 0 (mod 2)
# hidden_bits . 1055648929 = 0 (mod 2)
# hidden_bits . 1055780606 = 0 (mod 2)
# hidden_bits . 1055817807 = 0 (mod 2)
# hidden_bits . 1055834392 = 0 (mod 2)
# hidden_bits . 1055848008 = 0 (mod 2)
# hidden_bits . 1055935069 = 0 (mod 2)
# hidden_bits . 1056461725 = 0 (mod 2)
# hidden_bits . 1056490041 = 0 (mod 2)
# hidden_bits . 1056646415 = 0 (mod 2)
# hidden_bits . 1056661233 = 0 (mod 2)
# hidden_bits . 1056757333 = 0 (mod 2)
# hidden_bits . 1056931233 = 0 (mod 2)
# hidden_bits . 1056952630 = 0 (mod 2)
# hidden_bits . 1057090842 = 0 (mod 2)
# hidden_bits . 1057197338 = 0 (mod 2)
# hidden_bits . 1057285409 = 0 (mod 2)
# hidden_bits . 1057458445 = 0 (mod 2)
# hidden_bits . 1057465844 = 0 (mod 2)
# hidden_bits . 1057556582 = 0 (mod 2)
# hidden_bits . 1057703706 = 0 (mod 2)
# hidden_bits . 1057905616 = 0 (mod 2)
# hidden_bits . 1057967703 = 0 (mod 2)
# hidden_bits . 1057992280 = 0 (mod 2)
# hidden_bits . 1058056413 = 0 (mod 2)
# hidden_bits . 1058212504 = 0 (mod 2)
# hidden_bits . 1058378370 = 0 (mod 2)
# hidden_bits . 1058407142 = 0 (mod 2)
# hidden_bits . 1058414090 = 0 (mod 2)
# hidden_bits . 1058453281 = 0 (mod 2)
# hidden_bits . 1058573639 = 0 (mod 2)
# hidden_bits . 1058732468 = 0 (mod 2)
# hidden_bits . 1058757414 = 0 (mod 2)
# hidden_bits . 1058906818 = 0 (mod 2)
# hidden_bits . 1059293271 = 0 (mod 2)
# hidden_bits . 1059321546 = 0 (mod 2)
# hidden_bits . 1059344149 = 0 (mod 2)
# hidden_bits . 1059379710 = 0 (mod 2)
# hidden_bits . 1059412654 = 0 (mod 2)
# hidden_bits . 1059434161 = 0 (mod 2)
# hidden_bits . 1059502497 = 0 (mod 2)
# hidden_bits . 1059516281 = 0 (mod 2)
# hidden_bits . 1059685987 = 0 (mod 2)
# hidden_bits . 1059733870 = 0 (mod 2)
# hidden_bits . 1060415932 = 0 (mod 2)
# hidden_bits . 1060416569 = 0 (mod 2)
# hidden_bits . 1060455467 = 0 (mod 2)
# hidden_bits . 1060482353 = 0 (mod 2)
# hidden_bits . 1060521485 = 0 (mod 2)
# hidden_bits . 1060563797 = 0 (mod 2)
# hidden_bits . 1060597015 = 0 (mod 2)
# hidden_bits . 1061011162 = 0 (mod 2)
# hidden_bits . 1061142045 = 0 (mod 2)
# hidden_bits . 1061167550 = 0 (mod 2)
# hidden_bits . 1061229768 = 0 (mod 2)
# hidden_bits . 1061259082 = 0 (mod 2)
# hidden_bits . 1061263114 = 0 (mod 2)
# hidden_bits . 1061329259 = 0 (mod 2)
# hidden_bits . 1061486213 = 0 (mod 2)
# hidden_bits . 1061771087 = 0 (mod 2)
# hidden_bits . 1061810880 = 0 (mod 2)
# hidden_bits . 1062070674 = 0 (mod 2)
# hidden_bits . 1062394951 = 0 (mod 2)
# hidden_bits . 1062707070 = 0 (mod 2)
# hidden_bits . 1062784013 = 0 (mod 2)
# hidden_bits . 1062798203 = 0 (mod 2)
# hidden_bits . 1062804874 = 0 (mod 2)
# hidden_bits . 1062964587 = 0 (mod 2)
# hidden_bits . 1063166349 = 0 (mod 2)
# hidden_bits . 1063238955 = 0 (mod 2)
# hidden_bits . 1063268552 = 0 (mod 2)
# hidden_bits . 1063324772 = 0 (mod 2)
# hidden_bits . 1063329324 = 0 (mod 2)
# hidden_bits . 1063439155 = 0 (mod 2)
# hidden_bits . 1063590928 = 0 (mod 2)
# hidden_bits . 1063640578 = 0 (mod 2)
# hidden_bits . 1063680942 = 0 (mod 2)
# hidden_bits . 1063696709 = 0 (mod 2)
# hidden_bits . 1063937032 = 0 (mod 2)
# hidden_bits . 1064027939 = 0 (mod 2)
# hidden_bits . 1064111943 = 0 (mod 2)
# hidden_bits . 1064135322 = 0 (mod 2)
# hidden_bits . 1064270246 = 0 (mod 2)
# hidden_bits . 1064656739 = 0 (mod 2)
# hidden_bits . 1064669731 = 0 (mod 2)
# hidden_bits . 1064694500 = 0 (mod 2)
# hidden_bits . 1064703501 = 0 (mod 2)
# hidden_bits . 1064749525 = 0 (mod 2)
# hidden_bits . 1064798633 = 0 (mod 2)
# hidden_bits . 1065233749 = 0 (mod 2)
# hidden_bits . 1065352135 = 0 (mod 2)
# hidden_bits . 1065403236 = 0 (mod 2)
# hidden_bits . 1065578968 = 0 (mod 2)
# hidden_bits . 1065608427 = 0 (mod 2)
# hidden_bits . 1065744216 = 0 (mod 2)
# hidden_bits . 1065834209 = 0 (mod 2)
# hidden_bits . 1065865744 = 0 (mod 2)
# hidden_bits . 1066049682 = 0 (mod 2)
# hidden_bits . 1066162868 = 0 (mod 2)
# hidden_bits . 1066205116 = 0 (mod 2)
# hidden_bits . 1066212012 = 0 (mod 2)
# hidden_bits . 1066297112 = 0 (mod 2)
# hidden_bits . 1066415908 = 0 (mod 2)
# hidden_bits . 1066589978 = 0 (mod 2)
# hidden_bits . 1066650005 = 0 (mod 2)
# hidden_bits . 1066684823 = 0 (mod 2)
# hidden_bits . 1066715132 = 0 (mod 2)
# hidden_bits . 1067266760 = 0 (mod 2)
# hidden_bits . 1067461436 = 0 (mod 2)
# hidden_bits . 1067681751 = 0 (mod 2)
# hidden_bits . 1067698440 = 0 (mod 2)
# hidden_bits . 1067761462 = 0 (mod 2)
# hidden_bits . 1067858219 = 0 (mod 2)
# hidden_bits . 1068059480 = 0 (mod 2)
# hidden_bits . 1068244019 = 0 (mod 2)
# hidden_bits . 1068591854 = 0 (mod 2)
# hidden_bits . 1068682832 = 0 (mod 2)
# hidden_bits . 1068773345 = 0 (mod 2)
# hidden_bits . 1068799713 = 0 (mod 2)
# hidden_bits . 1068804749 = 0 (mod 2)
# hidden_bits . 1068906066 = 0 (mod 2)
# hidden_bits . 1069047424 = 0 (mod 2)
# hidden_bits . 1069064124 = 0 (mod 2)
# hidden_bits . 1069117878 = 0 (mod 2)
# hidden_bits . 1069164843 = 0 (mod 2)
# hidden_bits . 1069168519 = 0 (mod 2)
# hidden_bits . 1069183009 = 0 (mod 2)
# hidden_bits . 1069331845 = 0 (mod 2)
# hidden_bits . 1069481543 = 0 (mod 2)
# hidden_bits . 1069509556 = 0 (mod 2)
# hidden_bits . 1069588167 = 0 (mod 2)
# hidden_bits . 1069771461 = 0 (mod 2)
# hidden_bits . 1069939641 = 0 (mod 2)
# hidden_bits . 1070030369 = 0 (mod 2)
# hidden_bits . 1070277548 = 0 (mod 2)
# hidden_bits . 1070391718 = 0 (mod 2)
# hidden_bits . 1070517366 = 0 (mod 2)
# hidden_bits . 1070552121 = 0 (mod 2)
# hidden_bits . 1070604304 = 0 (mod 2)
# hidden_bits . 1070665953 = 0 (mod 2)
# hidden_bits . 1070741512 = 0 (mod 2)
# hidden_bits . 1070901153 = 0 (mod 2)
# hidden_bits . 1070936868 = 0 (mod 2)
# hidden_bits . 1070943056 = 0 (mod 2)
# hidden_bits . 1071000082 = 0 (mod 2)
# hidden_bits . 1071008261 = 0 (mod 2)
# hidden_bits . 1071093269 = 0 (mod 2)
# hidden_bits . 1071125058 = 0 (mod 2)
# hidden_bits . 1071235008 = 0 (mod 2)
# hidden_bits . 1071472141 = 0 (mod 2)
# hidden_bits . 1071528878 = 0 (mod 2)
# hidden_bits . 1071537651 = 0 (mod 2)
# hidden_bits . 1071590908 = 0 (mod 2)
# hidden_bits . 1071681635 = 0 (mod 2)
# hidden_bits . 1071738378 = 0 (mod 2)
# hidden_bits . 1071740387 = 0 (mod 2)
# hidden_bits . 1072032499 = 0 (mod 2)
# hidden_bits . 1072264878 = 0 (mod 2)
# hidden_bits . 1072299778 = 0 (mod 2)
# hidden_bits . 1072520144 = 0 (mod 2)
# hidden_bits . 1072887818 = 0 (mod 2)
# hidden_bits . 1073202852 = 0 (mod 2)
# hidden_bits . 1073207355 = 0 (mod 2)
# hidden_bits . 1073551353 = 0 (mod 2)
# hidden_bits . 1073604862 = 0 (mod 2)
# hidden_bits . 1073733141 = 0 (mod 2)
# hidden_bits . 1073741822 = 0 (mod 2)

# %% [markdown]
# ...The ultimate point of the algorithm is that, by solving the above system of equations, we can determine the value of `hidden_string`, with a probabilistic likelihood that converges exponentially faster than a "classical" algorithm, in the number of measurement "shots." (In a real hardware quantum computer, the number of "shots" would correspond to exactly the number of queries of the oracle).

# %%
for key in results.keys():
    x = (bin(hidden_bits & key).count("1")) & 1
    print(hidden_bits, ".", key, "=", x, "(mod 2)")
# Out:
# 37 . 2529 = 0 (mod 2)
# 37 . 134246 = 0 (mod 2)
# 37 . 241771 = 0 (mod 2)
# 37 . 246910 = 0 (mod 2)
# 37 . 305671 = 0 (mod 2)
# 37 . 336116 = 0 (mod 2)
# 37 . 431181 = 0 (mod 2)
# 37 . 618560 = 0 (mod 2)
# 37 . 693939 = 0 (mod 2)
# 37 . 703075 = 0 (mod 2)
# 37 . 713751 = 0 (mod 2)
# 37 . 906915 = 0 (mod 2)
# 37 . 1086423 = 0 (mod 2)
# 37 . 1135954 = 0 (mod 2)
# 37 . 1338831 = 0 (mod 2)
# 37 . 1583348 = 0 (mod 2)
# 37 . 1708383 = 0 (mod 2)
# 37 . 1719678 = 0 (mod 2)
# 37 . 1799752 = 0 (mod 2)
# 37 . 1832763 = 0 (mod 2)
# 37 . 1865836 = 0 (mod 2)
# 37 . 1882256 = 0 (mod 2)
# 37 . 1968842 = 0 (mod 2)
# 37 . 1969004 = 0 (mod 2)
# 37 . 2169532 = 0 (mod 2)
# 37 . 2205225 = 0 (mod 2)
# 37 . 2274504 = 0 (mod 2)
# 37 . 2433221 = 0 (mod 2)
# 37 . 2461912 = 0 (mod 2)
# 37 . 2522637 = 0 (mod 2)
# 37 . 2607047 = 0 (mod 2)
# 37 . 2677246 = 0 (mod 2)
# 37 . 2700393 = 0 (mod 2)
# 37 . 2955416 = 0 (mod 2)
# 37 . 2990075 = 0 (mod 2)
# 37 . 3034757 = 0 (mod 2)
# 37 . 3165061 = 0 (mod 2)
# 37 . 3222134 = 0 (mod 2)
# 37 . 3522606 = 0 (mod 2)
# 37 . 3540350 = 0 (mod 2)
# 37 . 3756910 = 0 (mod 2)
# 37 . 3899307 = 0 (mod 2)
# 37 . 4127729 = 0 (mod 2)
# 37 . 4150198 = 0 (mod 2)
# 37 . 4514890 = 0 (mod 2)
# 37 . 4560647 = 0 (mod 2)
# 37 . 4651964 = 0 (mod 2)
# 37 . 4781319 = 0 (mod 2)
# 37 . 4808953 = 0 (mod 2)
# 37 . 5118400 = 0 (mod 2)
# 37 . 5185565 = 0 (mod 2)
# 37 . 5195105 = 0 (mod 2)
# 37 . 5332183 = 0 (mod 2)
# 37 . 5339571 = 0 (mod 2)
# 37 . 5404918 = 0 (mod 2)
# 37 . 5716055 = 0 (mod 2)
# 37 . 5718557 = 0 (mod 2)
# 37 . 6019719 = 0 (mod 2)
# 37 . 6264825 = 0 (mod 2)
# 37 . 6436772 = 0 (mod 2)
# 37 . 6471495 = 0 (mod 2)
# 37 . 6490238 = 0 (mod 2)
# 37 . 6682973 = 0 (mod 2)
# 37 . 6703768 = 0 (mod 2)
# 37 . 6802959 = 0 (mod 2)
# 37 . 6924780 = 0 (mod 2)
# 37 . 6936325 = 0 (mod 2)
# 37 . 6971110 = 0 (mod 2)
# 37 . 7214098 = 0 (mod 2)
# 37 . 7241418 = 0 (mod 2)
# 37 . 7285105 = 0 (mod 2)
# 37 . 7380298 = 0 (mod 2)
# 37 . 7467679 = 0 (mod 2)
# 37 . 7525133 = 0 (mod 2)
# 37 . 7648179 = 0 (mod 2)
# 37 . 7719309 = 0 (mod 2)
# 37 . 7826688 = 0 (mod 2)
# 37 . 7864355 = 0 (mod 2)
# 37 . 8066806 = 0 (mod 2)
# 37 . 8310249 = 0 (mod 2)
# 37 . 8411602 = 0 (mod 2)
# 37 . 8470232 = 0 (mod 2)
# 37 . 8563556 = 0 (mod 2)
# 37 . 8571405 = 0 (mod 2)
# 37 . 8643994 = 0 (mod 2)
# 37 . 8658420 = 0 (mod 2)
# 37 . 8699179 = 0 (mod 2)
# 37 . 8876511 = 0 (mod 2)
# 37 . 8970811 = 0 (mod 2)
# 37 . 8982502 = 0 (mod 2)
# 37 . 9031069 = 0 (mod 2)
# 37 . 9146804 = 0 (mod 2)
# 37 . 9181502 = 0 (mod 2)
# 37 . 9256789 = 0 (mod 2)
# 37 . 9261876 = 0 (mod 2)
# 37 . 9273997 = 0 (mod 2)
# 37 . 9301561 = 0 (mod 2)
# 37 . 9339853 = 0 (mod 2)
# 37 . 9395377 = 0 (mod 2)
# 37 . 9559804 = 0 (mod 2)
# 37 . 9685035 = 0 (mod 2)
# 37 . 9696057 = 0 (mod 2)
# 37 . 9735092 = 0 (mod 2)
# 37 . 9738675 = 0 (mod 2)
# 37 . 9764432 = 0 (mod 2)
# 37 . 10084944 = 0 (mod 2)
# 37 . 10132651 = 0 (mod 2)
# 37 . 10144188 = 0 (mod 2)
# 37 . 10262435 = 0 (mod 2)
# 37 . 10319872 = 0 (mod 2)
# 37 . 10585688 = 0 (mod 2)
# 37 . 10600970 = 0 (mod 2)
# 37 . 10727729 = 0 (mod 2)
# 37 . 10888919 = 0 (mod 2)
# 37 . 11003032 = 0 (mod 2)
# 37 . 11111932 = 0 (mod 2)
# 37 . 11375462 = 0 (mod 2)
# 37 . 11423111 = 0 (mod 2)
# 37 . 11649496 = 0 (mod 2)
# 37 . 11815547 = 0 (mod 2)
# 37 . 11857418 = 0 (mod 2)
# 37 . 11893998 = 0 (mod 2)
# 37 . 11917860 = 0 (mod 2)
# 37 . 12092869 = 0 (mod 2)
# 37 . 12156860 = 0 (mod 2)
# 37 . 12322870 = 0 (mod 2)
# 37 . 12323018 = 0 (mod 2)
# 37 . 12422307 = 0 (mod 2)
# 37 . 12495931 = 0 (mod 2)
# 37 . 12503916 = 0 (mod 2)
# 37 . 12609823 = 0 (mod 2)
# 37 . 12710390 = 0 (mod 2)
# 37 . 12904282 = 0 (mod 2)
# 37 . 12980063 = 0 (mod 2)
# 37 . 13045748 = 0 (mod 2)
# 37 . 13162389 = 0 (mod 2)
# 37 . 13192892 = 0 (mod 2)
# 37 . 13304737 = 0 (mod 2)
# 37 . 13381983 = 0 (mod 2)
# 37 . 13495214 = 0 (mod 2)
# 37 . 13721342 = 0 (mod 2)
# 37 . 13811443 = 0 (mod 2)
# 37 . 13924623 = 0 (mod 2)
# 37 . 14515586 = 0 (mod 2)
# 37 . 14554534 = 0 (mod 2)
# 37 . 14673577 = 0 (mod 2)
# 37 . 14930606 = 0 (mod 2)
# 37 . 14930859 = 0 (mod 2)
# 37 . 14955800 = 0 (mod 2)
# 37 . 14980900 = 0 (mod 2)
# 37 . 15086736 = 0 (mod 2)
# 37 . 15540515 = 0 (mod 2)
# 37 . 15703253 = 0 (mod 2)
# 37 . 15751803 = 0 (mod 2)
# 37 . 15861325 = 0 (mod 2)
# 37 . 15864188 = 0 (mod 2)
# 37 . 15894908 = 0 (mod 2)
# 37 . 15924862 = 0 (mod 2)
# 37 . 15987408 = 0 (mod 2)
# 37 . 16109041 = 0 (mod 2)
# 37 . 16165256 = 0 (mod 2)
# 37 . 16191685 = 0 (mod 2)
# 37 . 16378200 = 0 (mod 2)
# 37 . 16502989 = 0 (mod 2)
# 37 . 16599460 = 0 (mod 2)
# 37 . 16658450 = 0 (mod 2)
# 37 . 16667663 = 0 (mod 2)
# 37 . 16723282 = 0 (mod 2)
# 37 . 16820006 = 0 (mod 2)
# 37 . 17074207 = 0 (mod 2)
# 37 . 17153961 = 0 (mod 2)
# 37 . 17197896 = 0 (mod 2)
# 37 . 17303996 = 0 (mod 2)
# 37 . 17421164 = 0 (mod 2)
# 37 . 17732160 = 0 (mod 2)
# 37 . 17757729 = 0 (mod 2)
# 37 . 17788871 = 0 (mod 2)
# 37 . 17792016 = 0 (mod 2)
# 37 . 18129608 = 0 (mod 2)
# 37 . 18157911 = 0 (mod 2)
# 37 . 18193178 = 0 (mod 2)
# 37 . 18348923 = 0 (mod 2)
# 37 . 18490726 = 0 (mod 2)
# 37 . 18769927 = 0 (mod 2)
# 37 . 18777593 = 0 (mod 2)
# 37 . 18894680 = 0 (mod 2)
# 37 . 19155994 = 0 (mod 2)
# 37 . 19215901 = 0 (mod 2)
# 37 . 19273761 = 0 (mod 2)
# 37 . 19535844 = 0 (mod 2)
# 37 . 19638257 = 0 (mod 2)
# 37 . 19828790 = 0 (mod 2)
# 37 . 19945910 = 0 (mod 2)
# 37 . 20065577 = 0 (mod 2)
# 37 . 20067446 = 0 (mod 2)
# 37 . 20217730 = 0 (mod 2)
# 37 . 20269591 = 0 (mod 2)
# 37 . 20411226 = 0 (mod 2)
# 37 . 20574663 = 0 (mod 2)
# 37 . 20857593 = 0 (mod 2)
# 37 . 20857610 = 0 (mod 2)
# 37 . 20967596 = 0 (mod 2)
# 37 . 20996465 = 0 (mod 2)
# 37 . 21043065 = 0 (mod 2)
# 37 . 21245164 = 0 (mod 2)
# 37 . 21302628 = 0 (mod 2)
# 37 . 21500621 = 0 (mod 2)
# 37 . 21539973 = 0 (mod 2)
# 37 . 21625567 = 0 (mod 2)
# 37 . 21645717 = 0 (mod 2)
# 37 . 21669333 = 0 (mod 2)
# 37 . 21746447 = 0 (mod 2)
# 37 . 21981356 = 0 (mod 2)
# 37 . 21989386 = 0 (mod 2)
# 37 . 22020685 = 0 (mod 2)
# 37 . 22022121 = 0 (mod 2)
# 37 . 22087938 = 0 (mod 2)
# 37 . 22132326 = 0 (mod 2)
# 37 . 22170909 = 0 (mod 2)
# 37 . 22615242 = 0 (mod 2)
# 37 . 22721403 = 0 (mod 2)
# 37 . 22762909 = 0 (mod 2)
# 37 . 22984190 = 0 (mod 2)
# 37 . 23013274 = 0 (mod 2)
# 37 . 23034266 = 0 (mod 2)
# 37 . 23095230 = 0 (mod 2)
# 37 . 23133138 = 0 (mod 2)
# 37 . 23237511 = 0 (mod 2)
# 37 . 23315627 = 0 (mod 2)
# 37 . 23347694 = 0 (mod 2)
# 37 . 23465232 = 0 (mod 2)
# 37 . 23540565 = 0 (mod 2)
# 37 . 23582487 = 0 (mod 2)
# 37 . 23828091 = 0 (mod 2)
# 37 . 23882141 = 0 (mod 2)
# 37 . 23956301 = 0 (mod 2)
# 37 . 24017989 = 0 (mod 2)
# 37 . 24106655 = 0 (mod 2)
# 37 . 24177088 = 0 (mod 2)
# 37 . 24228542 = 0 (mod 2)
# 37 . 24285837 = 0 (mod 2)
# 37 . 24316140 = 0 (mod 2)
# 37 . 24354015 = 0 (mod 2)
# 37 . 24426397 = 0 (mod 2)
# 37 . 24433843 = 0 (mod 2)
# 37 . 24484403 = 0 (mod 2)
# 37 . 24538980 = 0 (mod 2)
# 37 . 24558034 = 0 (mod 2)
# 37 . 24608291 = 0 (mod 2)
# 37 . 24805064 = 0 (mod 2)
# 37 . 25028039 = 0 (mod 2)
# 37 . 25154406 = 0 (mod 2)
# 37 . 25235018 = 0 (mod 2)
# 37 . 25514653 = 0 (mod 2)
# 37 . 25593487 = 0 (mod 2)
# 37 . 25644988 = 0 (mod 2)
# 37 . 25721918 = 0 (mod 2)
# 37 . 25770044 = 0 (mod 2)
# 37 . 25861530 = 0 (mod 2)
# 37 . 26020129 = 0 (mod 2)
# 37 . 26126326 = 0 (mod 2)
# 37 . 26203471 = 0 (mod 2)
# 37 . 26239327 = 0 (mod 2)
# 37 . 26352642 = 0 (mod 2)
# 37 . 26748011 = 0 (mod 2)
# 37 . 26751731 = 0 (mod 2)
# 37 . 26751843 = 0 (mod 2)
# 37 . 26846572 = 0 (mod 2)
# 37 . 26875198 = 0 (mod 2)
# 37 . 26877698 = 0 (mod 2)
# 37 . 26915964 = 0 (mod 2)
# 37 . 26925281 = 0 (mod 2)
# 37 . 27075006 = 0 (mod 2)
# 37 . 27418456 = 0 (mod 2)
# 37 . 27467371 = 0 (mod 2)
# 37 . 27558493 = 0 (mod 2)
# 37 . 27600664 = 0 (mod 2)
# 37 . 27736455 = 0 (mod 2)
# 37 . 27742874 = 0 (mod 2)
# 37 . 27788618 = 0 (mod 2)
# 37 . 27813547 = 0 (mod 2)
# 37 . 27817406 = 0 (mod 2)
# 37 . 27821701 = 0 (mod 2)
# 37 . 27922783 = 0 (mod 2)
# 37 . 27993415 = 0 (mod 2)
# 37 . 28001229 = 0 (mod 2)
# 37 . 28081816 = 0 (mod 2)
# 37 . 28101904 = 0 (mod 2)
# 37 . 28404626 = 0 (mod 2)
# 37 . 28423345 = 0 (mod 2)
# 37 . 28429091 = 0 (mod 2)
# 37 . 28607926 = 0 (mod 2)
# 37 . 28842019 = 0 (mod 2)
# 37 . 28875098 = 0 (mod 2)
# 37 . 28987827 = 0 (mod 2)
# 37 . 29079459 = 0 (mod 2)
# 37 . 29218046 = 0 (mod 2)
# 37 . 29517274 = 0 (mod 2)
# 37 . 29568620 = 0 (mod 2)
# 37 . 29599595 = 0 (mod 2)
# 37 . 29874276 = 0 (mod 2)
# 37 . 30323243 = 0 (mod 2)
# 37 . 30567629 = 0 (mod 2)
# 37 . 30649396 = 0 (mod 2)
# 37 . 30675963 = 0 (mod 2)
# 37 . 30694179 = 0 (mod 2)
# 37 . 30734914 = 0 (mod 2)
# 37 . 30786150 = 0 (mod 2)
# 37 . 30795917 = 0 (mod 2)
# 37 . 31298484 = 0 (mod 2)
# 37 . 31362063 = 0 (mod 2)
# 37 . 31427243 = 0 (mod 2)
# 37 . 31438536 = 0 (mod 2)
# 37 . 31743439 = 0 (mod 2)
# 37 . 31870251 = 0 (mod 2)
# 37 . 32024684 = 0 (mod 2)
# 37 . 32044744 = 0 (mod 2)
# 37 . 32074312 = 0 (mod 2)
# 37 . 32182408 = 0 (mod 2)
# 37 . 32828752 = 0 (mod 2)
# 37 . 33102844 = 0 (mod 2)
# 37 . 33119373 = 0 (mod 2)
# 37 . 33160313 = 0 (mod 2)
# 37 . 33304410 = 0 (mod 2)
# 37 . 33368372 = 0 (mod 2)
# 37 . 33507527 = 0 (mod 2)
# 37 . 33606782 = 0 (mod 2)
# 37 . 33716836 = 0 (mod 2)
# 37 . 33871442 = 0 (mod 2)
# 37 . 34115039 = 0 (mod 2)
# 37 . 34292034 = 0 (mod 2)
# 37 . 34342848 = 0 (mod 2)
# 37 . 34372537 = 0 (mod 2)
# 37 . 34381113 = 0 (mod 2)
# 37 . 34397447 = 0 (mod 2)
# 37 . 34450775 = 0 (mod 2)
# 37 . 34473892 = 0 (mod 2)
# 37 . 34540475 = 0 (mod 2)
# 37 . 34559837 = 0 (mod 2)
# 37 . 34972749 = 0 (mod 2)
# 37 . 35046400 = 0 (mod 2)
# 37 . 35105373 = 0 (mod 2)
# 37 . 35152177 = 0 (mod 2)
# 37 . 35182807 = 0 (mod 2)
# 37 . 35216110 = 0 (mod 2)
# 37 . 35544748 = 0 (mod 2)
# 37 . 35738745 = 0 (mod 2)
# 37 . 36231923 = 0 (mod 2)
# 37 . 36457129 = 0 (mod 2)
# 37 . 36499351 = 0 (mod 2)
# 37 . 36857020 = 0 (mod 2)
# 37 . 37026959 = 0 (mod 2)
# 37 . 37102623 = 0 (mod 2)
# 37 . 37158431 = 0 (mod 2)
# 37 . 37206579 = 0 (mod 2)
# 37 . 37217193 = 0 (mod 2)
# 37 . 37359540 = 0 (mod 2)
# 37 . 37360190 = 0 (mod 2)
# 37 . 37405027 = 0 (mod 2)
# 37 . 37459561 = 0 (mod 2)
# 37 . 37603200 = 0 (mod 2)
# 37 . 37635310 = 0 (mod 2)
# 37 . 37708309 = 0 (mod 2)
# 37 . 37864940 = 0 (mod 2)
# 37 . 37972175 = 0 (mod 2)
# 37 . 38005556 = 0 (mod 2)
# 37 . 38139894 = 0 (mod 2)
# 37 . 38193415 = 0 (mod 2)
# 37 . 38286338 = 0 (mod 2)
# 37 . 38345117 = 0 (mod 2)
# 37 . 38585426 = 0 (mod 2)
# 37 . 38614031 = 0 (mod 2)
# 37 . 38783923 = 0 (mod 2)
# 37 . 38796651 = 0 (mod 2)
# 37 . 38800722 = 0 (mod 2)
# 37 . 38827138 = 0 (mod 2)
# 37 . 38906153 = 0 (mod 2)
# 37 . 38954642 = 0 (mod 2)
# 37 . 39148368 = 0 (mod 2)
# 37 . 39213564 = 0 (mod 2)
# 37 . 39292075 = 0 (mod 2)
# 37 . 39646388 = 0 (mod 2)
# 37 . 39773371 = 0 (mod 2)
# 37 . 39812537 = 0 (mod 2)
# 37 . 39960675 = 0 (mod 2)
# 37 . 40202155 = 0 (mod 2)
# 37 . 40281332 = 0 (mod 2)
# 37 . 40375495 = 0 (mod 2)
# 37 . 40554158 = 0 (mod 2)
# 37 . 40714022 = 0 (mod 2)
# 37 . 40767960 = 0 (mod 2)
# 37 . 40918830 = 0 (mod 2)
# 37 . 40920525 = 0 (mod 2)
# 37 . 41011152 = 0 (mod 2)
# 37 . 41016981 = 0 (mod 2)
# 37 . 41158493 = 0 (mod 2)
# 37 . 41199751 = 0 (mod 2)
# 37 . 41241385 = 0 (mod 2)
# 37 . 41357371 = 0 (mod 2)
# 37 . 41666620 = 0 (mod 2)
# 37 . 41703411 = 0 (mod 2)
# 37 . 41707648 = 0 (mod 2)
# 37 . 42011152 = 0 (mod 2)
# 37 . 42040500 = 0 (mod 2)
# 37 . 42092176 = 0 (mod 2)
# 37 . 42128088 = 0 (mod 2)
# 37 . 42237043 = 0 (mod 2)
# 37 . 42281674 = 0 (mod 2)
# 37 . 42594867 = 0 (mod 2)
# 37 . 42869023 = 0 (mod 2)
# 37 . 42929843 = 0 (mod 2)
# 37 . 42945451 = 0 (mod 2)
# 37 . 43180352 = 0 (mod 2)
# 37 . 43303496 = 0 (mod 2)
# 37 . 43305626 = 0 (mod 2)
# 37 . 43349458 = 0 (mod 2)
# 37 . 43350557 = 0 (mod 2)
# 37 . 43461128 = 0 (mod 2)
# 37 . 43490335 = 0 (mod 2)
# 37 . 43495247 = 0 (mod 2)
# 37 . 43548579 = 0 (mod 2)
# 37 . 43561351 = 0 (mod 2)
# 37 . 43771869 = 0 (mod 2)
# 37 . 44140006 = 0 (mod 2)
# 37 . 44195516 = 0 (mod 2)
# 37 . 44208600 = 0 (mod 2)
# 37 . 44303782 = 0 (mod 2)
# 37 . 44444359 = 0 (mod 2)
# 37 . 44512389 = 0 (mod 2)
# 37 . 44653576 = 0 (mod 2)
# 37 . 44815668 = 0 (mod 2)
# 37 . 44884749 = 0 (mod 2)
# 37 . 45014326 = 0 (mod 2)
# 37 . 45025721 = 0 (mod 2)
# 37 . 45154092 = 0 (mod 2)
# 37 . 45216719 = 0 (mod 2)
# 37 . 45261919 = 0 (mod 2)
# 37 . 45417560 = 0 (mod 2)
# 37 . 45596943 = 0 (mod 2)
# 37 . 45692723 = 0 (mod 2)
# 37 . 45721986 = 0 (mod 2)
# 37 . 45744814 = 0 (mod 2)
# 37 . 45787502 = 0 (mod 2)
# 37 . 45848264 = 0 (mod 2)
# 37 . 45916063 = 0 (mod 2)
# 37 . 45995299 = 0 (mod 2)
# 37 . 45995326 = 0 (mod 2)
# 37 . 46226921 = 0 (mod 2)
# 37 . 46373845 = 0 (mod 2)
# 37 . 46456024 = 0 (mod 2)
# 37 . 46957711 = 0 (mod 2)
# 37 . 46968246 = 0 (mod 2)
# 37 . 47028329 = 0 (mod 2)
# 37 . 47286884 = 0 (mod 2)
# 37 . 47338915 = 0 (mod 2)
# 37 . 47367019 = 0 (mod 2)
# 37 . 47516142 = 0 (mod 2)
# 37 . 47692160 = 0 (mod 2)
# 37 . 47706033 = 0 (mod 2)
# 37 . 47793093 = 0 (mod 2)
# 37 . 47811669 = 0 (mod 2)
# 37 . 47845698 = 0 (mod 2)
# 37 . 47862700 = 0 (mod 2)
# 37 . 47874212 = 0 (mod 2)
# 37 . 47905741 = 0 (mod 2)
# 37 . 47909756 = 0 (mod 2)
# 37 . 47930816 = 0 (mod 2)
# 37 . 48150095 = 0 (mod 2)
# 37 . 48204482 = 0 (mod 2)
# 37 . 48302295 = 0 (mod 2)
# 37 . 48312773 = 0 (mod 2)
# 37 . 48417493 = 0 (mod 2)
# 37 . 48630218 = 0 (mod 2)
# 37 . 48663038 = 0 (mod 2)
# 37 . 49016415 = 0 (mod 2)
# 37 . 49257800 = 0 (mod 2)
# 37 . 49294374 = 0 (mod 2)
# 37 . 49392305 = 0 (mod 2)
# 37 . 49447796 = 0 (mod 2)
# 37 . 49452524 = 0 (mod 2)
# 37 . 49568919 = 0 (mod 2)
# 37 . 49606332 = 0 (mod 2)
# 37 . 49669082 = 0 (mod 2)
# 37 . 49687301 = 0 (mod 2)
# 37 . 49774535 = 0 (mod 2)
# 37 . 49789504 = 0 (mod 2)
# 37 . 49828058 = 0 (mod 2)
# 37 . 49863931 = 0 (mod 2)
# 37 . 49956306 = 0 (mod 2)
# 37 . 50136456 = 0 (mod 2)
# 37 . 50271189 = 0 (mod 2)
# 37 . 50373494 = 0 (mod 2)
# 37 . 50550774 = 0 (mod 2)
# 37 . 50601864 = 0 (mod 2)
# 37 . 50640847 = 0 (mod 2)
# 37 . 50643750 = 0 (mod 2)
# 37 . 50805589 = 0 (mod 2)
# 37 . 50883797 = 0 (mod 2)
# 37 . 50952517 = 0 (mod 2)
# 37 . 50970982 = 0 (mod 2)
# 37 . 51179313 = 0 (mod 2)
# 37 . 51197343 = 0 (mod 2)
# 37 . 51257432 = 0 (mod 2)
# 37 . 51280274 = 0 (mod 2)
# 37 . 51344620 = 0 (mod 2)
# 37 . 51367907 = 0 (mod 2)
# 37 . 51394609 = 0 (mod 2)
# 37 . 51480188 = 0 (mod 2)
# 37 . 51491699 = 0 (mod 2)
# 37 . 51524096 = 0 (mod 2)
# 37 . 51973878 = 0 (mod 2)
# 37 . 52078140 = 0 (mod 2)
# 37 . 52107717 = 0 (mod 2)
# 37 . 52137268 = 0 (mod 2)
# 37 . 52168548 = 0 (mod 2)
# 37 . 52204229 = 0 (mod 2)
# 37 . 52268554 = 0 (mod 2)
# 37 . 52335851 = 0 (mod 2)
# 37 . 52485737 = 0 (mod 2)
# 37 . 52563973 = 0 (mod 2)
# 37 . 52767682 = 0 (mod 2)
# 37 . 52876312 = 0 (mod 2)
# 37 . 52929928 = 0 (mod 2)
# 37 . 53020201 = 0 (mod 2)
# 37 . 53155814 = 0 (mod 2)
# 37 . 53224727 = 0 (mod 2)
# 37 . 53262103 = 0 (mod 2)
# 37 . 53365694 = 0 (mod 2)
# 37 . 53405061 = 0 (mod 2)
# 37 . 53412707 = 0 (mod 2)
# 37 . 53421696 = 0 (mod 2)
# 37 . 53435617 = 0 (mod 2)
# 37 . 53472725 = 0 (mod 2)
# 37 . 53491328 = 0 (mod 2)
# 37 . 53924232 = 0 (mod 2)
# 37 . 54037125 = 0 (mod 2)
# 37 . 54219310 = 0 (mod 2)
# 37 . 54219330 = 0 (mod 2)
# 37 . 54529946 = 0 (mod 2)
# 37 . 54536205 = 0 (mod 2)
# 37 . 54602560 = 0 (mod 2)
# 37 . 54656758 = 0 (mod 2)
# 37 . 54793554 = 0 (mod 2)
# 37 . 54969290 = 0 (mod 2)
# 37 . 54997447 = 0 (mod 2)
# 37 . 55020078 = 0 (mod 2)
# 37 . 55089800 = 0 (mod 2)
# 37 . 55154525 = 0 (mod 2)
# 37 . 55164652 = 0 (mod 2)
# 37 . 55217031 = 0 (mod 2)
# 37 . 55333878 = 0 (mod 2)
# 37 . 55493153 = 0 (mod 2)
# 37 . 55549645 = 0 (mod 2)
# 37 . 55629952 = 0 (mod 2)
# 37 . 55984605 = 0 (mod 2)
# 37 . 56023908 = 0 (mod 2)
# 37 . 56124771 = 0 (mod 2)
# 37 . 56278040 = 0 (mod 2)
# 37 . 56335168 = 0 (mod 2)
# 37 . 56459149 = 0 (mod 2)
# 37 . 56498005 = 0 (mod 2)
# 37 . 56526193 = 0 (mod 2)
# 37 . 56707556 = 0 (mod 2)
# 37 . 56745298 = 0 (mod 2)
# 37 . 56774630 = 0 (mod 2)
# 37 . 56872187 = 0 (mod 2)
# 37 . 57157456 = 0 (mod 2)
# 37 . 57292267 = 0 (mod 2)
# 37 . 57302305 = 0 (mod 2)
# 37 . 57525663 = 0 (mod 2)
# 37 . 57636306 = 0 (mod 2)
# 37 . 57829135 = 0 (mod 2)
# 37 . 57854249 = 0 (mod 2)
# 37 . 57883474 = 0 (mod 2)
# 37 . 57970217 = 0 (mod 2)
# 37 . 58043933 = 0 (mod 2)
# 37 . 58081311 = 0 (mod 2)
# 37 . 58377370 = 0 (mod 2)
# 37 . 58471675 = 0 (mod 2)
# 37 . 58489577 = 0 (mod 2)
# 37 . 58697797 = 0 (mod 2)
# 37 . 58814674 = 0 (mod 2)
# 37 . 59008064 = 0 (mod 2)
# 37 . 59097746 = 0 (mod 2)
# 37 . 59143888 = 0 (mod 2)
# 37 . 59290383 = 0 (mod 2)
# 37 . 59342641 = 0 (mod 2)
# 37 . 59393132 = 0 (mod 2)
# 37 . 59424064 = 0 (mod 2)
# 37 . 59449175 = 0 (mod 2)
# 37 . 59450399 = 0 (mod 2)
# 37 . 59707451 = 0 (mod 2)
# 37 . 59772137 = 0 (mod 2)
# 37 . 59805347 = 0 (mod 2)
# 37 . 59896044 = 0 (mod 2)
# 37 . 59924493 = 0 (mod 2)
# 37 . 59932634 = 0 (mod 2)
# 37 . 59997926 = 0 (mod 2)
# 37 . 60000441 = 0 (mod 2)
# 37 . 60168458 = 0 (mod 2)
# 37 . 60356529 = 0 (mod 2)
# 37 . 60358149 = 0 (mod 2)
# 37 . 60364716 = 0 (mod 2)
# 37 . 60421822 = 0 (mod 2)
# 37 . 60563124 = 0 (mod 2)
# 37 . 60669656 = 0 (mod 2)
# 37 . 60758324 = 0 (mod 2)
# 37 . 60950538 = 0 (mod 2)
# 37 . 60966116 = 0 (mod 2)
# 37 . 61035136 = 0 (mod 2)
# 37 . 61057615 = 0 (mod 2)
# 37 . 61283085 = 0 (mod 2)
# 37 . 61380168 = 0 (mod 2)
# 37 . 61512397 = 0 (mod 2)
# 37 . 61517243 = 0 (mod 2)
# 37 . 61661727 = 0 (mod 2)
# 37 . 61699472 = 0 (mod 2)
# 37 . 61891973 = 0 (mod 2)
# 37 . 62068643 = 0 (mod 2)
# 37 . 62076693 = 0 (mod 2)
# 37 . 62209772 = 0 (mod 2)
# 37 . 62554309 = 0 (mod 2)
# 37 . 62732780 = 0 (mod 2)
# 37 . 62756871 = 0 (mod 2)
# 37 . 63022123 = 0 (mod 2)
# 37 . 63157668 = 0 (mod 2)
# 37 . 63205438 = 0 (mod 2)
# 37 . 63206610 = 0 (mod 2)
# 37 . 63531466 = 0 (mod 2)
# 37 . 63597791 = 0 (mod 2)
# 37 . 63732120 = 0 (mod 2)
# 37 . 63795899 = 0 (mod 2)
# 37 . 63973436 = 0 (mod 2)
# 37 . 64016115 = 0 (mod 2)
# 37 . 64320904 = 0 (mod 2)
# 37 . 64549755 = 0 (mod 2)
# 37 . 64605358 = 0 (mod 2)
# 37 . 64690880 = 0 (mod 2)
# 37 . 64720711 = 0 (mod 2)
# 37 . 64847265 = 0 (mod 2)
# 37 . 64896205 = 0 (mod 2)
# 37 . 64915558 = 0 (mod 2)
# 37 . 64922166 = 0 (mod 2)
# 37 . 64951524 = 0 (mod 2)
# 37 . 64954498 = 0 (mod 2)
# 37 . 64971269 = 0 (mod 2)
# 37 . 65035750 = 0 (mod 2)
# 37 . 65070588 = 0 (mod 2)
# 37 . 65173066 = 0 (mod 2)
# 37 . 65284286 = 0 (mod 2)
# 37 . 65543818 = 0 (mod 2)
# 37 . 65586556 = 0 (mod 2)
# 37 . 65605725 = 0 (mod 2)
# 37 . 65607063 = 0 (mod 2)
# 37 . 65692217 = 0 (mod 2)
# 37 . 65713073 = 0 (mod 2)
# 37 . 65903212 = 0 (mod 2)
# 37 . 66007821 = 0 (mod 2)
# 37 . 66049818 = 0 (mod 2)
# 37 . 66106723 = 0 (mod 2)
# 37 . 66173834 = 0 (mod 2)
# 37 . 66314041 = 0 (mod 2)
# 37 . 66476813 = 0 (mod 2)
# 37 . 66595305 = 0 (mod 2)
# 37 . 66638421 = 0 (mod 2)
# 37 . 66919457 = 0 (mod 2)
# 37 . 66968318 = 0 (mod 2)
# 37 . 67250081 = 0 (mod 2)
# 37 . 67443594 = 0 (mod 2)
# 37 . 67510343 = 0 (mod 2)
# 37 . 67744007 = 0 (mod 2)
# 37 . 67838999 = 0 (mod 2)
# 37 . 67859853 = 0 (mod 2)
# 37 . 67877727 = 0 (mod 2)
# 37 . 67906603 = 0 (mod 2)
# 37 . 67947357 = 0 (mod 2)
# 37 . 68156357 = 0 (mod 2)
# 37 . 68201237 = 0 (mod 2)
# 37 . 68252298 = 0 (mod 2)
# 37 . 68427681 = 0 (mod 2)
# 37 . 68464238 = 0 (mod 2)
# 37 . 68584492 = 0 (mod 2)
# 37 . 68685968 = 0 (mod 2)
# 37 . 68831239 = 0 (mod 2)
# 37 . 69132877 = 0 (mod 2)
# 37 . 69258333 = 0 (mod 2)
# 37 . 69298161 = 0 (mod 2)
# 37 . 69406142 = 0 (mod 2)
# 37 . 69574866 = 0 (mod 2)
# 37 . 69721823 = 0 (mod 2)
# 37 . 69741471 = 0 (mod 2)
# 37 . 69800806 = 0 (mod 2)
# 37 . 69898665 = 0 (mod 2)
# 37 . 69914440 = 0 (mod 2)
# 37 . 70014021 = 0 (mod 2)
# 37 . 70352228 = 0 (mod 2)
# 37 . 70472512 = 0 (mod 2)
# 37 . 70801482 = 0 (mod 2)
# 37 . 70887690 = 0 (mod 2)
# 37 . 71099287 = 0 (mod 2)
# 37 . 71141734 = 0 (mod 2)
# 37 . 71176875 = 0 (mod 2)
# 37 . 71190331 = 0 (mod 2)
# 37 . 71210077 = 0 (mod 2)
# 37 . 71394875 = 0 (mod 2)
# 37 . 71428707 = 0 (mod 2)
# 37 . 71538818 = 0 (mod 2)
# 37 . 71623676 = 0 (mod 2)
# 37 . 72222664 = 0 (mod 2)
# 37 . 72224676 = 0 (mod 2)
# 37 . 72417982 = 0 (mod 2)
# 37 . 72519678 = 0 (mod 2)
# 37 . 72605919 = 0 (mod 2)
# 37 . 72733208 = 0 (mod 2)
# 37 . 72744611 = 0 (mod 2)
# 37 . 72793039 = 0 (mod 2)
# 37 . 72806190 = 0 (mod 2)
# 37 . 72876615 = 0 (mod 2)
# 37 . 72888663 = 0 (mod 2)
# 37 . 72892485 = 0 (mod 2)
# 37 . 72940331 = 0 (mod 2)
# 37 . 73063972 = 0 (mod 2)
# 37 . 73427223 = 0 (mod 2)
# 37 . 73429389 = 0 (mod 2)
# 37 . 73446621 = 0 (mod 2)
# 37 . 73792556 = 0 (mod 2)
# 37 . 73902098 = 0 (mod 2)
# 37 . 74106509 = 0 (mod 2)
# 37 . 74193047 = 0 (mod 2)
# 37 . 74253361 = 0 (mod 2)
# 37 . 74275024 = 0 (mod 2)
# 37 . 74462104 = 0 (mod 2)
# 37 . 74599092 = 0 (mod 2)
# 37 . 74666181 = 0 (mod 2)
# 37 . 74734651 = 0 (mod 2)
# 37 . 74887637 = 0 (mod 2)
# 37 . 74946542 = 0 (mod 2)
# 37 . 75004329 = 0 (mod 2)
# 37 . 75409057 = 0 (mod 2)
# 37 . 75434509 = 0 (mod 2)
# 37 . 75673595 = 0 (mod 2)
# 37 . 75693762 = 0 (mod 2)
# 37 . 75764504 = 0 (mod 2)
# 37 . 75784663 = 0 (mod 2)
# 37 . 75790024 = 0 (mod 2)
# 37 . 75935239 = 0 (mod 2)
# 37 . 75959895 = 0 (mod 2)
# 37 . 75996201 = 0 (mod 2)
# 37 . 76149052 = 0 (mod 2)
# 37 . 76378304 = 0 (mod 2)
# 37 . 76476065 = 0 (mod 2)
# 37 . 76600839 = 0 (mod 2)
# 37 . 76743523 = 0 (mod 2)
# 37 . 76762342 = 0 (mod 2)
# 37 . 76766546 = 0 (mod 2)
# 37 . 76823384 = 0 (mod 2)
# 37 . 76929916 = 0 (mod 2)
# 37 . 76941701 = 0 (mod 2)
# 37 . 76961735 = 0 (mod 2)
# 37 . 77096407 = 0 (mod 2)
# 37 . 77137538 = 0 (mod 2)
# 37 . 77253803 = 0 (mod 2)
# 37 . 77360858 = 0 (mod 2)
# 37 . 77600883 = 0 (mod 2)
# 37 . 77713048 = 0 (mod 2)
# 37 . 77775245 = 0 (mod 2)
# 37 . 77827464 = 0 (mod 2)
# 37 . 77976472 = 0 (mod 2)
# 37 . 77995372 = 0 (mod 2)
# 37 . 78003605 = 0 (mod 2)
# 37 . 78006666 = 0 (mod 2)
# 37 . 78144942 = 0 (mod 2)
# 37 . 78150185 = 0 (mod 2)
# 37 . 78232328 = 0 (mod 2)
# 37 . 78336661 = 0 (mod 2)
# 37 . 78370247 = 0 (mod 2)
# 37 . 78573840 = 0 (mod 2)
# 37 . 78580440 = 0 (mod 2)
# 37 . 78673032 = 0 (mod 2)
# 37 . 78737764 = 0 (mod 2)
# 37 . 78982223 = 0 (mod 2)
# 37 . 79109628 = 0 (mod 2)
# 37 . 79161326 = 0 (mod 2)
# 37 . 79441825 = 0 (mod 2)
# 37 . 79639117 = 0 (mod 2)
# 37 . 79718039 = 0 (mod 2)
# 37 . 79738596 = 0 (mod 2)
# 37 . 79741747 = 0 (mod 2)
# 37 . 79878897 = 0 (mod 2)
# 37 . 80199603 = 0 (mod 2)
# 37 . 80230485 = 0 (mod 2)
# 37 . 80306300 = 0 (mod 2)
# 37 . 80391676 = 0 (mod 2)
# 37 . 80430577 = 0 (mod 2)
# 37 . 80430590 = 0 (mod 2)
# 37 . 80568049 = 0 (mod 2)
# 37 . 80653458 = 0 (mod 2)
# 37 . 80858893 = 0 (mod 2)
# 37 . 80951590 = 0 (mod 2)
# 37 . 81243997 = 0 (mod 2)
# 37 . 81261876 = 0 (mod 2)
# 37 . 81414618 = 0 (mod 2)
# 37 . 81513090 = 0 (mod 2)
# 37 . 81609543 = 0 (mod 2)
# 37 . 81667691 = 0 (mod 2)
# 37 . 81697260 = 0 (mod 2)
# 37 . 81892521 = 0 (mod 2)
# 37 . 81923243 = 0 (mod 2)
# 37 . 81969275 = 0 (mod 2)
# 37 . 82219357 = 0 (mod 2)
# 37 . 82281240 = 0 (mod 2)
# 37 . 82381978 = 0 (mod 2)
# 37 . 82385635 = 0 (mod 2)
# 37 . 82407222 = 0 (mod 2)
# 37 . 82493427 = 0 (mod 2)
# 37 . 82614883 = 0 (mod 2)
# 37 . 82646244 = 0 (mod 2)
# 37 . 82719880 = 0 (mod 2)
# 37 . 82746122 = 0 (mod 2)
# 37 . 82768636 = 0 (mod 2)
# 37 . 82799962 = 0 (mod 2)
# 37 . 82873403 = 0 (mod 2)
# 37 . 82985290 = 0 (mod 2)
# 37 . 83016517 = 0 (mod 2)
# 37 . 83039368 = 0 (mod 2)
# 37 . 83184571 = 0 (mod 2)
# 37 . 83251324 = 0 (mod 2)
# 37 . 83256343 = 0 (mod 2)
# 37 . 83903275 = 0 (mod 2)
# 37 . 83925236 = 0 (mod 2)
# 37 . 84051873 = 0 (mod 2)
# 37 . 84233874 = 0 (mod 2)
# 37 . 84334607 = 0 (mod 2)
# 37 . 84571807 = 0 (mod 2)
# 37 . 84593150 = 0 (mod 2)
# 37 . 84648177 = 0 (mod 2)
# 37 . 84687523 = 0 (mod 2)
# 37 . 84761708 = 0 (mod 2)
# 37 . 85017123 = 0 (mod 2)
# 37 . 85467794 = 0 (mod 2)
# 37 . 85561593 = 0 (mod 2)
# 37 . 85592044 = 0 (mod 2)
# 37 . 85805414 = 0 (mod 2)
# 37 . 85931728 = 0 (mod 2)
# 37 . 86016747 = 0 (mod 2)
# 37 . 86028816 = 0 (mod 2)
# 37 . 86292759 = 0 (mod 2)
# 37 . 86313259 = 0 (mod 2)
# 37 . 86315840 = 0 (mod 2)
# 37 . 86469246 = 0 (mod 2)
# 37 . 86620987 = 0 (mod 2)
# 37 . 87452890 = 0 (mod 2)
# 37 . 87616157 = 0 (mod 2)
# 37 . 87641700 = 0 (mod 2)
# 37 . 87740101 = 0 (mod 2)
# 37 . 87812690 = 0 (mod 2)
# 37 . 87895009 = 0 (mod 2)
# 37 . 87997049 = 0 (mod 2)
# 37 . 87998643 = 0 (mod 2)
# 37 . 88054808 = 0 (mod 2)
# 37 . 88123515 = 0 (mod 2)
# 37 . 88458403 = 0 (mod 2)
# 37 . 88492631 = 0 (mod 2)
# 37 . 88668053 = 0 (mod 2)
# 37 . 88804846 = 0 (mod 2)
# 37 . 88899886 = 0 (mod 2)
# 37 . 88909998 = 0 (mod 2)
# 37 . 88928510 = 0 (mod 2)
# 37 . 88976855 = 0 (mod 2)
# 37 . 88990830 = 0 (mod 2)
# 37 . 89194959 = 0 (mod 2)
# 37 . 89282548 = 0 (mod 2)
# 37 . 89296180 = 0 (mod 2)
# 37 . 89423431 = 0 (mod 2)
# 37 . 89464706 = 0 (mod 2)
# 37 . 89497313 = 0 (mod 2)
# 37 . 89511137 = 0 (mod 2)
# 37 . 89560683 = 0 (mod 2)
# 37 . 89797540 = 0 (mod 2)
# 37 . 89867110 = 0 (mod 2)
# 37 . 89889365 = 0 (mod 2)
# 37 . 89913415 = 0 (mod 2)
# 37 . 89917236 = 0 (mod 2)
# 37 . 89927002 = 0 (mod 2)
# 37 . 90044122 = 0 (mod 2)
# 37 . 90285948 = 0 (mod 2)
# 37 . 90320719 = 0 (mod 2)
# 37 . 90419182 = 0 (mod 2)
# 37 . 90786066 = 0 (mod 2)
# 37 . 91012411 = 0 (mod 2)
# 37 . 91263484 = 0 (mod 2)
# 37 . 91434242 = 0 (mod 2)
# 37 . 91612915 = 0 (mod 2)
# 37 . 91644946 = 0 (mod 2)
# 37 . 92015091 = 0 (mod 2)
# 37 . 92140022 = 0 (mod 2)
# 37 . 92216023 = 0 (mod 2)
# 37 . 92228127 = 0 (mod 2)
# 37 . 92242333 = 0 (mod 2)
# 37 . 92249193 = 0 (mod 2)
# 37 . 92255147 = 0 (mod 2)
# 37 . 92274240 = 0 (mod 2)
# 37 . 92333732 = 0 (mod 2)
# 37 . 92356565 = 0 (mod 2)
# 37 . 92451602 = 0 (mod 2)
# 37 . 92460598 = 0 (mod 2)
# 37 . 92645356 = 0 (mod 2)
# 37 . 92728328 = 0 (mod 2)
# 37 . 92894121 = 0 (mod 2)
# 37 . 92941208 = 0 (mod 2)
# 37 . 93134769 = 0 (mod 2)
# 37 . 93173433 = 0 (mod 2)
# 37 . 93190213 = 0 (mod 2)
# 37 . 93353496 = 0 (mod 2)
# 37 . 93543173 = 0 (mod 2)
# 37 . 93679662 = 0 (mod 2)
# 37 . 93698916 = 0 (mod 2)
# 37 . 93784144 = 0 (mod 2)
# 37 . 93807562 = 0 (mod 2)
# 37 . 94255765 = 0 (mod 2)
# 37 . 94277553 = 0 (mod 2)
# 37 . 94692265 = 0 (mod 2)
# 37 . 94713907 = 0 (mod 2)
# 37 . 94756257 = 0 (mod 2)
# 37 . 95190418 = 0 (mod 2)
# 37 . 95238999 = 0 (mod 2)
# 37 . 95411635 = 0 (mod 2)
# 37 . 95575985 = 0 (mod 2)
# 37 . 95733820 = 0 (mod 2)
# 37 . 95903170 = 0 (mod 2)
# 37 . 95908476 = 0 (mod 2)
# 37 . 96026915 = 0 (mod 2)
# 37 . 96039969 = 0 (mod 2)
# 37 . 96163855 = 0 (mod 2)
# 37 . 96187981 = 0 (mod 2)
# 37 . 96609966 = 0 (mod 2)
# 37 . 96803574 = 0 (mod 2)
# 37 . 96848210 = 0 (mod 2)
# 37 . 97129669 = 0 (mod 2)
# 37 . 97232382 = 0 (mod 2)
# 37 . 97350001 = 0 (mod 2)
# 37 . 97377309 = 0 (mod 2)
# 37 . 97466411 = 0 (mod 2)
# 37 . 97548677 = 0 (mod 2)
# 37 . 97631014 = 0 (mod 2)
# 37 . 97645753 = 0 (mod 2)
# 37 . 97785972 = 0 (mod 2)
# 37 . 97817431 = 0 (mod 2)
# 37 . 97874586 = 0 (mod 2)
# 37 . 97938985 = 0 (mod 2)
# 37 . 97974725 = 0 (mod 2)
# 37 . 97996373 = 0 (mod 2)
# 37 . 98233387 = 0 (mod 2)
# 37 . 98259906 = 0 (mod 2)
# 37 . 98307886 = 0 (mod 2)
# 37 . 98348573 = 0 (mod 2)
# 37 . 98433743 = 0 (mod 2)
# 37 . 98474172 = 0 (mod 2)
# 37 . 98529311 = 0 (mod 2)
# 37 . 99226276 = 0 (mod 2)
# 37 . 99358349 = 0 (mod 2)
# 37 . 99382431 = 0 (mod 2)
# 37 . 99422218 = 0 (mod 2)
# 37 . 99544208 = 0 (mod 2)
# 37 . 99565670 = 0 (mod 2)
# 37 . 99650386 = 0 (mod 2)
# 37 . 99699574 = 0 (mod 2)
# 37 . 99722350 = 0 (mod 2)
# 37 . 99731948 = 0 (mod 2)
# 37 . 99738768 = 0 (mod 2)
# 37 . 99846499 = 0 (mod 2)
# 37 . 99962442 = 0 (mod 2)
# 37 . 100031923 = 0 (mod 2)
# 37 . 100174651 = 0 (mod 2)
# 37 . 100238087 = 0 (mod 2)
# 37 . 100601974 = 0 (mod 2)
# 37 . 100820485 = 0 (mod 2)
# 37 . 100949876 = 0 (mod 2)
# 37 . 101062715 = 0 (mod 2)
# 37 . 101100854 = 0 (mod 2)
# 37 . 101118407 = 0 (mod 2)
# 37 . 101184415 = 0 (mod 2)
# 37 . 101377613 = 0 (mod 2)
# 37 . 101444888 = 0 (mod 2)
# 37 . 101543125 = 0 (mod 2)
# 37 . 101658005 = 0 (mod 2)
# 37 . 101734513 = 0 (mod 2)
# 37 . 101750702 = 0 (mod 2)
# 37 . 101864811 = 0 (mod 2)
# 37 . 102007370 = 0 (mod 2)
# 37 . 102068959 = 0 (mod 2)
# 37 . 102074752 = 0 (mod 2)
# 37 . 102109803 = 0 (mod 2)
# 37 . 102138589 = 0 (mod 2)
# 37 . 102169198 = 0 (mod 2)
# 37 . 102333831 = 0 (mod 2)
# 37 . 102344538 = 0 (mod 2)
# 37 . 102426091 = 0 (mod 2)
# 37 . 102521214 = 0 (mod 2)
# 37 . 102522527 = 0 (mod 2)
# 37 . 102523937 = 0 (mod 2)
# 37 . 103029655 = 0 (mod 2)
# 37 . 103109394 = 0 (mod 2)
# 37 . 103136474 = 0 (mod 2)
# 37 . 103452040 = 0 (mod 2)
# 37 . 103502249 = 0 (mod 2)
# 37 . 103556907 = 0 (mod 2)
# 37 . 103566204 = 0 (mod 2)
# 37 . 103673560 = 0 (mod 2)
# 37 . 103688756 = 0 (mod 2)
# 37 . 103874286 = 0 (mod 2)
# 37 . 103897119 = 0 (mod 2)
# 37 . 103929022 = 0 (mod 2)
# 37 . 103997959 = 0 (mod 2)
# 37 . 103999109 = 0 (mod 2)
# 37 . 104060020 = 0 (mod 2)
# 37 . 104137498 = 0 (mod 2)
# 37 . 104426795 = 0 (mod 2)
# 37 . 104465851 = 0 (mod 2)
# 37 . 104683783 = 0 (mod 2)
# 37 . 104704998 = 0 (mod 2)
# 37 . 104738581 = 0 (mod 2)
# 37 . 104741548 = 0 (mod 2)
# 37 . 104859510 = 0 (mod 2)
# 37 . 105260687 = 0 (mod 2)
# 37 . 105266548 = 0 (mod 2)
# 37 . 105501255 = 0 (mod 2)
# 37 . 105538923 = 0 (mod 2)
# 37 . 105618397 = 0 (mod 2)
# 37 . 105650609 = 0 (mod 2)
# 37 . 105756003 = 0 (mod 2)
# 37 . 105797049 = 0 (mod 2)
# 37 . 105851138 = 0 (mod 2)
# 37 . 105917094 = 0 (mod 2)
# 37 . 105924220 = 0 (mod 2)
# 37 . 105954973 = 0 (mod 2)
# 37 . 106148373 = 0 (mod 2)
# 37 . 106472681 = 0 (mod 2)
# 37 . 106530238 = 0 (mod 2)
# 37 . 106689693 = 0 (mod 2)
# 37 . 106698412 = 0 (mod 2)
# 37 . 106832456 = 0 (mod 2)
# 37 . 106847918 = 0 (mod 2)
# 37 . 107220393 = 0 (mod 2)
# 37 . 107319943 = 0 (mod 2)
# 37 . 107632124 = 0 (mod 2)
# 37 . 107638718 = 0 (mod 2)
# 37 . 108118866 = 0 (mod 2)
# 37 . 108140810 = 0 (mod 2)
# 37 . 108181742 = 0 (mod 2)
# 37 . 108241045 = 0 (mod 2)
# 37 . 108243302 = 0 (mod 2)
# 37 . 108259141 = 0 (mod 2)
# 37 . 108261473 = 0 (mod 2)
# 37 . 108624856 = 0 (mod 2)
# 37 . 108649989 = 0 (mod 2)
# 37 . 108802002 = 0 (mod 2)
# 37 . 108947904 = 0 (mod 2)
# 37 . 109098378 = 0 (mod 2)
# 37 . 109134687 = 0 (mod 2)
# 37 . 109218558 = 0 (mod 2)
# 37 . 109243272 = 0 (mod 2)
# 37 . 109323635 = 0 (mod 2)
# 37 . 109454497 = 0 (mod 2)
# 37 . 109495409 = 0 (mod 2)
# 37 . 109526001 = 0 (mod 2)
# 37 . 109659392 = 0 (mod 2)
# 37 . 109737780 = 0 (mod 2)
# 37 . 109823325 = 0 (mod 2)
# 37 . 109964831 = 0 (mod 2)
# 37 . 110015675 = 0 (mod 2)
# 37 . 110031075 = 0 (mod 2)
# 37 . 110084859 = 0 (mod 2)
# 37 . 110452352 = 0 (mod 2)
# 37 . 110466634 = 0 (mod 2)
# 37 . 110482527 = 0 (mod 2)
# 37 . 110630677 = 0 (mod 2)
# 37 . 110794337 = 0 (mod 2)
# 37 . 110864254 = 0 (mod 2)
# 37 . 110895156 = 0 (mod 2)
# 37 . 110954731 = 0 (mod 2)
# 37 . 111168182 = 0 (mod 2)
# 37 . 111194676 = 0 (mod 2)
# 37 . 111229420 = 0 (mod 2)
# 37 . 111364874 = 0 (mod 2)
# 37 . 111493597 = 0 (mod 2)
# 37 . 111657858 = 0 (mod 2)
# 37 . 111673991 = 0 (mod 2)
# 37 . 111904016 = 0 (mod 2)
# 37 . 111945393 = 0 (mod 2)
# 37 . 112205942 = 0 (mod 2)
# 37 . 112208527 = 0 (mod 2)
# 37 . 112222905 = 0 (mod 2)
# 37 . 112322333 = 0 (mod 2)
# 37 . 112357399 = 0 (mod 2)
# 37 . 112559711 = 0 (mod 2)
# 37 . 112672594 = 0 (mod 2)
# 37 . 112837099 = 0 (mod 2)
# 37 . 113039163 = 0 (mod 2)
# 37 . 113581341 = 0 (mod 2)
# 37 . 113581381 = 0 (mod 2)
# 37 . 113638338 = 0 (mod 2)
# 37 . 113655432 = 0 (mod 2)
# 37 . 113727232 = 0 (mod 2)
# 37 . 113751422 = 0 (mod 2)
# 37 . 113762235 = 0 (mod 2)
# 37 . 113765054 = 0 (mod 2)
# 37 . 114042227 = 0 (mod 2)
# 37 . 114072300 = 0 (mod 2)
# 37 . 114104007 = 0 (mod 2)
# 37 . 114135211 = 0 (mod 2)
# 37 . 114388872 = 0 (mod 2)
# 37 . 114461197 = 0 (mod 2)
# 37 . 114477044 = 0 (mod 2)
# 37 . 114541868 = 0 (mod 2)
# 37 . 114662272 = 0 (mod 2)
# 37 . 114803328 = 0 (mod 2)
# 37 . 114926023 = 0 (mod 2)
# 37 . 114932055 = 0 (mod 2)
# 37 . 114939845 = 0 (mod 2)
# 37 . 114985324 = 0 (mod 2)
# 37 . 115004112 = 0 (mod 2)
# 37 . 115115430 = 0 (mod 2)
# 37 . 115216210 = 0 (mod 2)
# 37 . 115245655 = 0 (mod 2)
# 37 . 115364674 = 0 (mod 2)
# 37 . 115413182 = 0 (mod 2)
# 37 . 115488664 = 0 (mod 2)
# 37 . 115699254 = 0 (mod 2)
# 37 . 115750323 = 0 (mod 2)
# 37 . 115834601 = 0 (mod 2)
# 37 . 116160474 = 0 (mod 2)
# 37 . 116270457 = 0 (mod 2)
# 37 . 116343788 = 0 (mod 2)
# 37 . 116375767 = 0 (mod 2)
# 37 . 116385357 = 0 (mod 2)
# 37 . 116519268 = 0 (mod 2)
# 37 . 116532375 = 0 (mod 2)
# 37 . 116569045 = 0 (mod 2)
# 37 . 116589988 = 0 (mod 2)
# 37 . 116729915 = 0 (mod 2)
# 37 . 116825687 = 0 (mod 2)
# 37 . 116871099 = 0 (mod 2)
# 37 . 117134471 = 0 (mod 2)
# 37 . 117237025 = 0 (mod 2)
# 37 . 117333205 = 0 (mod 2)
# 37 . 117586481 = 0 (mod 2)
# 37 . 117730754 = 0 (mod 2)
# 37 . 117751916 = 0 (mod 2)
# 37 . 117795492 = 0 (mod 2)
# 37 . 117889315 = 0 (mod 2)
# 37 . 117905902 = 0 (mod 2)
# 37 . 118106573 = 0 (mod 2)
# 37 . 118335184 = 0 (mod 2)
# 37 . 118452319 = 0 (mod 2)
# 37 . 118467413 = 0 (mod 2)
# 37 . 118563252 = 0 (mod 2)
# 37 . 118579287 = 0 (mod 2)
# 37 . 118605277 = 0 (mod 2)
# 37 . 118670223 = 0 (mod 2)
# 37 . 118688530 = 0 (mod 2)
# 37 . 118800197 = 0 (mod 2)
# 37 . 118830820 = 0 (mod 2)
# 37 . 118830983 = 0 (mod 2)
# 37 . 118891172 = 0 (mod 2)
# 37 . 119105390 = 0 (mod 2)
# 37 . 119164334 = 0 (mod 2)
# 37 . 119185073 = 0 (mod 2)
# 37 . 119230630 = 0 (mod 2)
# 37 . 119300104 = 0 (mod 2)
# 37 . 119358563 = 0 (mod 2)
# 37 . 119441444 = 0 (mod 2)
# 37 . 119625955 = 0 (mod 2)
# 37 . 120012987 = 0 (mod 2)
# 37 . 120039311 = 0 (mod 2)
# 37 . 120058893 = 0 (mod 2)
# 37 . 120153078 = 0 (mod 2)
# 37 . 120223867 = 0 (mod 2)
# 37 . 120493742 = 0 (mod 2)
# 37 . 120573348 = 0 (mod 2)
# 37 . 120688100 = 0 (mod 2)
# 37 . 120885409 = 0 (mod 2)
# 37 . 120888128 = 0 (mod 2)
# 37 . 121176876 = 0 (mod 2)
# 37 . 121467262 = 0 (mod 2)
# 37 . 121487391 = 0 (mod 2)
# 37 . 121572997 = 0 (mod 2)
# 37 . 121606810 = 0 (mod 2)
# 37 . 121625544 = 0 (mod 2)
# 37 . 121766039 = 0 (mod 2)
# 37 . 121793368 = 0 (mod 2)
# 37 . 122033231 = 0 (mod 2)
# 37 . 122097677 = 0 (mod 2)
# 37 . 122111718 = 0 (mod 2)
# 37 . 122124039 = 0 (mod 2)
# 37 . 122244649 = 0 (mod 2)
# 37 . 122337918 = 0 (mod 2)
# 37 . 122469931 = 0 (mod 2)
# 37 . 122526741 = 0 (mod 2)
# 37 . 122647793 = 0 (mod 2)
# 37 . 122856261 = 0 (mod 2)
# 37 . 122879166 = 0 (mod 2)
# 37 . 123040891 = 0 (mod 2)
# 37 . 123088384 = 0 (mod 2)
# 37 . 123147774 = 0 (mod 2)
# 37 . 123165556 = 0 (mod 2)
# 37 . 123169398 = 0 (mod 2)
# 37 . 123188073 = 0 (mod 2)
# 37 . 123225682 = 0 (mod 2)
# 37 . 123294889 = 0 (mod 2)
# 37 . 123352753 = 0 (mod 2)
# 37 . 123353040 = 0 (mod 2)
# 37 . 123484214 = 0 (mod 2)
# 37 . 123787845 = 0 (mod 2)
# 37 . 123853824 = 0 (mod 2)
# 37 . 123879012 = 0 (mod 2)
# 37 . 124136230 = 0 (mod 2)
# 37 . 124183526 = 0 (mod 2)
# 37 . 124321958 = 0 (mod 2)
# 37 . 124323497 = 0 (mod 2)
# 37 . 124356255 = 0 (mod 2)
# 37 . 124420065 = 0 (mod 2)
# 37 . 124746199 = 0 (mod 2)
# 37 . 124814564 = 0 (mod 2)
# 37 . 124982728 = 0 (mod 2)
# 37 . 125055567 = 0 (mod 2)
# 37 . 125079823 = 0 (mod 2)
# 37 . 125122511 = 0 (mod 2)
# 37 . 125215320 = 0 (mod 2)
# 37 . 125267699 = 0 (mod 2)
# 37 . 125320775 = 0 (mod 2)
# 37 . 125539124 = 0 (mod 2)
# 37 . 125593805 = 0 (mod 2)
# 37 . 125807181 = 0 (mod 2)
# 37 . 126074138 = 0 (mod 2)
# 37 . 126141033 = 0 (mod 2)
# 37 . 126213194 = 0 (mod 2)
# 37 . 126399201 = 0 (mod 2)
# 37 . 126881607 = 0 (mod 2)
# 37 . 127067819 = 0 (mod 2)
# 37 . 127071325 = 0 (mod 2)
# 37 . 127100173 = 0 (mod 2)
# 37 . 127178027 = 0 (mod 2)
# 37 . 127180631 = 0 (mod 2)
# 37 . 127307444 = 0 (mod 2)
# 37 . 127660039 = 0 (mod 2)
# 37 . 127758928 = 0 (mod 2)
# 37 . 127884877 = 0 (mod 2)
# 37 . 127912855 = 0 (mod 2)
# 37 . 127930903 = 0 (mod 2)
# 37 . 128007583 = 0 (mod 2)
# 37 . 128367197 = 0 (mod 2)
# 37 . 128473126 = 0 (mod 2)
# 37 . 128474911 = 0 (mod 2)
# 37 . 128557400 = 0 (mod 2)
# 37 . 128612122 = 0 (mod 2)
# 37 . 128723382 = 0 (mod 2)
# 37 . 128754391 = 0 (mod 2)
# 37 . 128870400 = 0 (mod 2)
# 37 . 128922982 = 0 (mod 2)
# 37 . 129129059 = 0 (mod 2)
# 37 . 129159148 = 0 (mod 2)
# 37 . 129407158 = 0 (mod 2)
# 37 . 129685694 = 0 (mod 2)
# 37 . 129700549 = 0 (mod 2)
# 37 . 129755221 = 0 (mod 2)
# 37 . 129791386 = 0 (mod 2)
# 37 . 129912820 = 0 (mod 2)
# 37 . 129920983 = 0 (mod 2)
# 37 . 130042703 = 0 (mod 2)
# 37 . 130117097 = 0 (mod 2)
# 37 . 130183437 = 0 (mod 2)
# 37 . 130365180 = 0 (mod 2)
# 37 . 130378586 = 0 (mod 2)
# 37 . 130685820 = 0 (mod 2)
# 37 . 130718479 = 0 (mod 2)
# 37 . 130723198 = 0 (mod 2)
# 37 . 130734285 = 0 (mod 2)
# 37 . 130797990 = 0 (mod 2)
# 37 . 130829151 = 0 (mod 2)
# 37 . 131286552 = 0 (mod 2)
# 37 . 131503150 = 0 (mod 2)
# 37 . 131532276 = 0 (mod 2)
# 37 . 131643371 = 0 (mod 2)
# 37 . 131688419 = 0 (mod 2)
# 37 . 131713549 = 0 (mod 2)
# 37 . 131753608 = 0 (mod 2)
# 37 . 131781115 = 0 (mod 2)
# 37 . 131796736 = 0 (mod 2)
# 37 . 131888953 = 0 (mod 2)
# 37 . 131934930 = 0 (mod 2)
# 37 . 132000522 = 0 (mod 2)
# 37 . 132059900 = 0 (mod 2)
# 37 . 132150613 = 0 (mod 2)
# 37 . 132168446 = 0 (mod 2)
# 37 . 132223265 = 0 (mod 2)
# 37 . 132451215 = 0 (mod 2)
# 37 . 132756293 = 0 (mod 2)
# 37 . 132966374 = 0 (mod 2)
# 37 . 133064320 = 0 (mod 2)
# 37 . 133127651 = 0 (mod 2)
# 37 . 133148882 = 0 (mod 2)
# 37 . 133171986 = 0 (mod 2)
# 37 . 133181803 = 0 (mod 2)
# 37 . 133242010 = 0 (mod 2)
# 37 . 133490762 = 0 (mod 2)
# 37 . 133688789 = 0 (mod 2)
# 37 . 133748339 = 0 (mod 2)
# 37 . 133855623 = 0 (mod 2)
# 37 . 133910103 = 0 (mod 2)
# 37 . 133922721 = 0 (mod 2)
# 37 . 134032541 = 0 (mod 2)
# 37 . 134199298 = 0 (mod 2)
# 37 . 134264901 = 0 (mod 2)
# 37 . 134316131 = 0 (mod 2)
# 37 . 134538481 = 0 (mod 2)
# 37 . 134600993 = 0 (mod 2)
# 37 . 134657157 = 0 (mod 2)
# 37 . 134660913 = 0 (mod 2)
# 37 . 134718244 = 0 (mod 2)
# 37 . 134723958 = 0 (mod 2)
# 37 . 134863932 = 0 (mod 2)
# 37 . 134940506 = 0 (mod 2)
# 37 . 134989494 = 0 (mod 2)
# 37 . 134991345 = 0 (mod 2)
# 37 . 135123372 = 0 (mod 2)
# 37 . 135226094 = 0 (mod 2)
# 37 . 135299625 = 0 (mod 2)
# 37 . 135355966 = 0 (mod 2)
# 37 . 135412381 = 0 (mod 2)
# 37 . 135480638 = 0 (mod 2)
# 37 . 135498823 = 0 (mod 2)
# 37 . 135610419 = 0 (mod 2)
# 37 . 136265318 = 0 (mod 2)
# 37 . 136310014 = 0 (mod 2)
# 37 . 136363735 = 0 (mod 2)
# 37 . 136497434 = 0 (mod 2)
# 37 . 136540979 = 0 (mod 2)
# 37 . 136554703 = 0 (mod 2)
# 37 . 136625045 = 0 (mod 2)
# 37 . 136638694 = 0 (mod 2)
# 37 . 136638994 = 0 (mod 2)
# 37 . 136749990 = 0 (mod 2)
# 37 . 136760919 = 0 (mod 2)
# 37 . 136886410 = 0 (mod 2)
# 37 . 136949753 = 0 (mod 2)
# 37 . 136967639 = 0 (mod 2)
# 37 . 136974308 = 0 (mod 2)
# 37 . 137145595 = 0 (mod 2)
# 37 . 137288238 = 0 (mod 2)
# 37 . 137381146 = 0 (mod 2)
# 37 . 137484938 = 0 (mod 2)
# 37 . 137502774 = 0 (mod 2)
# 37 . 137725030 = 0 (mod 2)
# 37 . 138043285 = 0 (mod 2)
# 37 . 138152650 = 0 (mod 2)
# 37 . 138213881 = 0 (mod 2)
# 37 . 138314217 = 0 (mod 2)
# 37 . 138366423 = 0 (mod 2)
# 37 . 138534780 = 0 (mod 2)
# 37 . 138548769 = 0 (mod 2)
# 37 . 138634245 = 0 (mod 2)
# 37 . 138647882 = 0 (mod 2)
# 37 . 138773996 = 0 (mod 2)
# 37 . 138835564 = 0 (mod 2)
# 37 . 138881677 = 0 (mod 2)
# 37 . 138921260 = 0 (mod 2)
# 37 . 138953403 = 0 (mod 2)
# 37 . 139259663 = 0 (mod 2)
# 37 . 139345785 = 0 (mod 2)
# 37 . 139513685 = 0 (mod 2)
# 37 . 139516393 = 0 (mod 2)
# 37 . 139564139 = 0 (mod 2)
# 37 . 139609150 = 0 (mod 2)
# 37 . 139650055 = 0 (mod 2)
# 37 . 139690214 = 0 (mod 2)
# 37 . 139751724 = 0 (mod 2)
# 37 . 139764979 = 0 (mod 2)
# 37 . 139782480 = 0 (mod 2)
# 37 . 139800113 = 0 (mod 2)
# 37 . 139819136 = 0 (mod 2)
# 37 . 139991562 = 0 (mod 2)
# 37 . 140211735 = 0 (mod 2)
# 37 . 140225682 = 0 (mod 2)
# 37 . 140329123 = 0 (mod 2)
# 37 . 140429405 = 0 (mod 2)
# 37 . 140495723 = 0 (mod 2)
# 37 . 140497332 = 0 (mod 2)
# 37 . 140603400 = 0 (mod 2)
# 37 . 140616428 = 0 (mod 2)
# 37 . 140702318 = 0 (mod 2)
# 37 . 140829207 = 0 (mod 2)
# 37 . 140842476 = 0 (mod 2)
# 37 . 140905373 = 0 (mod 2)
# 37 . 140966920 = 0 (mod 2)
# 37 . 140981010 = 0 (mod 2)
# 37 . 141112143 = 0 (mod 2)
# 37 . 141161788 = 0 (mod 2)
# 37 . 141191063 = 0 (mod 2)
# 37 . 141301545 = 0 (mod 2)
# 37 . 141493776 = 0 (mod 2)
# 37 . 141607035 = 0 (mod 2)
# 37 . 141618077 = 0 (mod 2)
# 37 . 141636632 = 0 (mod 2)
# 37 . 141748767 = 0 (mod 2)
# 37 . 141885412 = 0 (mod 2)
# 37 . 142021361 = 0 (mod 2)
# 37 . 142078989 = 0 (mod 2)
# 37 . 142108224 = 0 (mod 2)
# 37 . 142191854 = 0 (mod 2)
# 37 . 142357776 = 0 (mod 2)
# 37 . 142518563 = 0 (mod 2)
# 37 . 142629929 = 0 (mod 2)
# 37 . 142685525 = 0 (mod 2)
# 37 . 142687642 = 0 (mod 2)
# 37 . 143300802 = 0 (mod 2)
# 37 . 143317189 = 0 (mod 2)
# 37 . 143478978 = 0 (mod 2)
# 37 . 143533540 = 0 (mod 2)
# 37 . 143772286 = 0 (mod 2)
# 37 . 143891889 = 0 (mod 2)
# 37 . 144112748 = 0 (mod 2)
# 37 . 144170801 = 0 (mod 2)
# 37 . 144249090 = 0 (mod 2)
# 37 . 144344151 = 0 (mod 2)
# 37 . 144612111 = 0 (mod 2)
# 37 . 144649551 = 0 (mod 2)
# 37 . 145201602 = 0 (mod 2)
# 37 . 145510472 = 0 (mod 2)
# 37 . 145611722 = 0 (mod 2)
# 37 . 145709517 = 0 (mod 2)
# 37 . 145973243 = 0 (mod 2)
# 37 . 146180109 = 0 (mod 2)
# 37 . 146555131 = 0 (mod 2)
# 37 . 146570117 = 0 (mod 2)
# 37 . 146619377 = 0 (mod 2)
# 37 . 146681580 = 0 (mod 2)
# 37 . 146706940 = 0 (mod 2)
# 37 . 146783645 = 0 (mod 2)
# 37 . 146875797 = 0 (mod 2)
# 37 . 146879375 = 0 (mod 2)
# 37 . 146936161 = 0 (mod 2)
# 37 . 146955636 = 0 (mod 2)
# 37 . 146980961 = 0 (mod 2)
# 37 . 146994130 = 0 (mod 2)
# 37 . 147004312 = 0 (mod 2)
# 37 . 147097807 = 0 (mod 2)
# 37 . 147399304 = 0 (mod 2)
# 37 . 147718983 = 0 (mod 2)
# 37 . 147892131 = 0 (mod 2)
# 37 . 148081569 = 0 (mod 2)
# 37 . 148285456 = 0 (mod 2)
# 37 . 148334146 = 0 (mod 2)
# 37 . 148377198 = 0 (mod 2)
# 37 . 148600213 = 0 (mod 2)
# 37 . 148618629 = 0 (mod 2)
# 37 . 148851515 = 0 (mod 2)
# 37 . 149224105 = 0 (mod 2)
# 37 . 149328889 = 0 (mod 2)
# 37 . 149609017 = 0 (mod 2)
# 37 . 149645376 = 0 (mod 2)
# 37 . 149675656 = 0 (mod 2)
# 37 . 150076744 = 0 (mod 2)
# 37 . 150081254 = 0 (mod 2)
# 37 . 150202589 = 0 (mod 2)
# 37 . 150261035 = 0 (mod 2)
# 37 . 150445648 = 0 (mod 2)
# 37 . 150455915 = 0 (mod 2)
# 37 . 150536517 = 0 (mod 2)
# 37 . 150573676 = 0 (mod 2)
# 37 . 150668304 = 0 (mod 2)
# 37 . 150822515 = 0 (mod 2)
# 37 . 151002297 = 0 (mod 2)
# 37 . 151082297 = 0 (mod 2)
# 37 . 151375460 = 0 (mod 2)
# 37 . 151455578 = 0 (mod 2)
# 37 . 151613189 = 0 (mod 2)
# 37 . 151638379 = 0 (mod 2)
# 37 . 151957061 = 0 (mod 2)
# 37 . 152016021 = 0 (mod 2)
# 37 . 152022907 = 0 (mod 2)
# 37 . 152417457 = 0 (mod 2)
# 37 . 152872827 = 0 (mod 2)
# 37 . 152876103 = 0 (mod 2)
# 37 . 153199420 = 0 (mod 2)
# 37 . 153333405 = 0 (mod 2)
# 37 . 153388186 = 0 (mod 2)
# 37 . 153407846 = 0 (mod 2)
# 37 . 153420342 = 0 (mod 2)
# 37 . 153708851 = 0 (mod 2)
# 37 . 153912868 = 0 (mod 2)
# 37 . 153982725 = 0 (mod 2)
# 37 . 154096581 = 0 (mod 2)
# 37 . 154208704 = 0 (mod 2)
# 37 . 154218601 = 0 (mod 2)
# 37 . 154470113 = 0 (mod 2)
# 37 . 154532862 = 0 (mod 2)
# 37 . 154655588 = 0 (mod 2)
# 37 . 154661330 = 0 (mod 2)
# 37 . 155146163 = 0 (mod 2)
# 37 . 155284595 = 0 (mod 2)
# 37 . 155383468 = 0 (mod 2)
# 37 . 155428662 = 0 (mod 2)
# 37 . 155447114 = 0 (mod 2)
# 37 . 155479506 = 0 (mod 2)
# 37 . 155509873 = 0 (mod 2)
# 37 . 155570414 = 0 (mod 2)
# 37 . 155598608 = 0 (mod 2)
# 37 . 155701350 = 0 (mod 2)
# 37 . 155874829 = 0 (mod 2)
# 37 . 155893555 = 0 (mod 2)
# 37 . 155902374 = 0 (mod 2)
# 37 . 156222530 = 0 (mod 2)
# 37 . 156334943 = 0 (mod 2)
# 37 . 156343194 = 0 (mod 2)
# 37 . 156914684 = 0 (mod 2)
# 37 . 157015921 = 0 (mod 2)
# 37 . 157265984 = 0 (mod 2)
# 37 . 157347672 = 0 (mod 2)
# 37 . 157394228 = 0 (mod 2)
# 37 . 157614062 = 0 (mod 2)
# 37 . 157746814 = 0 (mod 2)
# 37 . 158011032 = 0 (mod 2)
# 37 . 158178760 = 0 (mod 2)
# 37 . 158261172 = 0 (mod 2)
# 37 . 158312171 = 0 (mod 2)
# 37 . 158354017 = 0 (mod 2)
# 37 . 158400770 = 0 (mod 2)
# 37 . 158472878 = 0 (mod 2)
# 37 . 158473785 = 0 (mod 2)
# 37 . 158548103 = 0 (mod 2)
# 37 . 158670146 = 0 (mod 2)
# 37 . 158878362 = 0 (mod 2)
# 37 . 158978127 = 0 (mod 2)
# 37 . 159193951 = 0 (mod 2)
# 37 . 159201654 = 0 (mod 2)
# 37 . 159556701 = 0 (mod 2)
# 37 . 159632216 = 0 (mod 2)
# 37 . 159692907 = 0 (mod 2)
# 37 . 159779861 = 0 (mod 2)
# 37 . 159861876 = 0 (mod 2)
# 37 . 159869361 = 0 (mod 2)
# 37 . 159938200 = 0 (mod 2)
# 37 . 159978420 = 0 (mod 2)
# 37 . 160044332 = 0 (mod 2)
# 37 . 160049635 = 0 (mod 2)
# 37 . 160096706 = 0 (mod 2)
# 37 . 160151867 = 0 (mod 2)
# 37 . 160321892 = 0 (mod 2)
# 37 . 160337534 = 0 (mod 2)
# 37 . 160349750 = 0 (mod 2)
# 37 . 160442468 = 0 (mod 2)
# 37 . 160606457 = 0 (mod 2)
# 37 . 160627282 = 0 (mod 2)
# 37 . 160645550 = 0 (mod 2)
# 37 . 160762099 = 0 (mod 2)
# 37 . 160815114 = 0 (mod 2)
# 37 . 160833137 = 0 (mod 2)
# 37 . 160913772 = 0 (mod 2)
# 37 . 160983432 = 0 (mod 2)
# 37 . 161239367 = 0 (mod 2)
# 37 . 161332396 = 0 (mod 2)
# 37 . 161424325 = 0 (mod 2)
# 37 . 161438725 = 0 (mod 2)
# 37 . 161585454 = 0 (mod 2)
# 37 . 161640576 = 0 (mod 2)
# 37 . 161855907 = 0 (mod 2)
# 37 . 161905818 = 0 (mod 2)
# 37 . 161936208 = 0 (mod 2)
# 37 . 161991709 = 0 (mod 2)
# 37 . 162215729 = 0 (mod 2)
# 37 . 162481459 = 0 (mod 2)
# 37 . 162564864 = 0 (mod 2)
# 37 . 162654772 = 0 (mod 2)
# 37 . 162838557 = 0 (mod 2)
# 37 . 162851162 = 0 (mod 2)
# 37 . 162919803 = 0 (mod 2)
# 37 . 162923820 = 0 (mod 2)
# 37 . 162946381 = 0 (mod 2)
# 37 . 163021491 = 0 (mod 2)
# 37 . 163180537 = 0 (mod 2)
# 37 . 163210862 = 0 (mod 2)
# 37 . 163522430 = 0 (mod 2)
# 37 . 163884083 = 0 (mod 2)
# 37 . 164022871 = 0 (mod 2)
# 37 . 164077653 = 0 (mod 2)
# 37 . 164078068 = 0 (mod 2)
# 37 . 164099500 = 0 (mod 2)
# 37 . 164230206 = 0 (mod 2)
# 37 . 164392898 = 0 (mod 2)
# 37 . 164466806 = 0 (mod 2)
# 37 . 164482386 = 0 (mod 2)
# 37 . 164522662 = 0 (mod 2)
# 37 . 164658486 = 0 (mod 2)
# 37 . 164909642 = 0 (mod 2)
# 37 . 165015468 = 0 (mod 2)
# 37 . 165026629 = 0 (mod 2)
# 37 . 165467136 = 0 (mod 2)
# 37 . 165576066 = 0 (mod 2)
# 37 . 165577304 = 0 (mod 2)
# 37 . 165662635 = 0 (mod 2)
# 37 . 165829957 = 0 (mod 2)
# 37 . 165922143 = 0 (mod 2)
# 37 . 165991406 = 0 (mod 2)
# 37 . 166069859 = 0 (mod 2)
# 37 . 166121362 = 0 (mod 2)
# 37 . 166361621 = 0 (mod 2)
# 37 . 166404941 = 0 (mod 2)
# 37 . 166776185 = 0 (mod 2)
# 37 . 166815347 = 0 (mod 2)
# 37 . 166820743 = 0 (mod 2)
# 37 . 166889994 = 0 (mod 2)
# 37 . 167097723 = 0 (mod 2)
# 37 . 167236042 = 0 (mod 2)
# 37 . 167257546 = 0 (mod 2)
# 37 . 167375754 = 0 (mod 2)
# 37 . 167377362 = 0 (mod 2)
# 37 . 167428467 = 0 (mod 2)
# 37 . 167470966 = 0 (mod 2)
# 37 . 167637448 = 0 (mod 2)
# 37 . 167826335 = 0 (mod 2)
# 37 . 167834425 = 0 (mod 2)
# 37 . 167861645 = 0 (mod 2)
# 37 . 167924390 = 0 (mod 2)
# 37 . 167983982 = 0 (mod 2)
# 37 . 168072661 = 0 (mod 2)
# 37 . 168354659 = 0 (mod 2)
# 37 . 168382405 = 0 (mod 2)
# 37 . 168447785 = 0 (mod 2)
# 37 . 168507335 = 0 (mod 2)
# 37 . 168742769 = 0 (mod 2)
# 37 . 168759053 = 0 (mod 2)
# 37 . 168949274 = 0 (mod 2)
# 37 . 168988401 = 0 (mod 2)
# 37 . 169012790 = 0 (mod 2)
# 37 . 169061512 = 0 (mod 2)
# 37 . 169109748 = 0 (mod 2)
# 37 . 169111411 = 0 (mod 2)
# 37 . 169154748 = 0 (mod 2)
# 37 . 169215501 = 0 (mod 2)
# 37 . 169228670 = 0 (mod 2)
# 37 . 169259487 = 0 (mod 2)
# 37 . 169332503 = 0 (mod 2)
# 37 . 169697221 = 0 (mod 2)
# 37 . 169965870 = 0 (mod 2)
# 37 . 170202609 = 0 (mod 2)
# 37 . 170489871 = 0 (mod 2)
# 37 . 170503404 = 0 (mod 2)
# 37 . 170507791 = 0 (mod 2)
# 37 . 170534991 = 0 (mod 2)
# 37 . 170543606 = 0 (mod 2)
# 37 . 170574160 = 0 (mod 2)
# 37 . 170856060 = 0 (mod 2)
# 37 . 170865334 = 0 (mod 2)
# 37 . 170876557 = 0 (mod 2)
# 37 . 170898887 = 0 (mod 2)
# 37 . 171014850 = 0 (mod 2)
# 37 . 171304264 = 0 (mod 2)
# 37 . 171415575 = 0 (mod 2)
# 37 . 171447888 = 0 (mod 2)
# 37 . 171605973 = 0 (mod 2)
# 37 . 171637848 = 0 (mod 2)
# 37 . 171848474 = 0 (mod 2)
# 37 . 171859753 = 0 (mod 2)
# 37 . 172041318 = 0 (mod 2)
# 37 . 172091446 = 0 (mod 2)
# 37 . 172096937 = 0 (mod 2)
# 37 . 172251499 = 0 (mod 2)
# 37 . 172420654 = 0 (mod 2)
# 37 . 172704299 = 0 (mod 2)
# 37 . 172732431 = 0 (mod 2)
# 37 . 172865403 = 0 (mod 2)
# 37 . 173096853 = 0 (mod 2)
# 37 . 173132546 = 0 (mod 2)
# 37 . 173233003 = 0 (mod 2)
# 37 . 173310090 = 0 (mod 2)
# 37 . 173360252 = 0 (mod 2)
# 37 . 173404994 = 0 (mod 2)
# 37 . 173709832 = 0 (mod 2)
# 37 . 173828165 = 0 (mod 2)
# 37 . 174216292 = 0 (mod 2)
# 37 . 174253235 = 0 (mod 2)
# 37 . 174302566 = 0 (mod 2)
# 37 . 174317151 = 0 (mod 2)
# 37 . 174344607 = 0 (mod 2)
# 37 . 174436278 = 0 (mod 2)
# 37 . 174547655 = 0 (mod 2)
# 37 . 174608093 = 0 (mod 2)
# 37 . 174714637 = 0 (mod 2)
# 37 . 174867364 = 0 (mod 2)
# 37 . 174971221 = 0 (mod 2)
# 37 . 175094846 = 0 (mod 2)
# 37 . 175153337 = 0 (mod 2)
# 37 . 175176130 = 0 (mod 2)
# 37 . 175237591 = 0 (mod 2)
# 37 . 175633538 = 0 (mod 2)
# 37 . 175643966 = 0 (mod 2)
# 37 . 175664892 = 0 (mod 2)
# 37 . 175693795 = 0 (mod 2)
# 37 . 175708306 = 0 (mod 2)
# 37 . 175769955 = 0 (mod 2)
# 37 . 175823943 = 0 (mod 2)
# 37 . 175830485 = 0 (mod 2)
# 37 . 175966198 = 0 (mod 2)
# 37 . 176058890 = 0 (mod 2)
# 37 . 176071972 = 0 (mod 2)
# 37 . 176221320 = 0 (mod 2)
# 37 . 176319173 = 0 (mod 2)
# 37 . 176403252 = 0 (mod 2)
# 37 . 176436480 = 0 (mod 2)
# 37 . 176465559 = 0 (mod 2)
# 37 . 176473797 = 0 (mod 2)
# 37 . 176561505 = 0 (mod 2)
# 37 . 176566969 = 0 (mod 2)
# 37 . 176602145 = 0 (mod 2)
# 37 . 176609039 = 0 (mod 2)
# 37 . 176612498 = 0 (mod 2)
# 37 . 176652475 = 0 (mod 2)
# 37 . 176669876 = 0 (mod 2)
# 37 . 176670515 = 0 (mod 2)
# 37 . 176722048 = 0 (mod 2)
# 37 . 176817562 = 0 (mod 2)
# 37 . 176872213 = 0 (mod 2)
# 37 . 176923280 = 0 (mod 2)
# 37 . 176940718 = 0 (mod 2)
# 37 . 177055746 = 0 (mod 2)
# 37 . 177088085 = 0 (mod 2)
# 37 . 177264819 = 0 (mod 2)
# 37 . 177345379 = 0 (mod 2)
# 37 . 177484061 = 0 (mod 2)
# 37 . 177487554 = 0 (mod 2)
# 37 . 177509528 = 0 (mod 2)
# 37 . 177626686 = 0 (mod 2)
# 37 . 177870426 = 0 (mod 2)
# 37 . 178005225 = 0 (mod 2)
# 37 . 178077645 = 0 (mod 2)
# 37 . 178123791 = 0 (mod 2)
# 37 . 178415170 = 0 (mod 2)
# 37 . 178428921 = 0 (mod 2)
# 37 . 178581266 = 0 (mod 2)
# 37 . 178583119 = 0 (mod 2)
# 37 . 178619408 = 0 (mod 2)
# 37 . 178671645 = 0 (mod 2)
# 37 . 178904678 = 0 (mod 2)
# 37 . 179391639 = 0 (mod 2)
# 37 . 179583550 = 0 (mod 2)
# 37 . 179976804 = 0 (mod 2)
# 37 . 180020952 = 0 (mod 2)
# 37 . 180028765 = 0 (mod 2)
# 37 . 180069609 = 0 (mod 2)
# 37 . 180176799 = 0 (mod 2)
# 37 . 180265518 = 0 (mod 2)
# 37 . 180271450 = 0 (mod 2)
# 37 . 180370980 = 0 (mod 2)
# 37 . 180577316 = 0 (mod 2)
# 37 . 180587735 = 0 (mod 2)
# 37 . 180609797 = 0 (mod 2)
# 37 . 180709512 = 0 (mod 2)
# 37 . 180864455 = 0 (mod 2)
# 37 . 180937170 = 0 (mod 2)
# 37 . 181048100 = 0 (mod 2)
# 37 . 181073459 = 0 (mod 2)
# 37 . 181412888 = 0 (mod 2)
# 37 . 181514033 = 0 (mod 2)
# 37 . 181542588 = 0 (mod 2)
# 37 . 181576433 = 0 (mod 2)
# 37 . 181646572 = 0 (mod 2)
# 37 . 181715492 = 0 (mod 2)
# 37 . 182016563 = 0 (mod 2)
# 37 . 182038864 = 0 (mod 2)
# 37 . 182096407 = 0 (mod 2)
# 37 . 182139387 = 0 (mod 2)
# 37 . 182283290 = 0 (mod 2)
# 37 . 182405438 = 0 (mod 2)
# 37 . 182461033 = 0 (mod 2)
# 37 . 182520072 = 0 (mod 2)
# 37 . 182570534 = 0 (mod 2)
# 37 . 182691963 = 0 (mod 2)
# 37 . 182843052 = 0 (mod 2)
# 37 . 183406523 = 0 (mod 2)
# 37 . 183432054 = 0 (mod 2)
# 37 . 183678892 = 0 (mod 2)
# 37 . 184083132 = 0 (mod 2)
# 37 . 184087952 = 0 (mod 2)
# 37 . 184254076 = 0 (mod 2)
# 37 . 184269734 = 0 (mod 2)
# 37 . 184297083 = 0 (mod 2)
# 37 . 184401949 = 0 (mod 2)
# 37 . 184505119 = 0 (mod 2)
# 37 . 184641167 = 0 (mod 2)
# 37 . 184756701 = 0 (mod 2)
# 37 . 184780941 = 0 (mod 2)
# 37 . 184954831 = 0 (mod 2)
# 37 . 185015696 = 0 (mod 2)
# 37 . 185077620 = 0 (mod 2)
# 37 . 185094479 = 0 (mod 2)
# 37 . 185259344 = 0 (mod 2)
# 37 . 185705794 = 0 (mod 2)
# 37 . 185820652 = 0 (mod 2)
# 37 . 185912817 = 0 (mod 2)
# 37 . 185913730 = 0 (mod 2)
# 37 . 185941581 = 0 (mod 2)
# 37 . 185958168 = 0 (mod 2)
# 37 . 186181450 = 0 (mod 2)
# 37 . 186284203 = 0 (mod 2)
# 37 . 186289707 = 0 (mod 2)
# 37 . 186302805 = 0 (mod 2)
# 37 . 186348406 = 0 (mod 2)
# 37 . 186379928 = 0 (mod 2)
# 37 . 186388245 = 0 (mod 2)
# 37 . 186461266 = 0 (mod 2)
# 37 . 186465084 = 0 (mod 2)
# 37 . 186507733 = 0 (mod 2)
# 37 . 186552929 = 0 (mod 2)
# 37 . 186569298 = 0 (mod 2)
# 37 . 187011728 = 0 (mod 2)
# 37 . 187091828 = 0 (mod 2)
# 37 . 187229822 = 0 (mod 2)
# ...
# 37 . 1015588546 = 0 (mod 2)
# 37 . 1015658236 = 0 (mod 2)
# 37 . 1015740639 = 0 (mod 2)
# 37 . 1015898081 = 0 (mod 2)
# 37 . 1015928865 = 0 (mod 2)
# 37 . 1016006032 = 0 (mod 2)
# 37 . 1016141215 = 0 (mod 2)
# 37 . 1016277202 = 0 (mod 2)
# 37 . 1016604587 = 0 (mod 2)
# 37 . 1016617452 = 0 (mod 2)
# 37 . 1016630715 = 0 (mod 2)
# 37 . 1016670451 = 0 (mod 2)
# 37 . 1017009234 = 0 (mod 2)
# 37 . 1017032965 = 0 (mod 2)
# 37 . 1017330211 = 0 (mod 2)
# 37 . 1017342999 = 0 (mod 2)
# 37 . 1017405620 = 0 (mod 2)
# 37 . 1017421146 = 0 (mod 2)
# 37 . 1017531231 = 0 (mod 2)
# 37 . 1017580488 = 0 (mod 2)
# 37 . 1017672883 = 0 (mod 2)
# 37 . 1017805281 = 0 (mod 2)
# 37 . 1017885486 = 0 (mod 2)
# 37 . 1018176164 = 0 (mod 2)
# 37 . 1018738325 = 0 (mod 2)
# 37 . 1018749611 = 0 (mod 2)
# 37 . 1018897759 = 0 (mod 2)
# 37 . 1019054482 = 0 (mod 2)
# 37 . 1019110012 = 0 (mod 2)
# 37 . 1019222758 = 0 (mod 2)
# 37 . 1019238080 = 0 (mod 2)
# 37 . 1019397087 = 0 (mod 2)
# 37 . 1019425296 = 0 (mod 2)
# 37 . 1019572526 = 0 (mod 2)
# 37 . 1019723736 = 0 (mod 2)
# 37 . 1019739691 = 0 (mod 2)
# 37 . 1019747717 = 0 (mod 2)
# 37 . 1019774786 = 0 (mod 2)
# 37 . 1019967112 = 0 (mod 2)
# 37 . 1019984934 = 0 (mod 2)
# 37 . 1020022282 = 0 (mod 2)
# 37 . 1020061975 = 0 (mod 2)
# 37 . 1020167923 = 0 (mod 2)
# 37 . 1020176937 = 0 (mod 2)
# 37 . 1020224507 = 0 (mod 2)
# 37 . 1020225699 = 0 (mod 2)
# 37 . 1020266211 = 0 (mod 2)
# 37 . 1020284490 = 0 (mod 2)
# 37 . 1020310817 = 0 (mod 2)
# 37 . 1020408766 = 0 (mod 2)
# 37 . 1020543895 = 0 (mod 2)
# 37 . 1020931600 = 0 (mod 2)
# 37 . 1021061698 = 0 (mod 2)
# 37 . 1021398168 = 0 (mod 2)
# 37 . 1021583721 = 0 (mod 2)
# 37 . 1021655760 = 0 (mod 2)
# 37 . 1021738271 = 0 (mod 2)
# 37 . 1021780585 = 0 (mod 2)
# 37 . 1021817198 = 0 (mod 2)
# 37 . 1021835196 = 0 (mod 2)
# 37 . 1021836557 = 0 (mod 2)
# 37 . 1021914598 = 0 (mod 2)
# 37 . 1022118651 = 0 (mod 2)
# 37 . 1022247609 = 0 (mod 2)
# 37 . 1022274742 = 0 (mod 2)
# 37 . 1022518026 = 0 (mod 2)
# 37 . 1022521377 = 0 (mod 2)
# 37 . 1022531343 = 0 (mod 2)
# 37 . 1022560812 = 0 (mod 2)
# 37 . 1022699636 = 0 (mod 2)
# 37 . 1022825649 = 0 (mod 2)
# 37 . 1023062279 = 0 (mod 2)
# 37 . 1023143780 = 0 (mod 2)
# 37 . 1023240803 = 0 (mod 2)
# 37 . 1023705695 = 0 (mod 2)
# 37 . 1023859571 = 0 (mod 2)
# 37 . 1023909343 = 0 (mod 2)
# 37 . 1023911331 = 0 (mod 2)
# 37 . 1023943356 = 0 (mod 2)
# 37 . 1023960225 = 0 (mod 2)
# 37 . 1024039762 = 0 (mod 2)
# 37 . 1024250150 = 0 (mod 2)
# 37 . 1024329905 = 0 (mod 2)
# 37 . 1024415595 = 0 (mod 2)
# 37 . 1024426294 = 0 (mod 2)
# 37 . 1024440113 = 0 (mod 2)
# 37 . 1024459249 = 0 (mod 2)
# 37 . 1024484401 = 0 (mod 2)
# 37 . 1024500688 = 0 (mod 2)
# 37 . 1024658712 = 0 (mod 2)
# 37 . 1024920656 = 0 (mod 2)
# 37 . 1024927751 = 0 (mod 2)
# 37 . 1025027981 = 0 (mod 2)
# 37 . 1025141862 = 0 (mod 2)
# 37 . 1025172383 = 0 (mod 2)
# 37 . 1025280755 = 0 (mod 2)
# 37 . 1025570013 = 0 (mod 2)
# 37 . 1025679199 = 0 (mod 2)
# 37 . 1025931975 = 0 (mod 2)
# 37 . 1026038210 = 0 (mod 2)
# 37 . 1026088543 = 0 (mod 2)
# 37 . 1026319668 = 0 (mod 2)
# 37 . 1026337649 = 0 (mod 2)
# 37 . 1026384235 = 0 (mod 2)
# 37 . 1026559102 = 0 (mod 2)
# 37 . 1026691013 = 0 (mod 2)
# 37 . 1026802967 = 0 (mod 2)
# 37 . 1026813089 = 0 (mod 2)
# 37 . 1026865421 = 0 (mod 2)
# 37 . 1026867480 = 0 (mod 2)
# 37 . 1026871523 = 0 (mod 2)
# 37 . 1026984018 = 0 (mod 2)
# 37 . 1027061570 = 0 (mod 2)
# 37 . 1027110396 = 0 (mod 2)
# 37 . 1027114192 = 0 (mod 2)
# 37 . 1027171274 = 0 (mod 2)
# 37 . 1027231596 = 0 (mod 2)
# 37 . 1027274501 = 0 (mod 2)
# 37 . 1027554020 = 0 (mod 2)
# 37 . 1027574858 = 0 (mod 2)
# 37 . 1027607804 = 0 (mod 2)
# 37 . 1027726963 = 0 (mod 2)
# 37 . 1027764643 = 0 (mod 2)
# 37 . 1027825631 = 0 (mod 2)
# 37 . 1027840519 = 0 (mod 2)
# 37 . 1027869241 = 0 (mod 2)
# 37 . 1028192612 = 0 (mod 2)
# 37 . 1028306568 = 0 (mod 2)
# 37 . 1028429405 = 0 (mod 2)
# 37 . 1028486193 = 0 (mod 2)
# 37 . 1028505324 = 0 (mod 2)
# 37 . 1028872706 = 0 (mod 2)
# 37 . 1028892980 = 0 (mod 2)
# 37 . 1028983810 = 0 (mod 2)
# 37 . 1029005906 = 0 (mod 2)
# 37 . 1029366474 = 0 (mod 2)
# 37 . 1029639540 = 0 (mod 2)
# 37 . 1029683602 = 0 (mod 2)
# 37 . 1029713493 = 0 (mod 2)
# 37 . 1029743851 = 0 (mod 2)
# 37 . 1029943539 = 0 (mod 2)
# 37 . 1029995454 = 0 (mod 2)
# 37 . 1030018706 = 0 (mod 2)
# 37 . 1030088369 = 0 (mod 2)
# 37 . 1030184152 = 0 (mod 2)
# 37 . 1030245873 = 0 (mod 2)
# 37 . 1030361902 = 0 (mod 2)
# 37 . 1030369340 = 0 (mod 2)
# 37 . 1030515085 = 0 (mod 2)
# 37 . 1030688371 = 0 (mod 2)
# 37 . 1030779065 = 0 (mod 2)
# 37 . 1030836393 = 0 (mod 2)
# 37 . 1030863055 = 0 (mod 2)
# 37 . 1030896661 = 0 (mod 2)
# 37 . 1030928548 = 0 (mod 2)
# 37 . 1031096581 = 0 (mod 2)
# 37 . 1031274632 = 0 (mod 2)
# 37 . 1031326218 = 0 (mod 2)
# 37 . 1031392182 = 0 (mod 2)
# 37 . 1031458934 = 0 (mod 2)
# 37 . 1031573353 = 0 (mod 2)
# 37 . 1031595454 = 0 (mod 2)
# 37 . 1031652693 = 0 (mod 2)
# 37 . 1031685021 = 0 (mod 2)
# 37 . 1031736382 = 0 (mod 2)
# 37 . 1031823501 = 0 (mod 2)
# 37 . 1031847453 = 0 (mod 2)
# 37 . 1031995622 = 0 (mod 2)
# 37 . 1032019970 = 0 (mod 2)
# 37 . 1032047731 = 0 (mod 2)
# 37 . 1032418767 = 0 (mod 2)
# 37 . 1032520463 = 0 (mod 2)
# 37 . 1032525704 = 0 (mod 2)
# 37 . 1032559304 = 0 (mod 2)
# 37 . 1032733016 = 0 (mod 2)
# 37 . 1032849751 = 0 (mod 2)
# 37 . 1032864151 = 0 (mod 2)
# 37 . 1032964030 = 0 (mod 2)
# 37 . 1033516637 = 0 (mod 2)
# 37 . 1033533640 = 0 (mod 2)
# 37 . 1033605064 = 0 (mod 2)
# 37 . 1033700644 = 0 (mod 2)
# 37 . 1033753713 = 0 (mod 2)
# 37 . 1033832080 = 0 (mod 2)
# 37 . 1033868334 = 0 (mod 2)
# 37 . 1033991319 = 0 (mod 2)
# 37 . 1034051471 = 0 (mod 2)
# 37 . 1034135381 = 0 (mod 2)
# 37 . 1034139221 = 0 (mod 2)
# 37 . 1034413698 = 0 (mod 2)
# 37 . 1034509402 = 0 (mod 2)
# 37 . 1034509509 = 0 (mod 2)
# 37 . 1034577752 = 0 (mod 2)
# 37 . 1034651485 = 0 (mod 2)
# 37 . 1034888804 = 0 (mod 2)
# 37 . 1034962768 = 0 (mod 2)
# 37 . 1035024783 = 0 (mod 2)
# 37 . 1035158641 = 0 (mod 2)
# 37 . 1035163527 = 0 (mod 2)
# 37 . 1035298169 = 0 (mod 2)
# 37 . 1035454986 = 0 (mod 2)
# 37 . 1035527047 = 0 (mod 2)
# 37 . 1035541000 = 0 (mod 2)
# 37 . 1035931402 = 0 (mod 2)
# 37 . 1036292409 = 0 (mod 2)
# 37 . 1036500760 = 0 (mod 2)
# 37 . 1036558139 = 0 (mod 2)
# 37 . 1036704781 = 0 (mod 2)
# 37 . 1036784005 = 0 (mod 2)
# 37 . 1036972907 = 0 (mod 2)
# 37 . 1037076375 = 0 (mod 2)
# 37 . 1037108406 = 0 (mod 2)
# 37 . 1037142741 = 0 (mod 2)
# 37 . 1037222561 = 0 (mod 2)
# 37 . 1037416912 = 0 (mod 2)
# 37 . 1037493386 = 0 (mod 2)
# 37 . 1037594470 = 0 (mod 2)
# 37 . 1037615291 = 0 (mod 2)
# 37 . 1037699861 = 0 (mod 2)
# 37 . 1037891897 = 0 (mod 2)
# 37 . 1037980073 = 0 (mod 2)
# 37 . 1037987842 = 0 (mod 2)
# 37 . 1037993567 = 0 (mod 2)
# 37 . 1038024346 = 0 (mod 2)
# 37 . 1038042007 = 0 (mod 2)
# 37 . 1038096898 = 0 (mod 2)
# 37 . 1038165305 = 0 (mod 2)
# 37 . 1038232538 = 0 (mod 2)
# 37 . 1038256408 = 0 (mod 2)
# 37 . 1038460897 = 0 (mod 2)
# 37 . 1038468498 = 0 (mod 2)
# 37 . 1038626376 = 0 (mod 2)
# 37 . 1038636019 = 0 (mod 2)
# 37 . 1038658320 = 0 (mod 2)
# 37 . 1038892273 = 0 (mod 2)
# 37 . 1038916531 = 0 (mod 2)
# 37 . 1038963900 = 0 (mod 2)
# 37 . 1039228734 = 0 (mod 2)
# 37 . 1039263011 = 0 (mod 2)
# 37 . 1039502193 = 0 (mod 2)
# 37 . 1039570312 = 0 (mod 2)
# 37 . 1039578428 = 0 (mod 2)
# 37 . 1039629637 = 0 (mod 2)
# 37 . 1039708687 = 0 (mod 2)
# 37 . 1039823821 = 0 (mod 2)
# 37 . 1039902323 = 0 (mod 2)
# 37 . 1040041588 = 0 (mod 2)
# 37 . 1040042186 = 0 (mod 2)
# 37 . 1040149692 = 0 (mod 2)
# 37 . 1040190482 = 0 (mod 2)
# 37 . 1040236521 = 0 (mod 2)
# 37 . 1040506361 = 0 (mod 2)
# 37 . 1040575890 = 0 (mod 2)
# 37 . 1040598661 = 0 (mod 2)
# 37 . 1040712942 = 0 (mod 2)
# 37 . 1040969076 = 0 (mod 2)
# 37 . 1041296955 = 0 (mod 2)
# 37 . 1041327253 = 0 (mod 2)
# 37 . 1041348732 = 0 (mod 2)
# 37 . 1041455751 = 0 (mod 2)
# 37 . 1041683947 = 0 (mod 2)
# 37 . 1041694336 = 0 (mod 2)
# 37 . 1042018186 = 0 (mod 2)
# 37 . 1042089943 = 0 (mod 2)
# 37 . 1042158282 = 0 (mod 2)
# 37 . 1042229130 = 0 (mod 2)
# 37 . 1042242662 = 0 (mod 2)
# 37 . 1042288318 = 0 (mod 2)
# 37 . 1042310635 = 0 (mod 2)
# 37 . 1042457042 = 0 (mod 2)
# 37 . 1042524504 = 0 (mod 2)
# 37 . 1042526599 = 0 (mod 2)
# 37 . 1042546081 = 0 (mod 2)
# 37 . 1042628439 = 0 (mod 2)
# 37 . 1042647000 = 0 (mod 2)
# 37 . 1042843638 = 0 (mod 2)
# 37 . 1042931015 = 0 (mod 2)
# 37 . 1042932350 = 0 (mod 2)
# 37 . 1042956286 = 0 (mod 2)
# 37 . 1043154403 = 0 (mod 2)
# 37 . 1043180224 = 0 (mod 2)
# 37 . 1043207539 = 0 (mod 2)
# 37 . 1043211692 = 0 (mod 2)
# 37 . 1043238495 = 0 (mod 2)
# 37 . 1043329846 = 0 (mod 2)
# 37 . 1043448564 = 0 (mod 2)
# 37 . 1043476808 = 0 (mod 2)
# 37 . 1043535932 = 0 (mod 2)
# 37 . 1043640292 = 0 (mod 2)
# 37 . 1043667271 = 0 (mod 2)
# 37 . 1043874163 = 0 (mod 2)
# 37 . 1044068104 = 0 (mod 2)
# 37 . 1044124943 = 0 (mod 2)
# 37 . 1044305969 = 0 (mod 2)
# 37 . 1044453824 = 0 (mod 2)
# 37 . 1044457252 = 0 (mod 2)
# 37 . 1044487189 = 0 (mod 2)
# 37 . 1044563208 = 0 (mod 2)
# 37 . 1044721754 = 0 (mod 2)
# 37 . 1044929126 = 0 (mod 2)
# 37 . 1045125228 = 0 (mod 2)
# 37 . 1045132716 = 0 (mod 2)
# 37 . 1045273963 = 0 (mod 2)
# 37 . 1045401907 = 0 (mod 2)
# 37 . 1045570609 = 0 (mod 2)
# 37 . 1045674150 = 0 (mod 2)
# 37 . 1045732103 = 0 (mod 2)
# 37 . 1046264079 = 0 (mod 2)
# 37 . 1046435899 = 0 (mod 2)
# 37 . 1046676754 = 0 (mod 2)
# 37 . 1046759268 = 0 (mod 2)
# 37 . 1046804025 = 0 (mod 2)
# 37 . 1046881309 = 0 (mod 2)
# 37 . 1047151061 = 0 (mod 2)
# 37 . 1047200315 = 0 (mod 2)
# 37 . 1047435579 = 0 (mod 2)
# 37 . 1047543467 = 0 (mod 2)
# 37 . 1047810909 = 0 (mod 2)
# 37 . 1047819154 = 0 (mod 2)
# 37 . 1047843933 = 0 (mod 2)
# 37 . 1047888702 = 0 (mod 2)
# 37 . 1048051625 = 0 (mod 2)
# 37 . 1048099686 = 0 (mod 2)
# 37 . 1048146468 = 0 (mod 2)
# 37 . 1048407960 = 0 (mod 2)
# 37 . 1048407967 = 0 (mod 2)
# 37 . 1048455166 = 0 (mod 2)
# 37 . 1048549881 = 0 (mod 2)
# 37 . 1048559573 = 0 (mod 2)
# 37 . 1048665060 = 0 (mod 2)
# 37 . 1048732129 = 0 (mod 2)
# 37 . 1048841843 = 0 (mod 2)
# 37 . 1048914640 = 0 (mod 2)
# 37 . 1048993287 = 0 (mod 2)
# 37 . 1049017239 = 0 (mod 2)
# 37 . 1049347299 = 0 (mod 2)
# 37 . 1049486538 = 0 (mod 2)
# 37 . 1049647696 = 0 (mod 2)
# 37 . 1049718830 = 0 (mod 2)
# 37 . 1049749896 = 0 (mod 2)
# 37 . 1049804805 = 0 (mod 2)
# 37 . 1049919476 = 0 (mod 2)
# 37 . 1050012195 = 0 (mod 2)
# 37 . 1050030658 = 0 (mod 2)
# 37 . 1050054085 = 0 (mod 2)
# 37 . 1050111426 = 0 (mod 2)
# 37 . 1050314242 = 0 (mod 2)
# 37 . 1050319767 = 0 (mod 2)
# 37 . 1050483712 = 0 (mod 2)
# 37 . 1050527511 = 0 (mod 2)
# 37 . 1050915458 = 0 (mod 2)
# 37 . 1051046131 = 0 (mod 2)
# 37 . 1051193375 = 0 (mod 2)
# 37 . 1051219702 = 0 (mod 2)
# 37 . 1051261151 = 0 (mod 2)
# 37 . 1051420734 = 0 (mod 2)
# 37 . 1051479721 = 0 (mod 2)
# 37 . 1051552555 = 0 (mod 2)
# 37 . 1051621684 = 0 (mod 2)
# 37 . 1051759420 = 0 (mod 2)
# 37 . 1051820075 = 0 (mod 2)
# 37 . 1051884708 = 0 (mod 2)
# 37 . 1051894134 = 0 (mod 2)
# 37 . 1052050219 = 0 (mod 2)
# 37 . 1052175197 = 0 (mod 2)
# 37 . 1052209579 = 0 (mod 2)
# 37 . 1052232223 = 0 (mod 2)
# 37 . 1052389950 = 0 (mod 2)
# 37 . 1052407874 = 0 (mod 2)
# 37 . 1052418885 = 0 (mod 2)
# 37 . 1052559181 = 0 (mod 2)
# 37 . 1052768645 = 0 (mod 2)
# 37 . 1053083124 = 0 (mod 2)
# 37 . 1053178322 = 0 (mod 2)
# 37 . 1053194887 = 0 (mod 2)
# 37 . 1053198413 = 0 (mod 2)
# 37 . 1053233237 = 0 (mod 2)
# 37 . 1053697003 = 0 (mod 2)
# 37 . 1053796475 = 0 (mod 2)
# 37 . 1053820573 = 0 (mod 2)
# 37 . 1053895795 = 0 (mod 2)
# 37 . 1053920227 = 0 (mod 2)
# 37 . 1053920737 = 0 (mod 2)
# 37 . 1053986074 = 0 (mod 2)
# 37 . 1054131341 = 0 (mod 2)
# 37 . 1054132707 = 0 (mod 2)
# 37 . 1054153827 = 0 (mod 2)
# 37 . 1054161813 = 0 (mod 2)
# 37 . 1054177190 = 0 (mod 2)
# 37 . 1054329170 = 0 (mod 2)
# 37 . 1054333575 = 0 (mod 2)
# 37 . 1054356997 = 0 (mod 2)
# 37 . 1054372334 = 0 (mod 2)
# 37 . 1054579735 = 0 (mod 2)
# 37 . 1054640384 = 0 (mod 2)
# 37 . 1054696543 = 0 (mod 2)
# 37 . 1054791281 = 0 (mod 2)
# 37 . 1054815317 = 0 (mod 2)
# 37 . 1054989325 = 0 (mod 2)
# 37 . 1055012245 = 0 (mod 2)
# 37 . 1055136036 = 0 (mod 2)
# 37 . 1055157734 = 0 (mod 2)
# 37 . 1055162110 = 0 (mod 2)
# 37 . 1055301942 = 0 (mod 2)
# 37 . 1055508260 = 0 (mod 2)
# 37 . 1055648929 = 0 (mod 2)
# 37 . 1055780606 = 0 (mod 2)
# 37 . 1055817807 = 0 (mod 2)
# 37 . 1055834392 = 0 (mod 2)
# 37 . 1055848008 = 0 (mod 2)
# 37 . 1055935069 = 0 (mod 2)
# 37 . 1056461725 = 0 (mod 2)
# 37 . 1056490041 = 0 (mod 2)
# 37 . 1056646415 = 0 (mod 2)
# 37 . 1056661233 = 0 (mod 2)
# 37 . 1056757333 = 0 (mod 2)
# 37 . 1056931233 = 0 (mod 2)
# 37 . 1056952630 = 0 (mod 2)
# 37 . 1057090842 = 0 (mod 2)
# 37 . 1057197338 = 0 (mod 2)
# 37 . 1057285409 = 0 (mod 2)
# 37 . 1057458445 = 0 (mod 2)
# 37 . 1057465844 = 0 (mod 2)
# 37 . 1057556582 = 0 (mod 2)
# 37 . 1057703706 = 0 (mod 2)
# 37 . 1057905616 = 0 (mod 2)
# 37 . 1057967703 = 0 (mod 2)
# 37 . 1057992280 = 0 (mod 2)
# 37 . 1058056413 = 0 (mod 2)
# 37 . 1058212504 = 0 (mod 2)
# 37 . 1058378370 = 0 (mod 2)
# 37 . 1058407142 = 0 (mod 2)
# 37 . 1058414090 = 0 (mod 2)
# 37 . 1058453281 = 0 (mod 2)
# 37 . 1058573639 = 0 (mod 2)
# 37 . 1058732468 = 0 (mod 2)
# 37 . 1058757414 = 0 (mod 2)
# 37 . 1058906818 = 0 (mod 2)
# 37 . 1059293271 = 0 (mod 2)
# 37 . 1059321546 = 0 (mod 2)
# 37 . 1059344149 = 0 (mod 2)
# 37 . 1059379710 = 0 (mod 2)
# 37 . 1059412654 = 0 (mod 2)
# 37 . 1059434161 = 0 (mod 2)
# 37 . 1059502497 = 0 (mod 2)
# 37 . 1059516281 = 0 (mod 2)
# 37 . 1059685987 = 0 (mod 2)
# 37 . 1059733870 = 0 (mod 2)
# 37 . 1060415932 = 0 (mod 2)
# 37 . 1060416569 = 0 (mod 2)
# 37 . 1060455467 = 0 (mod 2)
# 37 . 1060482353 = 0 (mod 2)
# 37 . 1060521485 = 0 (mod 2)
# 37 . 1060563797 = 0 (mod 2)
# 37 . 1060597015 = 0 (mod 2)
# 37 . 1061011162 = 0 (mod 2)
# 37 . 1061142045 = 0 (mod 2)
# 37 . 1061167550 = 0 (mod 2)
# 37 . 1061229768 = 0 (mod 2)
# 37 . 1061259082 = 0 (mod 2)
# 37 . 1061263114 = 0 (mod 2)
# 37 . 1061329259 = 0 (mod 2)
# 37 . 1061486213 = 0 (mod 2)
# 37 . 1061771087 = 0 (mod 2)
# 37 . 1061810880 = 0 (mod 2)
# 37 . 1062070674 = 0 (mod 2)
# 37 . 1062394951 = 0 (mod 2)
# 37 . 1062707070 = 0 (mod 2)
# 37 . 1062784013 = 0 (mod 2)
# 37 . 1062798203 = 0 (mod 2)
# 37 . 1062804874 = 0 (mod 2)
# 37 . 1062964587 = 0 (mod 2)
# 37 . 1063166349 = 0 (mod 2)
# 37 . 1063238955 = 0 (mod 2)
# 37 . 1063268552 = 0 (mod 2)
# 37 . 1063324772 = 0 (mod 2)
# 37 . 1063329324 = 0 (mod 2)
# 37 . 1063439155 = 0 (mod 2)
# 37 . 1063590928 = 0 (mod 2)
# 37 . 1063640578 = 0 (mod 2)
# 37 . 1063680942 = 0 (mod 2)
# 37 . 1063696709 = 0 (mod 2)
# 37 . 1063937032 = 0 (mod 2)
# 37 . 1064027939 = 0 (mod 2)
# 37 . 1064111943 = 0 (mod 2)
# 37 . 1064135322 = 0 (mod 2)
# 37 . 1064270246 = 0 (mod 2)
# 37 . 1064656739 = 0 (mod 2)
# 37 . 1064669731 = 0 (mod 2)
# 37 . 1064694500 = 0 (mod 2)
# 37 . 1064703501 = 0 (mod 2)
# 37 . 1064749525 = 0 (mod 2)
# 37 . 1064798633 = 0 (mod 2)
# 37 . 1065233749 = 0 (mod 2)
# 37 . 1065352135 = 0 (mod 2)
# 37 . 1065403236 = 0 (mod 2)
# 37 . 1065578968 = 0 (mod 2)
# 37 . 1065608427 = 0 (mod 2)
# 37 . 1065744216 = 0 (mod 2)
# 37 . 1065834209 = 0 (mod 2)
# 37 . 1065865744 = 0 (mod 2)
# 37 . 1066049682 = 0 (mod 2)
# 37 . 1066162868 = 0 (mod 2)
# 37 . 1066205116 = 0 (mod 2)
# 37 . 1066212012 = 0 (mod 2)
# 37 . 1066297112 = 0 (mod 2)
# 37 . 1066415908 = 0 (mod 2)
# 37 . 1066589978 = 0 (mod 2)
# 37 . 1066650005 = 0 (mod 2)
# 37 . 1066684823 = 0 (mod 2)
# 37 . 1066715132 = 0 (mod 2)
# 37 . 1067266760 = 0 (mod 2)
# 37 . 1067461436 = 0 (mod 2)
# 37 . 1067681751 = 0 (mod 2)
# 37 . 1067698440 = 0 (mod 2)
# 37 . 1067761462 = 0 (mod 2)
# 37 . 1067858219 = 0 (mod 2)
# 37 . 1068059480 = 0 (mod 2)
# 37 . 1068244019 = 0 (mod 2)
# 37 . 1068591854 = 0 (mod 2)
# 37 . 1068682832 = 0 (mod 2)
# 37 . 1068773345 = 0 (mod 2)
# 37 . 1068799713 = 0 (mod 2)
# 37 . 1068804749 = 0 (mod 2)
# 37 . 1068906066 = 0 (mod 2)
# 37 . 1069047424 = 0 (mod 2)
# 37 . 1069064124 = 0 (mod 2)
# 37 . 1069117878 = 0 (mod 2)
# 37 . 1069164843 = 0 (mod 2)
# 37 . 1069168519 = 0 (mod 2)
# 37 . 1069183009 = 0 (mod 2)
# 37 . 1069331845 = 0 (mod 2)
# 37 . 1069481543 = 0 (mod 2)
# 37 . 1069509556 = 0 (mod 2)
# 37 . 1069588167 = 0 (mod 2)
# 37 . 1069771461 = 0 (mod 2)
# 37 . 1069939641 = 0 (mod 2)
# 37 . 1070030369 = 0 (mod 2)
# 37 . 1070277548 = 0 (mod 2)
# 37 . 1070391718 = 0 (mod 2)
# 37 . 1070517366 = 0 (mod 2)
# 37 . 1070552121 = 0 (mod 2)
# 37 . 1070604304 = 0 (mod 2)
# 37 . 1070665953 = 0 (mod 2)
# 37 . 1070741512 = 0 (mod 2)
# 37 . 1070901153 = 0 (mod 2)
# 37 . 1070936868 = 0 (mod 2)
# 37 . 1070943056 = 0 (mod 2)
# 37 . 1071000082 = 0 (mod 2)
# 37 . 1071008261 = 0 (mod 2)
# 37 . 1071093269 = 0 (mod 2)
# 37 . 1071125058 = 0 (mod 2)
# 37 . 1071235008 = 0 (mod 2)
# 37 . 1071472141 = 0 (mod 2)
# 37 . 1071528878 = 0 (mod 2)
# 37 . 1071537651 = 0 (mod 2)
# 37 . 1071590908 = 0 (mod 2)
# 37 . 1071681635 = 0 (mod 2)
# 37 . 1071738378 = 0 (mod 2)
# 37 . 1071740387 = 0 (mod 2)
# 37 . 1072032499 = 0 (mod 2)
# 37 . 1072264878 = 0 (mod 2)
# 37 . 1072299778 = 0 (mod 2)
# 37 . 1072520144 = 0 (mod 2)
# 37 . 1072887818 = 0 (mod 2)
# 37 . 1073202852 = 0 (mod 2)
# 37 . 1073207355 = 0 (mod 2)
# 37 . 1073551353 = 0 (mod 2)
# 37 . 1073604862 = 0 (mod 2)
# 37 . 1073733141 = 0 (mod 2)
# 37 . 1073741822 = 0 (mod 2)
