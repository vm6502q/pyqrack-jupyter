# %% [markdown]
# # Simon's algorithm

# %% [markdown]
# Simon's algorithm is closely related in principle to the Bernstein-Vazirani algorithm and the Deutsch-Josza algorithm, (which are also explained in other notebooks in this repository).
#
# We are given an "oracle" and promised that its output are either **one-to-one** or **two-to-one**, i.e., it either has **exactly** as many possible outputs as possible inputs or **exactly half** as many possible outputs as possible inputs. In effect, all two-to-one functions can be thought of as being based on a "**hidden string**" encoded into the oracle, whereas one-to-one functions are the only case where the hidden string is "**0**." Our problem is therefore to determine the "hidden string" encoded into the oracle.
#
# A classical computer, on average, needs to check about half the possible inputs to answer the question of what the hidden string is; a quantum computer needs **exponentially fewer** queries of the oracle to determine the same answer.

# %%
from collections import Counter
from pyqrack import QrackSimulator

hidden_bits = 37
input_size = 8
num_qubits = input_size * 2
oracle_qubits = [*range(input_size)]

# %% [markdown]
# You may change the `hidden_bits` above to be any value that can fit within the oracle register width. Your `hidden_bits` corresponds to the oracle below:

# %%
def oracle(sim):
    # The first portion of this oracle is effectively a one-to-one oracle,
    # in itself, (though not the only possible one-to-one oracle).
    for i in oracle_qubits:
        sim.mcx([i], i + input_size)

    # The second portion of this oracle makes it two-to-one,
    # (unless "hidden_bits" is 0):
    for i in oracle_qubits:
        if (hidden_bits >> i) & 1:
            for j in oracle_qubits:
                if (hidden_bits >> j) & 1:
                    sim.mcx([i], j + input_size)
            break;

# %% [markdown]
# All of the following statements of equality are true:

# %%
# Prepare the initial register state:
sim = QrackSimulator(num_qubits)
for i in oracle_qubits:
    sim.h(i)

# Make exactly one query to the oracle:
oracle(sim)

# Finish the unitary portion of the algorithm, with the result from the oracle...
# (It is often presented that measurement of the second register needs to occur before this step;
# this is actually wholly theoretically unnecessary in the ideal, due to locality of quantum information.)
for i in oracle_qubits:
    sim.h(i)

# The cost in "shot" count is linear, at this point.
results = Counter(sim.measure_shots(oracle_qubits, 10000))

for key in results.keys():
    print("hidden_bits .", key, "= 0 (mod 2)")
# Out:
# Device #0, Loaded binary from: /home/iamu/.qrack/qrack_ocl_dev_Intel(R)_UHD_Graphics_[0x9bc4].ir
# Device #1, Loaded binary from: /home/iamu/.qrack/qrack_ocl_dev_NVIDIA_GeForce_RTX_3080_Laptop_GPU.ir
# hidden_bits . 0 = 0 (mod 2)
# hidden_bits . 2 = 0 (mod 2)
# hidden_bits . 5 = 0 (mod 2)
# hidden_bits . 7 = 0 (mod 2)
# hidden_bits . 8 = 0 (mod 2)
# hidden_bits . 10 = 0 (mod 2)
# hidden_bits . 13 = 0 (mod 2)
# hidden_bits . 15 = 0 (mod 2)
# hidden_bits . 16 = 0 (mod 2)
# hidden_bits . 18 = 0 (mod 2)
# hidden_bits . 21 = 0 (mod 2)
# hidden_bits . 23 = 0 (mod 2)
# hidden_bits . 24 = 0 (mod 2)
# hidden_bits . 26 = 0 (mod 2)
# hidden_bits . 29 = 0 (mod 2)
# hidden_bits . 31 = 0 (mod 2)
# hidden_bits . 33 = 0 (mod 2)
# hidden_bits . 35 = 0 (mod 2)
# hidden_bits . 36 = 0 (mod 2)
# hidden_bits . 38 = 0 (mod 2)
# hidden_bits . 41 = 0 (mod 2)
# hidden_bits . 43 = 0 (mod 2)
# hidden_bits . 44 = 0 (mod 2)
# hidden_bits . 46 = 0 (mod 2)
# hidden_bits . 49 = 0 (mod 2)
# hidden_bits . 51 = 0 (mod 2)
# hidden_bits . 52 = 0 (mod 2)
# hidden_bits . 54 = 0 (mod 2)
# hidden_bits . 57 = 0 (mod 2)
# hidden_bits . 59 = 0 (mod 2)
# hidden_bits . 60 = 0 (mod 2)
# hidden_bits . 62 = 0 (mod 2)
# hidden_bits . 64 = 0 (mod 2)
# hidden_bits . 66 = 0 (mod 2)
# hidden_bits . 69 = 0 (mod 2)
# hidden_bits . 71 = 0 (mod 2)
# hidden_bits . 72 = 0 (mod 2)
# hidden_bits . 74 = 0 (mod 2)
# hidden_bits . 77 = 0 (mod 2)
# hidden_bits . 79 = 0 (mod 2)
# hidden_bits . 80 = 0 (mod 2)
# hidden_bits . 82 = 0 (mod 2)
# hidden_bits . 85 = 0 (mod 2)
# hidden_bits . 87 = 0 (mod 2)
# hidden_bits . 88 = 0 (mod 2)
# hidden_bits . 90 = 0 (mod 2)
# hidden_bits . 93 = 0 (mod 2)
# hidden_bits . 95 = 0 (mod 2)
# hidden_bits . 97 = 0 (mod 2)
# hidden_bits . 99 = 0 (mod 2)
# hidden_bits . 100 = 0 (mod 2)
# hidden_bits . 102 = 0 (mod 2)
# hidden_bits . 105 = 0 (mod 2)
# hidden_bits . 107 = 0 (mod 2)
# hidden_bits . 108 = 0 (mod 2)
# hidden_bits . 110 = 0 (mod 2)
# hidden_bits . 113 = 0 (mod 2)
# hidden_bits . 115 = 0 (mod 2)
# hidden_bits . 116 = 0 (mod 2)
# hidden_bits . 118 = 0 (mod 2)
# hidden_bits . 121 = 0 (mod 2)
# hidden_bits . 123 = 0 (mod 2)
# hidden_bits . 124 = 0 (mod 2)
# hidden_bits . 126 = 0 (mod 2)
# hidden_bits . 128 = 0 (mod 2)
# hidden_bits . 130 = 0 (mod 2)
# hidden_bits . 133 = 0 (mod 2)
# hidden_bits . 135 = 0 (mod 2)
# hidden_bits . 136 = 0 (mod 2)
# hidden_bits . 138 = 0 (mod 2)
# hidden_bits . 141 = 0 (mod 2)
# hidden_bits . 143 = 0 (mod 2)
# hidden_bits . 144 = 0 (mod 2)
# hidden_bits . 146 = 0 (mod 2)
# hidden_bits . 149 = 0 (mod 2)
# hidden_bits . 151 = 0 (mod 2)
# hidden_bits . 152 = 0 (mod 2)
# hidden_bits . 154 = 0 (mod 2)
# hidden_bits . 157 = 0 (mod 2)
# hidden_bits . 159 = 0 (mod 2)
# hidden_bits . 161 = 0 (mod 2)
# hidden_bits . 163 = 0 (mod 2)
# hidden_bits . 164 = 0 (mod 2)
# hidden_bits . 166 = 0 (mod 2)
# hidden_bits . 169 = 0 (mod 2)
# hidden_bits . 171 = 0 (mod 2)
# hidden_bits . 172 = 0 (mod 2)
# hidden_bits . 174 = 0 (mod 2)
# hidden_bits . 177 = 0 (mod 2)
# hidden_bits . 179 = 0 (mod 2)
# hidden_bits . 180 = 0 (mod 2)
# hidden_bits . 182 = 0 (mod 2)
# hidden_bits . 185 = 0 (mod 2)
# hidden_bits . 187 = 0 (mod 2)
# hidden_bits . 188 = 0 (mod 2)
# hidden_bits . 190 = 0 (mod 2)
# hidden_bits . 192 = 0 (mod 2)
# hidden_bits . 194 = 0 (mod 2)
# hidden_bits . 197 = 0 (mod 2)
# hidden_bits . 199 = 0 (mod 2)
# hidden_bits . 200 = 0 (mod 2)
# hidden_bits . 202 = 0 (mod 2)
# hidden_bits . 205 = 0 (mod 2)
# hidden_bits . 207 = 0 (mod 2)
# hidden_bits . 208 = 0 (mod 2)
# hidden_bits . 210 = 0 (mod 2)
# hidden_bits . 213 = 0 (mod 2)
# hidden_bits . 215 = 0 (mod 2)
# hidden_bits . 216 = 0 (mod 2)
# hidden_bits . 218 = 0 (mod 2)
# hidden_bits . 221 = 0 (mod 2)
# hidden_bits . 223 = 0 (mod 2)
# hidden_bits . 225 = 0 (mod 2)
# hidden_bits . 227 = 0 (mod 2)
# hidden_bits . 228 = 0 (mod 2)
# hidden_bits . 230 = 0 (mod 2)
# hidden_bits . 233 = 0 (mod 2)
# hidden_bits . 235 = 0 (mod 2)
# hidden_bits . 236 = 0 (mod 2)
# hidden_bits . 238 = 0 (mod 2)
# hidden_bits . 241 = 0 (mod 2)
# hidden_bits . 243 = 0 (mod 2)
# hidden_bits . 244 = 0 (mod 2)
# hidden_bits . 246 = 0 (mod 2)
# hidden_bits . 249 = 0 (mod 2)
# hidden_bits . 251 = 0 (mod 2)
# hidden_bits . 252 = 0 (mod 2)
# hidden_bits . 254 = 0 (mod 2)

# %% [markdown]
# ...The ultimate point of the algorithm is that, by solving the above system of equations, we can determine the value of `hidden_string`, with a probabilistic likelihood that converges exponentially faster than a "classical" algorithm, in the number of measurement "shots." (In a real hardware quantum computer, the number of "shots" would correspond to exactly the number of queries of the oracle).

# %%
for key in results.keys():
    x = (bin(hidden_bits & key).count("1")) & 1
    print(hidden_bits, ".", key, "=", x, "(mod 2)")
# Out:
# 37 . 0 = 0 (mod 2)
# 37 . 2 = 0 (mod 2)
# 37 . 5 = 0 (mod 2)
# 37 . 7 = 0 (mod 2)
# 37 . 8 = 0 (mod 2)
# 37 . 10 = 0 (mod 2)
# 37 . 13 = 0 (mod 2)
# 37 . 15 = 0 (mod 2)
# 37 . 16 = 0 (mod 2)
# 37 . 18 = 0 (mod 2)
# 37 . 21 = 0 (mod 2)
# 37 . 23 = 0 (mod 2)
# 37 . 24 = 0 (mod 2)
# 37 . 26 = 0 (mod 2)
# 37 . 29 = 0 (mod 2)
# 37 . 31 = 0 (mod 2)
# 37 . 33 = 0 (mod 2)
# 37 . 35 = 0 (mod 2)
# 37 . 36 = 0 (mod 2)
# 37 . 38 = 0 (mod 2)
# 37 . 41 = 0 (mod 2)
# 37 . 43 = 0 (mod 2)
# 37 . 44 = 0 (mod 2)
# 37 . 46 = 0 (mod 2)
# 37 . 49 = 0 (mod 2)
# 37 . 51 = 0 (mod 2)
# 37 . 52 = 0 (mod 2)
# 37 . 54 = 0 (mod 2)
# 37 . 57 = 0 (mod 2)
# 37 . 59 = 0 (mod 2)
# 37 . 60 = 0 (mod 2)
# 37 . 62 = 0 (mod 2)
# 37 . 64 = 0 (mod 2)
# 37 . 66 = 0 (mod 2)
# 37 . 69 = 0 (mod 2)
# 37 . 71 = 0 (mod 2)
# 37 . 72 = 0 (mod 2)
# 37 . 74 = 0 (mod 2)
# 37 . 77 = 0 (mod 2)
# 37 . 79 = 0 (mod 2)
# 37 . 80 = 0 (mod 2)
# 37 . 82 = 0 (mod 2)
# 37 . 85 = 0 (mod 2)
# 37 . 87 = 0 (mod 2)
# 37 . 88 = 0 (mod 2)
# 37 . 90 = 0 (mod 2)
# 37 . 93 = 0 (mod 2)
# 37 . 95 = 0 (mod 2)
# 37 . 97 = 0 (mod 2)
# 37 . 99 = 0 (mod 2)
# 37 . 100 = 0 (mod 2)
# 37 . 102 = 0 (mod 2)
# 37 . 105 = 0 (mod 2)
# 37 . 107 = 0 (mod 2)
# 37 . 108 = 0 (mod 2)
# 37 . 110 = 0 (mod 2)
# 37 . 113 = 0 (mod 2)
# 37 . 115 = 0 (mod 2)
# 37 . 116 = 0 (mod 2)
# 37 . 118 = 0 (mod 2)
# 37 . 121 = 0 (mod 2)
# 37 . 123 = 0 (mod 2)
# 37 . 124 = 0 (mod 2)
# 37 . 126 = 0 (mod 2)
# 37 . 128 = 0 (mod 2)
# 37 . 130 = 0 (mod 2)
# 37 . 133 = 0 (mod 2)
# 37 . 135 = 0 (mod 2)
# 37 . 136 = 0 (mod 2)
# 37 . 138 = 0 (mod 2)
# 37 . 141 = 0 (mod 2)
# 37 . 143 = 0 (mod 2)
# 37 . 144 = 0 (mod 2)
# 37 . 146 = 0 (mod 2)
# 37 . 149 = 0 (mod 2)
# 37 . 151 = 0 (mod 2)
# 37 . 152 = 0 (mod 2)
# 37 . 154 = 0 (mod 2)
# 37 . 157 = 0 (mod 2)
# 37 . 159 = 0 (mod 2)
# 37 . 161 = 0 (mod 2)
# 37 . 163 = 0 (mod 2)
# 37 . 164 = 0 (mod 2)
# 37 . 166 = 0 (mod 2)
# 37 . 169 = 0 (mod 2)
# 37 . 171 = 0 (mod 2)
# 37 . 172 = 0 (mod 2)
# 37 . 174 = 0 (mod 2)
# 37 . 177 = 0 (mod 2)
# 37 . 179 = 0 (mod 2)
# 37 . 180 = 0 (mod 2)
# 37 . 182 = 0 (mod 2)
# 37 . 185 = 0 (mod 2)
# 37 . 187 = 0 (mod 2)
# 37 . 188 = 0 (mod 2)
# 37 . 190 = 0 (mod 2)
# 37 . 192 = 0 (mod 2)
# 37 . 194 = 0 (mod 2)
# 37 . 197 = 0 (mod 2)
# 37 . 199 = 0 (mod 2)
# 37 . 200 = 0 (mod 2)
# 37 . 202 = 0 (mod 2)
# 37 . 205 = 0 (mod 2)
# 37 . 207 = 0 (mod 2)
# 37 . 208 = 0 (mod 2)
# 37 . 210 = 0 (mod 2)
# 37 . 213 = 0 (mod 2)
# 37 . 215 = 0 (mod 2)
# 37 . 216 = 0 (mod 2)
# 37 . 218 = 0 (mod 2)
# 37 . 221 = 0 (mod 2)
# 37 . 223 = 0 (mod 2)
# 37 . 225 = 0 (mod 2)
# 37 . 227 = 0 (mod 2)
# 37 . 228 = 0 (mod 2)
# 37 . 230 = 0 (mod 2)
# 37 . 233 = 0 (mod 2)
# 37 . 235 = 0 (mod 2)
# 37 . 236 = 0 (mod 2)
# 37 . 238 = 0 (mod 2)
# 37 . 241 = 0 (mod 2)
# 37 . 243 = 0 (mod 2)
# 37 . 244 = 0 (mod 2)
# 37 . 246 = 0 (mod 2)
# 37 . 249 = 0 (mod 2)
# 37 . 251 = 0 (mod 2)
# 37 . 252 = 0 (mod 2)
# 37 . 254 = 0 (mod 2)
