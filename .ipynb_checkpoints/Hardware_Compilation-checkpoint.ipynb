# %% [markdown]
# # Hardware Compilation (With Qrack)

# %% [markdown]
# You need the `pyqrack` package to run this notebook. [`vm6502q/pyqrack`](https://github.com/vm6502q/pyqrack) is a pure Python wrapper on the [`vm6502q/qrack`](https://github.com/vm6502q/qrack) quantum computer simulation framework core library. The preferred method of installation is from source code, at those GitHub repositories, but a package with default build precompiled binaries is available on [pypi](https://pypi.org/project/pyqrack/0.2.0/).

# %%
width = 3

# %%
# For example, if your Jupyter installation uses pip:
# import sys
# !{sys.executable} -m pip install pyqrack

import os

# Change these according to your OpenCL devices and system specifications:
# os.environ['QRACK_MAX_PAGE_QB']='27'
# os.environ['QRACK_QUNITMULTI_DEVICES']='1'
# os.environ['QRACK_QPAGER_DEVICES']='1'
# os.environ['QRACK_MAX_ALLOC_MB']='147456,15872'
# os.environ['QRACK_MAX_PAGING_QB']='30'
os.environ['QRACK_MAX_CPU_QB']='-1'

# %% [markdown]
# [`QrackSimulator`](https://github.com/vm6502q/pyqrack/blob/main/pyqrack/qrack_simulator.py) is the "workhorse" of the `pyqrack` package. It instantiates simulated "registers" of qubits that we can act basic quantum gates between, to form arbitrary universal quantum circuits.

# %% [markdown]
# `QrackCircuit` is an optional class for optimizing compilation. With it, one can define a circuit in advance, which is optimized upon definition. Then, one can save the optimized result to a file and later load it into a new or existing `QrackCircuit` instance. Ultimately, the circuit is executed by calling `run()` on a `QrackCircuit`, with a parameter of `QrackSimulator` of appropriate size. (The necessary width of the `QrackSimulator` can be determined with `QrackCircuit.get_qubit_count()`.)

# %%
import math
import random

sqrt1_2 = 1 / math.sqrt(2)

def x_to_y(circ, q):
    circ.mtrx([1, 0, 0, 1j], q)
    return 1

def x_to_z(circ, q):
    circ.mtrx([sqrt1_2, sqrt1_2, sqrt1_2, -sqrt1_2], q)
    return 1

def y_to_z(circ, q):
    circ.mtrx([1, 0, 0, -1j], q)
    circ.mtrx([sqrt1_2, sqrt1_2, sqrt1_2, -sqrt1_2], q)
    return 2

def y_to_x(circ, q):
    circ.mtrx([1, 0, 0, -1j], q)
    return 1

def z_to_x(circ, q):
    circ.mtrx([sqrt1_2, sqrt1_2, sqrt1_2, -sqrt1_2], q)
    return 1

def z_to_y(circ, q):
    circ.mtrx([sqrt1_2, sqrt1_2, sqrt1_2, -sqrt1_2], q)
    circ.mtrx([1, 0, 0, 1j], q)
    return 2

def cx(circ, q1, q2):
    circ.ucmtrx([q1], [0, 1, 1, 0], q2, 1)
    return 1

def cy(circ, q1, q2):
    circ.ucmtrx([q1], [0, -1j, 1j, 0], q2, 1)
    return 1

def cz(circ, q1, q2):
    circ.ucmtrx([q1], [1, 0, 0, -1], q2, 1)
    return 1

def acx(circ, q1, q2):
    circ.ucmtrx([q1], [0, 1, 1, 0], q2, 0)
    return 1

def acy(circ, q1, q2):
    circ.ucmtrx([q1], [0, -1j, 1j, 0], q2, 0)
    return 1

def acz(circ, q1, q2):
    circ.ucmtrx([q1], [1, 0, 0, -1], q2, 0)
    return 1

def swap(circ, q1, q2):
    circ.swap(q1, q2)
    return 1

def nswap(circ, q1, q2):
    circ.ucmtrx([q1], [1, 0, 0, -1], q2, 0)
    circ.swap(q1, q2)
    circ.ucmtrx([q1], [1, 0, 0, -1], q2, 0)
    return 3

def pswap(circ, q1, q2):
    circ.ucmtrx([q1], [1, 0, 0, -1], q2, 0)
    circ.swap(q1, q2)
    return 2

def mswap(circ, q1, q2):
    circ.swap(q1, q2)
    circ.ucmtrx([q1], [1, 0, 0, -1], q2, 0)
    return 2

def iswap(circ, q1, q2):
    circ.swap(q1, q2)
    circ.ucmtrx([q1], [1, 0, 0, -1], q2, 1)
    circ.mtrx([1, 0, 0, 1j], q1)
    circ.mtrx([1, 0, 0, 1j], q2)
    return 4

def iiswap(circ, q1, q2):
    circ.mtrx([1, 0, 0, -1j], q2)
    circ.mtrx([1, 0, 0, -1j], q1)
    circ.ucmtrx([q1], [1, 0, 0, -1], q2, 1)
    circ.swap(q1, q2)
    return 4

def random_circuit(width, circ):
    gate_count = 0
    
    single_bit_gates = { 0: (z_to_x, z_to_y), 1: (x_to_y, x_to_z), 2: (y_to_z, y_to_x) } 
    two_bit_gates = swap, pswap, mswap, nswap, iswap, iiswap, cx, cy, cz, acx, acy, acz
    
    # Nearest-neighbor couplers:
    gateSequence = [ 0, 3, 2, 1, 2, 1, 0, 3 ]
    row_len = math.ceil(math.sqrt(width))

    # Don't repeat bases:
    bases = [0] * width
    directions = [0] * width
    
    for i in range(3 * width):
        # Single bit gates
        for j in range(width):
            # Reset basis, every third layer
            if i % 3 == 0:
                bases[j] = random.randint(0, 2)
                directions[j] = random.randint(0, 1)
            
            # Sequential basis switch
            gate = single_bit_gates[bases[j]][directions[j]]
            gate_count += gate(circ, j)

            # Cycle through all 3 Pauli axes, every 3 layers
            if directions[j]:
                bases[j] -= 1
                if bases[j] < 0:
                    bases[j] += 3
            else:
                bases[j] += 1
                if bases[j] > 2:
                    bases[j] -= 3
                
            # Rotate around local Z axis
            rnd = random.uniform(0, 2 * math.pi)
            circ.mtrx([1, 0, 0, math.cos(rnd) + math.sin(rnd) * 1j], j)
            gate_count += 1
            
        # Nearest-neighbor couplers:
        ############################
        gate = gateSequence.pop(0)
        gateSequence.append(gate)
        for row in range(1, row_len, 2):
            for col in range(row_len):
                temp_row = row
                temp_col = col
                temp_row = temp_row + (1 if (gate & 2) else -1);
                temp_col = temp_col + (1 if (gate & 1) else 0)

                if (temp_row < 0) or (temp_col < 0) or (temp_row >= row_len) or (temp_col >= row_len):
                    continue

                b1 = row * row_len + col
                b2 = temp_row * row_len + temp_col

                if (b1 >= width) or (b2 >= width):
                    continue

                g = random.choice(two_bit_gates)
                gate_count += g(circ, b1, b2)

    print("Gate count (before optimization): " + str(gate_count))

    return circ

# %%
from pyqrack import QrackSimulator, QrackCircuit

qcircuit = QrackCircuit()
random_circuit(width, qcircuit)
qcircuit.out_to_file('qrack_circuit.qc')

data = ''
with open('qrack_circuit.qc', 'r') as file:
    data = file.read().split()
    
print("Gate count (after optimization): " + str(data[1]))
# Out:
# Gate count (before optimization): 73
# Gate count (after optimization): 17

# %% [markdown]
# If we have Qiskit and numpy installed, we can convert to a Qiskit circuit.

# %%
circ = QrackCircuit.file_to_qiskit_circuit('qrack_circuit.qc')
print(circ)
# Out:
#                     ┌──────────────┐┌──────────────┐┌──────────────┐»
# q_0: ───────────────┤0             ├┤1             ├┤0             ├»
#      ┌─────────────┐│              ││              ││              │»
# q_1: ┤ Multiplexer ├┤  Multiplexer ├┤  Multiplexer ├┤  Multiplexer ├»
#      ├─────────────┤│              ││              ││              │»
# q_2: ┤ Multiplexer ├┤1             ├┤0             ├┤1             ├»
#      └─────────────┘└──────────────┘└──────────────┘└──────────────┘»
# c: 3/═══════════════════════════════════════════════════════════════»
#                                                                     »
# «                                                                   »
# «q_0: ──────────────────────────────────────────────────────────────»
# «                    ┌──────────────┐               ┌──────────────┐»
# «q_1: ───────────────┤0             ├───────────────┤0             ├»
# «     ┌─────────────┐│  Multiplexer │┌─────────────┐│  Multiplexer │»
# «q_2: ┤ Multiplexer ├┤1             ├┤ Multiplexer ├┤1             ├»
# «     └─────────────┘└──────────────┘└─────────────┘└──────────────┘»
# «c: 3/══════════════════════════════════════════════════════════════»
# «                                                                   »
# «                                                    ┌──────────────┐»
# «q_0: ───────────────────────────────────────────────┤0             ├»
# «     ┌──────────────┐┌──────────────┐               │              │»
# «q_1: ┤1             ├┤0             ├───────────────┤  Multiplexer ├»
# «     │  Multiplexer ││  Multiplexer │┌─────────────┐│              │»
# «q_2: ┤0             ├┤1             ├┤ Multiplexer ├┤1             ├»
# «     └──────────────┘└──────────────┘└─────────────┘└──────────────┘»
# «c: 3/═══════════════════════════════════════════════════════════════»
# «                                                                    »
# «     ┌──────────────┐┌──────────────┐               ┌──────────────┐
# «q_0: ┤1             ├┤0             ├───────────────┤0             ├
# «     │              ││              │               │              │
# «q_1: ┤  Multiplexer ├┤  Multiplexer ├───────────────┤  Multiplexer ├
# «     │              ││              │┌─────────────┐│              │
# «q_2: ┤0             ├┤1             ├┤ Multiplexer ├┤1             ├
# «     └──────────────┘└──────────────┘└─────────────┘└──────────────┘
# «c: 3/═══════════════════════════════════════════════════════════════
# «

# %% [markdown]
# Let's transpile for `QStabilizerHybrid` Clifford+RZ gate set!

# %%
from qiskit.compiler.transpiler import transpile

basis_gates = ["rz", "h", "x", "y", "z", "s", "adjs", "sqrtx", "sqrty", "cx", "cy", "cz", "swap", "iswap"]
circ = transpile(circ, basis_gates=basis_gates, optimization_level=3)
print(circ)
# Out:
# global phase: 2.0505
#        ┌─────────┐  ┌──────────┐┌───┐┌──────────┐ ┌──────────┐ ┌──────────┐»
# q_0: ──┤ Rz(π/2) ├──┤ Rz(-π/2) ├┤ H ├┤ Rz(-π/2) ├─┤ Rz(3π/2) ├─┤ Rz(-π/2) ├»
#      ┌─┴─────────┴─┐├──────────┤├───┤├──────────┤┌┴──────────┴┐├──────────┤»
# q_1: ┤ Rz(-1.0269) ├┤ Rz(-π/2) ├┤ H ├┤ Rz(-π/2) ├┤ Rz(6.0001) ├┤ Rz(-π/2) ├»
#      └──┬───────┬──┘├──────────┤├───┤├──────────┤└┬──────────┬┘├──────────┤»
# q_2: ───┤ Rz(0) ├───┤ Rz(-π/2) ├┤ H ├┤ Rz(-π/2) ├─┤ Rz(3π/2) ├─┤ Rz(-π/2) ├»
#         └───────┘   └──────────┘└───┘└──────────┘ └──────────┘ └──────────┘»
# c: 3/══════════════════════════════════════════════════════════════════════»
#                                                                            »
# «     ┌───┐┌──────────┐  ┌────────┐  ┌────────┐┌──────────┐┌──────────┐┌───┐»
# «q_0: ┤ H ├┤ Rz(-π/2) ├──┤ Rz(2π) ├──┤0       ├┤ Rz(-π/2) ├┤ Rz(-π/2) ├┤ H ├»
# «     ├───┤├──────────┤┌─┴────────┴─┐│        │└──────────┘└──────────┘└───┘»
# «q_1: ┤ H ├┤ Rz(-π/2) ├┤ Rz(9.6621) ├┤  Iswap ├─────────────────────────────»
# «     ├───┤├──────────┤└┬──────────┬┘│        │                             »
# «q_2: ┤ H ├┤ Rz(-π/2) ├─┤ Rz(7π/2) ├─┤1       ├─────────────────────────────»
# «     └───┘└──────────┘ └──────────┘ └────────┘                             »
# «c: 3/══════════════════════════════════════════════════════════════════════»
# «                                                                           »
# «     ┌──────────┐┌──────────┐┌──────────┐┌───┐┌──────────┐┌────────┐┌────────┐»
# «q_0: ┤ Rz(-π/2) ├┤ Rz(3π/2) ├┤ Rz(-π/2) ├┤ H ├┤ Rz(-π/2) ├┤ Rz(3π) ├┤0       ├»
# «     └──────────┘└──────────┘└──────────┘└───┘└──────────┘└────────┘│        │»
# «q_1: ───────────────────────────────────────────────────────────────┤  Iswap ├»
# «                                                                    │        │»
# «q_2: ───────────────────────────────────────────────────────────────┤1       ├»
# «                                                                    └────────┘»
# «c: 3/═════════════════════════════════════════════════════════════════════════»
# «                                                                              »
# «     ┌─────────────┐┌──────────┐┌───┐┌──────────┐ ┌────────┐ ┌──────────┐┌───┐»
# «q_0: ┤ Rz(-3.0266) ├┤ Rz(-π/2) ├┤ H ├┤ Rz(-π/2) ├─┤ Rz(2π) ├─┤ Rz(-π/2) ├┤ H ├»
# «     └─────────────┘└──────────┘└───┘└──────────┘ └────────┘ └──────────┘└───┘»
# «q_1: ─────────────────────────────────────────────────────────────────────────»
# «        ┌────────┐  ┌──────────┐┌───┐┌──────────┐┌──────────┐┌──────────┐┌───┐»
# «q_2: ───┤ Rz(-π) ├──┤ Rz(-π/2) ├┤ H ├┤ Rz(-π/2) ├┤ Rz(3π/2) ├┤ Rz(-π/2) ├┤ H ├»
# «        └────────┘  └──────────┘└───┘└──────────┘└──────────┘└──────────┘└───┘»
# «c: 3/═════════════════════════════════════════════════════════════════════════»
# «                                                                              »
# «     ┌──────────┐┌────────────┐┌────────┐┌─────────────┐┌──────────┐┌───┐»
# «q_0: ┤ Rz(-π/2) ├┤ Rz(11.111) ├┤0       ├┤ Rz(-2.5832) ├┤ Rz(-π/2) ├┤ H ├»
# «     └──────────┘└────────────┘│        │└─────────────┘└──────────┘└───┘»
# «q_1: ──────────────────────────┤  Iswap ├────────────────────────────────»
# «     ┌──────────┐ ┌──────────┐ │        │┌─────────────┐┌──────────┐┌───┐»
# «q_2: ┤ Rz(-π/2) ├─┤ Rz(7π/2) ├─┤1       ├┤ Rz(-2.8329) ├┤ Rz(-π/2) ├┤ H ├»
# «     └──────────┘ └──────────┘ └────────┘└─────────────┘└──────────┘└───┘»
# «c: 3/════════════════════════════════════════════════════════════════════»
# «                                                                         »
# «     ┌──────────┐┌────────────┐┌──────────┐┌───┐┌──────────┐┌────────────┐»
# «q_0: ┤ Rz(-π/2) ├┤ Rz(5.4605) ├┤ Rz(-π/2) ├┤ H ├┤ Rz(-π/2) ├┤ Rz(8.2446) ├»
# «     └──────────┘└────────────┘└──────────┘└───┘└──────────┘└────────────┘»
# «q_1: ─────────────────────────────────────────────────────────────────────»
# «     ┌──────────┐┌────────────┐┌──────────┐┌───┐┌──────────┐┌────────────┐»
# «q_2: ┤ Rz(-π/2) ├┤ Rz(3.8724) ├┤ Rz(-π/2) ├┤ H ├┤ Rz(-π/2) ├┤ Rz(7.2261) ├»
# «     └──────────┘└────────────┘└──────────┘└───┘└──────────┘└────────────┘»
# «c: 3/═════════════════════════════════════════════════════════════════════»
# «                                                                          »
# «                                                                              »
# «q_0: ─────────────────────────────────────────────────────────────────────────»
# «                                                                              »
# «q_1: ─────────────────────────────────────────────────────────────────────────»
# «     ┌───────────────┐┌──────────┐┌───┐┌──────────┐┌────────┐┌──────────┐┌───┐»
# «q_2: ┤ Rz(-0.099669) ├┤ Rz(-π/2) ├┤ H ├┤ Rz(-π/2) ├┤ Rz(2π) ├┤ Rz(-π/2) ├┤ H ├»
# «     └───────────────┘└──────────┘└───┘└──────────┘└────────┘└──────────┘└───┘»
# «c: 3/═════════════════════════════════════════════════════════════════════════»
# «                                                                              »
# «                                                                      »
# «q_0: ─────────────────────────────────────────────────────────────────»
# «                               ┌────────┐ ┌────────┐ ┌──────────┐┌───┐»
# «q_1: ──────────────────────────┤0       ├─┤ Rz(-π) ├─┤ Rz(-π/2) ├┤ H ├»
# «     ┌──────────┐┌────────────┐│  Iswap │┌┴────────┴┐├──────────┤├───┤»
# «q_2: ┤ Rz(-π/2) ├┤ Rz(12.467) ├┤1       ├┤ Rz(-π/2) ├┤ Rz(-π/2) ├┤ H ├»
# «     └──────────┘└────────────┘└────────┘└──────────┘└──────────┘└───┘»
# «c: 3/═════════════════════════════════════════════════════════════════»
# «                                                                      »
# «                                                                       »
# «q_0: ──────────────────────────────────────────────────────────────────»
# «     ┌──────────┐┌───────────┐┌──────────┐┌───┐┌──────────┐┌──────────┐»
# «q_1: ┤ Rz(-π/2) ├┤ Rz(5.425) ├┤ Rz(-π/2) ├┤ H ├┤ Rz(-π/2) ├┤ Rz(5π/2) ├»
# «     ├──────────┤└┬──────────┤├──────────┤├───┤├──────────┤└┬────────┬┘»
# «q_2: ┤ Rz(-π/2) ├─┤ Rz(3π/2) ├┤ Rz(-π/2) ├┤ H ├┤ Rz(-π/2) ├─┤ Rz(2π) ├─»
# «     └──────────┘ └──────────┘└──────────┘└───┘└──────────┘ └────────┘ »
# «c: 3/══════════════════════════════════════════════════════════════════»
# «                                                                       »
# «                                                                         »
# «q_0: ────────────────────────────────────────────────────────────────────»
# «     ┌────────┐┌─────────────┐┌──────────┐┌───┐┌──────────┐┌────────────┐»
# «q_1: ┤0       ├┤ Rz(0.37014) ├┤ Rz(-π/2) ├┤ H ├┤ Rz(-π/2) ├┤ Rz(6.1246) ├»
# «     │  Iswap │└┬────────────┤├──────────┤├───┤├──────────┤├────────────┤»
# «q_2: ┤1       ├─┤ Rz(2.1348) ├┤ Rz(-π/2) ├┤ H ├┤ Rz(-π/2) ├┤ Rz(4.1791) ├»
# «     └────────┘ └────────────┘└──────────┘└───┘└──────────┘└────────────┘»
# «c: 3/════════════════════════════════════════════════════════════════════»
# «                                                                         »
# «                                                ┌────────┐┌─────────────┐┌───┐»
# «q_0: ───────────────────────────────────────────┤0       ├┤ Rz(-1.7901) ├┤ H ├»
# «     ┌──────────┐┌───┐┌──────────┐┌────────────┐│        │└─────────────┘└───┘»
# «q_1: ┤ Rz(-π/2) ├┤ H ├┤ Rz(-π/2) ├┤ Rz(6.6379) ├┤  Iswap ├────────────────────»
# «     ├──────────┤├───┤├──────────┤├────────────┤│        │ ┌────────────┐     »
# «q_2: ┤ Rz(-π/2) ├┤ H ├┤ Rz(-π/2) ├┤ Rz(9.6378) ├┤1       ├─┤ Rz(8.8723) ├─────»
# «     └──────────┘└───┘└──────────┘└────────────┘└────────┘ └────────────┘     »
# «c: 3/═════════════════════════════════════════════════════════════════════════»
# «                                                                              »
# «     ┌─────────┐┌───┐┌────────┐
# «q_0: ┤ Rz(π/2) ├┤ H ├┤ Rz(3π) ├
# «     └─────────┘└───┘└────────┘
# «q_1: ──────────────────────────
# «
# «q_2: ──────────────────────────
# «
# «c: 3/══════════════════════════
# «

# %% [markdown]
# If the basis gates can be converted, a Qiskit `QuantumCircuit` can also be read into a `QrackCircuit`.

# %%
# qcircuit = QrackCircuit.in_from_qiskit_circuit(circ)
# qcircuit.out_to_file('qiskit.qc')

# %% [markdown]
# Let's compile for hardware targets, with `QStabilizerHybrid` Clifford+RZ, by running the Clifford simulator without measurement. Measurement is our only (very) computationally expensive operation.

# %%
qsim = QrackSimulator(width, isSchmidtDecomposeMulti=False, isSchmidtDecompose=False, isOpenCL=False)
qsim.set_hardware_encoded(True)
qsim.run_qiskit_circuit(circ, 0)
qsim.out_to_file('qrack_circuit.chp')

# %% [markdown]
# The simulator itself acts like a unitary compiler, converting the intermediate result into a stabilizer code plus a single non-Clifford single-qubit gate layer, after the stabilizer state preparation.

# %%
circ = QrackSimulator.file_to_qiskit_circuit('qrack_circuit.chp')
circ.qasm(filename='qiskit_circuit.qasm')
print(circ)
# Out:
#       ┌───┐┌───┐                ┌───┐                ┌───┐   ┌───┐             »
#  q_0: ┤ S ├┤ H ├─────────────■──┤ H ├────────────────┤ X ├───┤ H ├─────────────»
#       ├───┤├───┤             │  ├───┤        ┌───┐   └─┬─┘   └───┘        ┌───┐»
#  q_1: ┤ S ├┤ H ├─────■───────┼──┤ H ├────────┤ X ├─────┼───────────────■──┤ H ├»
#       ├───┤└───┘     │       │  ├───┤┌───┐   └─┬─┘     │     ┌───┐     │  └───┘»
#  q_2: ┤ H ├──■───────┼───────┼──┤ H ├┤ X ├─────┼───────┼─────┤ H ├─────┼────■──»
#       └───┘  │     ┌─┴─┐     │  ├───┤└─┬─┘     │       │  ┌──┴───┴──┐  │    │  »
#  q_3: ───────┼─────┤ X ├─────┼──┤ X ├──┼───────┼───────┼──┤ Unitary ├──┼────┼──»
#       ┌───┐  │     └───┘     │  └───┘  │       │       │  └──┬───┬──┘  │    │  »
#  q_4: ┤ H ├──┼───────────────┼─────────┼───────■───────┼─────┤ Z ├─────┼────┼──»
#       └───┘  │             ┌─┴─┐┌───┐  │  ┌─────────┐  │     └───┘     │    │  »
#  q_5: ───────┼─────────────┤ X ├┤ X ├──┼──┤ Unitary ├──┼───────────────┼────┼──»
#       ┌───┐  │             └───┘└───┘  │  └─────────┘  │     ┌───┐     │    │  »
#  q_6: ┤ H ├──┼─────────────────────────┼───────────────■─────┤ Z ├─────┼────┼──»
#       └───┘┌─┴─┐┌─────────┐            │                     └───┘     │    │  »
#  q_7: ─────┤ X ├┤ Unitary ├────────────┼───────────────────────■───────┼────┼──»
#       ┌───┐└───┘└─────────┘            │  ┌─────────┐┌───┐     │       │    │  »
#  q_8: ┤ H ├────────────────────────────■──┤ Unitary ├┤ H ├─────■───────┼────┼──»
#       └───┘                               └─────────┘└───┘             │    │  »
#  q_9: ─────────────────────────────────────────────────────────────────┼────┼──»
#       ┌───┐                                                            │    │  »
# q_10: ┤ H ├────────────────────────────────────────────────────────────┼────┼──»
#       └───┘                                                            │    │  »
# q_11: ─────────────────────────────────────────────────────────────────┼────┼──»
#       ┌───┐                                                            │    │  »
# q_12: ┤ H ├────────────────────────────────────────────────────────────┼────┼──»
#       └───┘                                                            │    │  »
# q_13: ─────────────────────────────────────────────────────────────────┼────┼──»
#       ┌───┐                                                            │    │  »
# q_14: ┤ H ├────────────────────────────────────────────────────────────┼────┼──»
#       └───┘                                                            │    │  »
# q_15: ─────────────────────────────────────────────────────────────────┼────┼──»
#       ┌───┐                                                            │    │  »
# q_16: ┤ H ├────────────────────────────────────────────────────────────┼────┼──»
#       └───┘                                                            │    │  »
# q_17: ─────────────────────────────────────────────────────────────────┼────┼──»
#       ┌───┐                                                            │    │  »
# q_18: ┤ H ├────────────────────────────────────────────────────────────┼────┼──»
#       └───┘                                                          ┌─┴─┐  │  »
# q_19: ───────────────────────────────────────────────────────────────┤ X ├──┼──»
#       ┌───┐                                                          └───┘  │  »
# q_20: ┤ H ├─────────────────────────────────────────────────────────────────┼──»
#       └───┘                                                                 │  »
# q_21: ──────────────────────────────────────────────────────────────────────┼──»
#       ┌───┐                                                                 │  »
# q_22: ┤ H ├─────────────────────────────────────────────────────────────────┼──»
#       └───┘                                                                 │  »
# q_23: ──■───────────────────────────────────────────────────────────────────┼──»
#       ┌─┴─┐                                                                 │  »
# q_24: ┤ X ├─────────────────────────────────────────────────────────────────┼──»
#       └───┘                                                                 │  »
# q_25: ──────────────────────────────────────────────────────────────────────┼──»
#       ┌───┐                                                                 │  »
# q_26: ┤ H ├─────────────────────────────────────────────────────────────────┼──»
#       └───┘                                                                 │  »
# q_27: ──────────────────────────────────────────────────────────────────────┼──»
#       ┌───┐                                                                 │  »
# q_28: ┤ H ├─────────────────────────────────────────────────────────────────┼──»
#       └───┘                                                               ┌─┴─┐»
# q_29: ────────────────────────────────────────────────────────────────────┤ X ├»
#                                                                           └───┘»
# q_30: ─────────────────────────────────────────────────────────────────────────»
#                                                                                »
# «           ┌───┐                        ┌───┐                   ┌───┐┌───┐»
# « q_0: ──■──┤ H ├────────────────────────┤ X ├────────────────■──┤ H ├┤ X ├»
# «        │  └───┘           ┌───┐┌───┐   └─┬─┘                │  └───┘└─┬─┘»
# « q_1: ──┼──────────────────┤ X ├┤ H ├─────┼──────────────────┼─────────┼──»
# «        │                  └─┬─┘└───┘     │                  │         │  »
# « q_2: ──┼────■───────────────┼────────────┼──────────────────┼─────────┼──»
# «        │    │               │            │                  │         │  »
# « q_3: ──┼────┼───────────────┼────────────┼──────────■───────┼─────────┼──»
# «        │    │  ┌─────────┐  │  ┌───┐     │          │       │  ┌───┐  │  »
# « q_4: ──┼────┼──┤ Unitary ├──┼──┤ H ├─────┼──────────■───────┼──┤ H ├──┼──»
# «        │    │  └─────────┘  │  └───┘     │                  │  └───┘  │  »
# « q_5: ──┼────┼───────────────┼────────────┼──────────■───────┼─────────┼──»
# «        │    │  ┌─────────┐  │  ┌───┐     │          │       │  ┌───┐  │  »
# « q_6: ──┼────┼──┤ Unitary ├──┼──┤ H ├─────┼──────────■───────┼──┤ H ├──┼──»
# «        │    │  └─────────┘  │  └───┘     │                  │  └───┘  │  »
# « q_7: ──┼────┼───────────────┼────────────┼──────────────────┼─────────┼──»
# «        │    │     ┌───┐     │            │                  │         │  »
# « q_8: ──┼────┼─────┤ H ├─────┼────────────┼──────────────────┼─────────┼──»
# «      ┌─┴─┐  │  ┌──┴───┴──┐  │            │                  │         │  »
# « q_9: ┤ X ├──┼──┤ Unitary ├──┼────────────┼──────────────────┼─────────┼──»
# «      └───┘  │  └─────────┘  │            │     ┌─────────┐  │  ┌───┐  │  »
# «q_10: ───────┼───────────────┼────────────■─────┤ Unitary ├──┼──┤ H ├──┼──»
# «             │               │                  └─────────┘┌─┴─┐├───┤  │  »
# «q_11: ───────┼───────────────┼─────────────────────────────┤ X ├┤ X ├──┼──»
# «             │               │                             └───┘└───┘  │  »
# «q_12: ───────┼───────────────┼─────────────────────────────────────────■──»
# «             │               │                                            »
# «q_13: ───────┼───────────────┼────────────────────────────────────────────»
# «             │               │                                            »
# «q_14: ───────┼───────────────┼────────────────────────────────────────────»
# «             │               │                                            »
# «q_15: ───────┼───────────────┼────────────────────────────────────────────»
# «             │               │                                            »
# «q_16: ───────┼───────────────┼────────────────────────────────────────────»
# «             │               │                                            »
# «q_17: ───────┼───────────────┼────────────────────────────────────────────»
# «             │               │                                            »
# «q_18: ───────┼───────────────┼────────────────────────────────────────────»
# «      ┌───┐  │  ┌─────────┐  │                                            »
# «q_19: ┤ X ├──┼──┤ Unitary ├──┼───────────────────────────────■────────────»
# «      └───┘  │  └─────────┘  │  ┌───┐┌─────────┐   ┌───┐     │  ┌───┐     »
# «q_20: ───────┼───────────────■──┤ Z ├┤ Unitary ├───┤ H ├─────■──┤ H ├─────»
# «             │                  └───┘└─────────┘   └───┘        └───┘     »
# «q_21: ───────┼────────────────────────────────────────────────────────────»
# «             │                                                            »
# «q_22: ───────┼────────────────────────────────────────────────────────────»
# «             │                                                            »
# «q_23: ───────┼────────────────────────────────────────────────────────────»
# «             │                                                            »
# «q_24: ───────┼────────────────────────────────────────────────────────────»
# «             │                                                            »
# «q_25: ───────┼────────────────────────────────────────────────────────────»
# «             │                                                            »
# «q_26: ───────┼────────────────────────────────────────────────────────────»
# «             │                                                            »
# «q_27: ───────┼────────────────────────────────────────────────────────────»
# «             │                                                            »
# «q_28: ───────┼────────────────────────────────────────────────────────────»
# «      ┌───┐  │                                                            »
# «q_29: ┤ H ├──┼────────────────────────────────────────────────────────────»
# «      └───┘┌─┴─┐   ┌───┐                                                  »
# «q_30: ─────┤ X ├───┤ H ├──────────────────────────────────────────────────»
# «           └───┘   └───┘                                                  »
# «         ┌───┐      ┌───┐        ┌───┐           ┌───┐┌───┐        ┌───┐   »
# « q_0: ───┤ S ├──────┤ H ├─────■──┤ H ├───────────┤ X ├┤ H ├──■─────┤ H ├───»
# «         └───┘      └───┘     │  └───┘           └─┬─┘└───┘  │     └───┘   »
# « q_1: ────────────────────────┼────────────────────┼─────────┼─────────────»
# «                              │                    │         │             »
# « q_2: ────────────────────────┼────────────────────┼─────────┼─────────────»
# «                              │                    │         │             »
# « q_3: ────────────────────────┼────────────────────┼─────────┼─────────────»
# «                              │                    │         │             »
# « q_4: ────────────────────────┼────────────────────┼─────────┼─────────────»
# «                              │                    │         │             »
# « q_5: ────────────────────────┼────────────────────┼─────────┼─────────────»
# «                              │                    │         │             »
# « q_6: ────────────────────────┼────────────────────┼─────────┼─────────────»
# «                              │                    │         │             »
# « q_7: ────────────────────────┼────────────────────┼─────────┼─────────────»
# «                              │                    │         │             »
# « q_8: ────────────────────────┼────────────────────┼─────────┼─────────────»
# «                              │                    │         │             »
# « q_9: ─────■──────────────────┼────────────────────┼─────────┼─────────────»
# «           │        ┌───┐     │                    │         │             »
# «q_10: ─────■────────┤ H ├─────┼────────────────────┼─────────┼─────────────»
# «      ┌─────────┐   └───┘     │                    │         │             »
# «q_11: ┤ Unitary ├─────────────┼────────────■───────┼─────────┼─────────────»
# «      └──┬───┬──┘┌─────────┐  │  ┌───┐     │       │  ┌───┐  │             »
# «q_12: ───┤ Z ├───┤ Unitary ├──┼──┤ H ├─────■───────┼──┤ H ├──┼─────────────»
# «         └───┘   └─────────┘┌─┴─┐├───┤┌─────────┐  │  └───┘  │             »
# «q_13: ──────────────────────┤ X ├┤ X ├┤ Unitary ├──┼─────────┼─────────────»
# «                            └───┘└───┘└─────────┘  │  ┌───┐  │  ┌─────────┐»
# «q_14: ─────────────────────────────────────────────■──┤ Z ├──┼──┤ Unitary ├»
# «                                                      └───┘┌─┴─┐├─────────┤»
# «q_15: ─────────────────────────────────────────────────────┤ X ├┤ Unitary ├»
# «                                                           └───┘└─────────┘»
# «q_16: ─────────────────────────────────────────────────────────────────────»
# «                                                                           »
# «q_17: ─────────────────────────────────────────────────────────────────────»
# «                                                                           »
# «q_18: ─────────────────────────────────────────────────────────────────────»
# «                                                                           »
# «q_19: ─────────────────────────────────────────────────────────────────────»
# «                                                                           »
# «q_20: ─────────────────────────────────────────────────────────────────────»
# «                                                                           »
# «q_21: ─────────────────────────────────────────────────────────────────────»
# «                                                                           »
# «q_22: ─────────────────────────────────────────────────────────────────────»
# «                                                                           »
# «q_23: ─────────────────────────────────────────────────────────────────────»
# «                                                                           »
# «q_24: ─────────────────────────────────────────────────────────────────────»
# «                                                                           »
# «q_25: ─────────────────────────────────────────────────────────────────────»
# «                                                                           »
# «q_26: ─────────────────────────────────────────────────────────────────────»
# «                                                                           »
# «q_27: ─────────────────────────────────────────────────────────────────────»
# «                                                                           »
# «q_28: ─────────────────────────────────────────────────────────────────────»
# «                                                                           »
# «q_29: ─────────────────────────────────────────────────────────────────────»
# «                                                                           »
# «q_30: ─────────────────────────────────────────────────────────────────────»
# «                                                                           »
# «           ┌───┐                ┌───┐          ┌───┐             ┌───┐   »
# « q_0: ─────┤ X ├─────────────■──┤ H ├──────────┤ X ├───────■─────┤ S ├───»
# «           └─┬─┘             │  └───┘     ┌───┐└─┬─┘┌───┐  │     ├───┤   »
# « q_1: ───────┼───────────────┼─────────■──┤ H ├──┼──┤ X ├──┼─────┤ S ├───»
# «             │               │         │  └───┘  │  └─┬─┘  │     └───┘   »
# « q_2: ───────┼───────────────┼─────────┼─────────┼────┼────┼─────────────»
# «             │               │         │         │    │    │             »
# « q_3: ───────┼───────────────┼─────────┼─────────┼────┼────┼─────────────»
# «             │               │         │         │    │    │             »
# « q_4: ───────┼───────────────┼─────────┼─────────┼────┼────┼─────────────»
# «             │               │         │         │    │    │             »
# « q_5: ───────┼───────────────┼─────────┼─────────┼────┼────┼─────────────»
# «             │               │         │         │    │    │             »
# « q_6: ───────┼───────────────┼─────────┼─────────┼────┼────┼─────────────»
# «             │               │         │         │    │    │             »
# « q_7: ───────┼───────────────┼─────────┼─────────┼────┼────┼─────────────»
# «             │               │         │         │    │    │             »
# « q_8: ───────┼───────────────┼─────────┼─────────┼────┼────┼─────────────»
# «             │               │         │         │    │    │             »
# « q_9: ───────┼───────────────┼─────────┼─────────┼────┼────┼─────────────»
# «             │               │         │         │    │    │             »
# «q_10: ───────┼───────────────┼─────────┼─────────┼────┼────┼─────────────»
# «             │               │         │         │    │    │             »
# «q_11: ───────┼───────────────┼─────────┼─────────┼────┼────┼─────────────»
# «             │               │         │         │    │    │             »
# «q_12: ───────┼───────────────┼─────────┼─────────┼────┼────┼─────────────»
# «             │               │         │         │    │    │             »
# «q_13: ───────┼───────■───────┼─────────┼─────────┼────┼────┼─────────────»
# «      ┌───┐  │       │       │  ┌───┐  │         │    │    │             »
# «q_14: ┤ H ├──┼───────■───────┼──┤ H ├──┼─────────┼────┼────┼─────────────»
# «      └───┘  │               │  └───┘  │         │    │    │             »
# «q_15: ───────┼───────────────┼─────────┼────■────┼────┼────┼─────────────»
# «             │  ┌─────────┐  │  ┌───┐  │    │    │    │    │     ┌───┐   »
# «q_16: ───────■──┤ Unitary ├──┼──┤ H ├──┼────■────┼────┼────┼─────┤ H ├───»
# «                └─────────┘┌─┴─┐└───┘┌─┴─┐┌───┐  │    │    │  ┌──┴───┴──┐»
# «q_17: ─────────────────────┤ X ├─────┤ X ├┤ X ├──┼────┼────┼──┤ Unitary ├»
# «                           └───┘     └───┘└───┘  │    │    │  └──┬───┬──┘»
# «q_18: ───────────────────────────────────────────■────■────┼─────┤ Z ├───»
# «                                                           │     └───┘   »
# «q_19: ─────────────────────────────────────────────────────┼─────────────»
# «                                                           │             »
# «q_20: ─────────────────────────────────────────────────────┼─────────────»
# «                                                         ┌─┴─┐           »
# «q_21: ───────────────────────────────────────────────────┤ X ├───────────»
# «                                                         └───┘           »
# «q_22: ───────────────────────────────────────────────────────────────────»
# «                                                                         »
# «q_23: ───────────────────────────────────────────────────────────────────»
# «                                                                         »
# «q_24: ───────────────────────────────────────────────────────────────────»
# «                                                                         »
# «q_25: ───────────────────────────────────────────────────────────────────»
# «                                                                         »
# «q_26: ───────────────────────────────────────────────────────────────────»
# «                                                                         »
# «q_27: ───────────────────────────────────────────────────────────────────»
# «                                                                         »
# «q_28: ───────────────────────────────────────────────────────────────────»
# «                                                                         »
# «q_29: ───────────────────────────────────────────────────────────────────»
# «                                                                         »
# «q_30: ───────────────────────────────────────────────────────────────────»
# «                                                                         »
# «         ┌───┐                      ┌───┐┌───┐┌───┐                   ┌───┐   »
# « q_0: ───┤ H ├────────────────────X─┤ X ├┤ S ├┤ H ├─────────────■─────┤ H ├───»
# «         ├───┤           ┌───┐    │ └─┬─┘├───┤└───┘             │     └───┘   »
# « q_1: ───┤ H ├─────■─────┤ H ├────X───■──┤ X ├──■───────────────┼─────────────»
# «         └───┘     │     └───┘           └─┬─┘  │               │             »
# « q_2: ─────────────┼───────────────────────┼────┼───────────────┼─────────────»
# «                   │                       │    │               │             »
# « q_3: ─────────────┼───────────────────────┼────┼───────────────┼─────────────»
# «                   │                       │    │               │             »
# « q_4: ─────────────┼───────────────────────┼────┼───────────────┼─────────────»
# «                   │                       │    │               │             »
# « q_5: ─────────────┼───────────────────────┼────┼───────────────┼─────────────»
# «                   │                       │    │               │             »
# « q_6: ─────────────┼───────────────────────┼────┼───────────────┼─────────────»
# «                   │                       │    │               │             »
# « q_7: ─────────────┼───────────────────────┼────┼───────────────┼─────────────»
# «                   │                       │    │               │             »
# « q_8: ─────────────┼───────────────────────┼────┼───────────────┼─────────────»
# «                   │                       │    │               │             »
# « q_9: ─────────────┼───────────────────────┼────┼───────────────┼─────────────»
# «                   │                       │    │               │             »
# «q_10: ─────────────┼───────────────────────┼────┼───────────────┼─────────────»
# «                   │                       │    │               │             »
# «q_11: ─────────────┼───────────────────────┼────┼───────────────┼─────────────»
# «                   │                       │    │               │             »
# «q_12: ─────────────┼───────────────────────┼────┼───────────────┼─────────────»
# «                   │                       │    │               │             »
# «q_13: ─────────────┼───────────────────────┼────┼───────────────┼─────────────»
# «                   │                       │    │               │             »
# «q_14: ─────────────┼───────────────────────┼────┼───────────────┼─────────────»
# «                   │                       │    │               │             »
# «q_15: ─────────────┼───────────────────────┼────┼───────────────┼─────────────»
# «                   │                       │    │               │             »
# «q_16: ─────────────┼───────────────────────┼────┼───────────────┼─────────────»
# «                   │                       │    │               │             »
# «q_17: ─────────────┼──────────────■────────┼────┼───────────────┼─────────────»
# «      ┌─────────┐  │     ┌───┐    │ ┌───┐  │    │               │             »
# «q_18: ┤ Unitary ├──┼─────┤ H ├────■─┤ H ├──┼────┼───────────────┼─────────────»
# «      └─────────┘  │     └───┘      └───┘  │    │               │             »
# «q_19: ─────────────┼───────────────────────┼────┼───────────────┼─────────────»
# «                   │                       │    │               │             »
# «q_20: ─────────────┼───────────────────────┼────┼───────────────┼─────────────»
# «                 ┌─┴─┐┌─────────┐          │    │               │             »
# «q_21: ───────────┤ X ├┤ Unitary ├──────────┼────┼───────────────┼─────────────»
# «                 └───┘└─────────┘          │    │  ┌─────────┐  │     ┌───┐   »
# «q_22: ─────────────────────────────────────■────┼──┤ Unitary ├──┼─────┤ H ├───»
# «                                              ┌─┴─┐└──┬───┬──┘  │     └───┘   »
# «q_23: ────────────────────────────────────────┤ X ├───┤ H ├─────┼─────────────»
# «                                              └───┘   └───┘     │             »
# «q_24: ──────────────────────────────────────────────────────────┼─────────────»
# «                                                              ┌─┴─┐┌─────────┐»
# «q_25: ────────────────────────────────────────────────────────┤ X ├┤ Unitary ├»
# «                                                              └───┘└─────────┘»
# «q_26: ────────────────────────────────────────────────────────────────────────»
# «                                                                              »
# «q_27: ────────────────────────────────────────────────────────────────────────»
# «                                                                              »
# «q_28: ────────────────────────────────────────────────────────────────────────»
# «                                                                              »
# «q_29: ────────────────────────────────────────────────────────────────────────»
# «                                                                              »
# «q_30: ────────────────────────────────────────────────────────────────────────»
# «                                                                              »
# «                      ┌───┐   ┌───┐   ┌───┐             ┌───┐   ┌───┐»
# « q_0: ────────────────┤ X ├───┤ S ├───┤ H ├───────■─────┤ H ├───┤ X ├»
# «      ┌───┐┌─────────┐└─┬─┘   └───┘   └───┘       │     └───┘   └─┬─┘»
# « q_1: ┤ X ├┤ Unitary ├──┼─────────────────────────┼───────────────┼──»
# «      └─┬─┘└─────────┘  │                         │               │  »
# « q_2: ──┼───────────────┼─────────────────────────┼───────────────┼──»
# «        │               │                         │               │  »
# « q_3: ──┼───────────────┼─────────────────────────┼───────────────┼──»
# «        │               │                         │               │  »
# « q_4: ──┼───────────────┼─────────────────────────┼───────────────┼──»
# «        │               │                         │               │  »
# « q_5: ──┼───────────────┼─────────────────────────┼───────────────┼──»
# «        │               │                         │               │  »
# « q_6: ──┼───────────────┼─────────────────────────┼───────────────┼──»
# «        │               │                         │               │  »
# « q_7: ──┼───────────────┼─────────────────────────┼───────────────┼──»
# «        │               │                         │               │  »
# « q_8: ──┼───────────────┼─────────────────────────┼───────────────┼──»
# «        │               │                         │               │  »
# « q_9: ──┼───────────────┼─────────────────────────┼───────────────┼──»
# «        │               │                         │               │  »
# «q_10: ──┼───────────────┼─────────────────────────┼───────────────┼──»
# «        │               │                         │               │  »
# «q_11: ──┼───────────────┼─────────────────────────┼───────────────┼──»
# «        │               │                         │               │  »
# «q_12: ──┼───────────────┼─────────────────────────┼───────────────┼──»
# «        │               │                         │               │  »
# «q_13: ──┼───────────────┼─────────────────────────┼───────────────┼──»
# «        │               │                         │               │  »
# «q_14: ──┼───────────────┼─────────────────────────┼───────────────┼──»
# «        │               │                         │               │  »
# «q_15: ──┼───────────────┼─────────────────────────┼───────────────┼──»
# «        │               │                         │               │  »
# «q_16: ──┼───────────────┼─────────────────────────┼───────────────┼──»
# «        │               │                         │               │  »
# «q_17: ──┼───────────────┼─────────────────────────┼───────────────┼──»
# «        │               │                         │               │  »
# «q_18: ──┼───────────────┼─────────────────────────┼───────────────┼──»
# «        │               │                         │               │  »
# «q_19: ──┼───────────────┼─────────────────────────┼───────────────┼──»
# «        │               │                         │               │  »
# «q_20: ──┼───────────────┼─────────────────────────┼───────────────┼──»
# «        │               │                         │               │  »
# «q_21: ──┼───────■───────┼─────────────────────────┼───────────────┼──»
# «        │       │       │     ┌───┐               │               │  »
# «q_22: ──┼───────■───────┼─────┤ H ├───────────────┼───────────────┼──»
# «        │     ┌───┐     │     ├───┤        ┌───┐  │  ┌─────────┐  │  »
# «q_23: ──■─────┤ S ├─────┼─────┤ H ├─────■──┤ X ├──┼──┤ Unitary ├──┼──»
# «              └───┘     │     └───┘   ┌─┴─┐├───┤  │  └──┬───┬──┘  │  »
# «q_24: ──────────────────┼─────────────┤ X ├┤ H ├──┼─────┤ Z ├─────┼──»
# «                        │             └───┘└───┘  │     └───┘     │  »
# «q_25: ──────────────────┼────────────────────■────┼───────────────┼──»
# «                        │  ┌─────────┐┌───┐  │    │     ┌───┐     │  »
# «q_26: ──────────────────■──┤ Unitary ├┤ H ├──■────┼─────┤ H ├─────┼──»
# «                           └─────────┘└───┘     ┌─┴─┐┌──┴───┴──┐  │  »
# «q_27: ──────────────────────────────────────────┤ X ├┤ Unitary ├──┼──»
# «                                                └───┘└─────────┘  │  »
# «q_28: ────────────────────────────────────────────────────────────■──»
# «                                                                     »
# «q_29: ───────────────────────────────────────────────────────────────»
# «                                                                     »
# «q_30: ───────────────────────────────────────────────────────────────»
# «                                                                     »
# «         ┌───┐   ┌───┐┌───┐          ┌───┐┌───┐┌─────────┐                »
# « q_0: ───┤ S ├───┤ H ├┤ S ├──■───────┤ X ├┤ Y ├┤ Unitary ├────────────────»
# «         └───┘   └───┘└───┘  │       └─┬─┘└───┘└─────────┘                »
# « q_1: ───────────────────────┼─────────┼──────────────────────────────────»
# «                           ┌─┴─┐┌───┐  │  ┌───┐   ┌───┐   ┌───┐┌─────────┐»
# « q_2: ─────────────────────┤ X ├┤ H ├──■──┤ S ├───┤ X ├───┤ X ├┤ Unitary ├»
# «                           └───┘└───┘     └───┘   └─┬─┘   └─┬─┘└─────────┘»
# « q_3: ──────────────────────────────────────────────┼───────┼─────────────»
# «                                                    │       │             »
# « q_4: ──────────────────────────────────────────────┼───────┼─────────────»
# «                                                    │       │             »
# « q_5: ──────────────────────────────────────────────┼───────┼─────────────»
# «                                                    │       │             »
# « q_6: ──────────────────────────────────────────────┼───────┼─────────────»
# «                                                    │       │             »
# « q_7: ──────────────────────────────────────────────┼───────┼─────────────»
# «                                                    │       │             »
# « q_8: ──────────────────────────────────────────────┼───────┼─────────────»
# «                                                    │       │             »
# « q_9: ──────────────────────────────────────────────┼───────┼─────────────»
# «                                                    │       │             »
# «q_10: ──────────────────────────────────────────────┼───────┼─────────────»
# «                                                    │       │             »
# «q_11: ──────────────────────────────────────────────┼───────┼─────────────»
# «                                                    │       │             »
# «q_12: ──────────────────────────────────────────────┼───────┼─────────────»
# «                                                    │       │             »
# «q_13: ──────────────────────────────────────────────┼───────┼─────────────»
# «                                                    │       │             »
# «q_14: ──────────────────────────────────────────────┼───────┼─────────────»
# «                                                    │       │             »
# «q_15: ──────────────────────────────────────────────┼───────┼─────────────»
# «                                                    │       │             »
# «q_16: ──────────────────────────────────────────────┼───────┼─────────────»
# «                                                    │       │             »
# «q_17: ──────────────────────────────────────────────┼───────┼─────────────»
# «                                                    │       │             »
# «q_18: ──────────────────────────────────────────────┼───────┼─────────────»
# «                                                    │       │             »
# «q_19: ──────────────────────────────────────────────┼───────┼─────────────»
# «                                                    │       │             »
# «q_20: ──────────────────────────────────────────────┼───────┼─────────────»
# «                                                    │       │             »
# «q_21: ──────────────────────────────────────────────┼───────┼─────────────»
# «                                                    │       │             »
# «q_22: ──────────────────────────────────────────────┼───────┼─────────────»
# «                                                    │       │             »
# «q_23: ──────────────────■───────────────────────────┼───────┼─────────────»
# «      ┌─────────┐┌───┐  │  ┌───┐                    │       │             »
# «q_24: ┤ Unitary ├┤ H ├──■──┤ H ├────────────────────┼───────┼─────────────»
# «      └─────────┘└───┘     └───┘                    │       │             »
# «q_25: ──────────────────────────────────────────────┼───────┼─────────────»
# «                                                    │       │             »
# «q_26: ──────────────────────────────────────────────┼───────┼─────────────»
# «                                                    │       │             »
# «q_27: ──────────────────■───────────────────────────┼───────┼─────────────»
# «      ┌─────────┐┌───┐  │  ┌───┐                    │       │             »
# «q_28: ┤ Unitary ├┤ H ├──■──┤ H ├────────────────────┼───────┼─────────────»
# «      └─────────┘└───┘     └───┘                    │       │     ┌───┐   »
# «q_29: ──────────────────────────────────────────────■───────┼─────┤ H ├───»
# «                                                            │  ┌──┴───┴──┐»
# «q_30: ──────────────────────────────────────────────────────■──┤ Unitary ├»
# «                                                               └─────────┘»
# «
# « q_0: ───────────────────
# «
# « q_1: ───────────────────
# «
# « q_2: ───────────────────
# «
# « q_3: ───────────────────
# «
# « q_4: ───────────────────
# «
# « q_5: ───────────────────
# «
# « q_6: ───────────────────
# «
# « q_7: ───────────────────
# «
# « q_8: ───────────────────
# «
# « q_9: ───────────────────
# «
# «q_10: ───────────────────
# «
# «q_11: ───────────────────
# «
# «q_12: ───────────────────
# «
# «q_13: ───────────────────
# «
# «q_14: ───────────────────
# «
# «q_15: ───────────────────
# «
# «q_16: ───────────────────
# «
# «q_17: ───────────────────
# «
# «q_18: ───────────────────
# «
# «q_19: ───────────────────
# «
# «q_20: ───────────────────
# «
# «q_21: ───────────────────
# «
# «q_22: ───────────────────
# «
# «q_23: ───────────────────
# «
# «q_24: ───────────────────
# «
# «q_25: ───────────────────
# «
# «q_26: ───────────────────
# «
# «q_27: ───────────────────
# «
# «q_28: ───────────────────
# «      ┌─────────┐
# «q_29: ┤ Unitary ├─■──────
# «      └──┬───┬──┘ │ ┌───┐
# «q_30: ───┤ H ├────■─┤ H ├
# «         └───┘      └───┘
